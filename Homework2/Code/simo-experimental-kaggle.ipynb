# %% [markdown]
# ### Import libraries

# %%
#!rm -r /kaggle/working/model_vanilla_*
#!rm -r /kaggle/working/model_bilstm_0.63* /kaggle/working/model_bilstm_0.64* /kaggle/working/model_bilstm_0.65* /kaggle/working/model_bilstm_0.66*
#!rm -r /kaggle/working/model_bilstm_0.61* /kaggle/working/model_1dcnn_0.54321/
#!rm -r /kaggle/working/model_1dcnn_0.41564/ /kaggle/working/model_1dcnn_0.66461/ /kaggle/working/model_1dcnn_0.63786/

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)

print(tf.config.list_physical_devices())
# Out:
# 2.6.4
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Set seed for reproducibility

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
#  # Load the training dataset

# %%
path = "/kaggle/input/competition2/"
# Load the .npy file
X = np.load(path + "x_train.npy")
y = np.load(path + "y_train.npy")

print(X.shape, X.dtype, sep=", ")
print(y.shape, y.dtype, sep=", ")
# Out:
# (2429, 36, 6), float64
# (2429,), int32

# %% [markdown]
# Plotting the classes distributions

# %%
# Map classes STRINGS to integers
label_mapping = {
    'Wish': 0,
    'Another': 1,
    'Comfortably': 2,
    'Money': 3,
    'Breathe': 4,
    'Time': 5,
    'Brain': 6,
    'Echoes': 7,
    'Wearing': 8,
    'Sorrow': 9,
    'Hey': 10,
    'Shine': 11,  
}

#vertical bar plot of the classes distribution in y
plt.title('Classes distribution')
plt.bar(label_mapping.keys(), np.bincount(y), color = matplotlib.colormaps['Set2'].colors)
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Data preprocessing with cubic spline interpolation

# %% [markdown]
# Before the cubic spline interpolation

# %%
# plot the sequence of points in a randomly drawn sample from X
sample = random.randint(0, X.shape[0])

# create a figure with 6 subplots, one plot per each feature
fig, axs = plt.subplots(6, 1, figsize=(9, 13))
fig.suptitle('Sample ' + str(sample))
for i in range(6):
	axs[i].set_title('Feature ' + str(i))
	# add a dot at each point in the sequence
	axs[i].plot(X[sample, :, i], 'o-', color='blue', markersize=4)

plt.show()

# %% [markdown]
# Application of spline interpolation to create a spline with 108 new points

# %%
# add cubic spline interpolation between the data points of the sequence X[sample, :, i] and return the new set of points

from scipy import interpolate

# triple the number of points in the sequence to increase the resolution by a factor of 3
x_lin = np.linspace(0, 35, 36 * 3)

# new augmented dataset
X_spline = np.zeros((X.shape[0], x_lin.size, 6))
print(X_spline.shape)

for i in np.arange(X[:, 0, 0].size): # for each sample
	for j in np.arange(6): # for each feature
		# add a cubic spline interpolation between the data points of X[sample, :, 0]
		interpolation = interpolate.interp1d(np.arange(0, 36), X[i, :, j], kind='cubic', fill_value="extrapolate")
		X_spline[i, :, j] = interpolation(x_lin)
# Out:
# (2429, 108, 6)

# %% [markdown]
# Plot the new sequence of 108 points

# %%
# create a figure with 6 subplots, one plot per each feature
fig, axs = plt.subplots(6, 1, figsize=(9, 14))
fig.suptitle('Sample ' + str(sample))
for i in range(6):
	axs[i].set_title('Feature ' + str(i))
	# plots the given sequence of points without interpolation
	axs[i].plot(np.arange(0, 36), X[sample, :, i], 'o-', color='blue', markersize=4)

	x_lin = np.linspace(0, 35, 36 * 3)
	# plots the new set of points with cubic spline interpolation
	axs[i].plot(x_lin, X_spline[sample, :, i], "o-", color='red', markersize = 3, alpha = 0.7)

plt.show()

# %% [markdown]
#  Train-test split

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_spline, y, test_size=0.2, stratify=y)
print("training set : ", X_train.shape)
print("test set: ", X_test.shape)
# Out:
# training set :  (1943, 108, 6)
# test set:  (486, 108, 6)

# %% [markdown]
# Class weights computation

# %%
# Compute the class weights in order to balance loss during training
labels = np.unique(np.fromiter([t for t in y_train], np.int32))
class_weights = dict(enumerate(class_weight.compute_class_weight('balanced', classes=labels, y=y_train)))

# plot class weights with respect to the labels
plt.title('Class weights')
plt.bar(label_mapping.keys(), class_weights.values(), color = matplotlib.colormaps['Set2'].colors)
plt.xticks(rotation=90)
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# Application of Min Max Scaler to the dataset

# %%
features_num = X_train.shape[2]
print("features: ", features_num)

scalers = {}
scaling = False
if (scaling):
    for i in range(features_num):
        scalers[i] = MinMaxScaler()
        X_train[:, i, :] = scalers[i].fit_transform(X_train[:, i, :]) 

    for i in range(features_num):
        X_test[:, i, :] = scalers[i].transform(X_test[:, i, :])
# Out:
# features:  6

# %% [markdown]
# Categorical labels for the training and test data

# %%
# Convert the sparse labels to categorical values
y_train = tfk.utils.to_categorical(y_train)
y_test = tfk.utils.to_categorical(y_test)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1943, 12)
# (486, 12)

# %% [markdown]
# ## Build the models

# %% [markdown]
# Hyperparameters

# %%
input_shape = X_train.shape[1:]
print(input_shape)
classes = y_train.shape[-1]
batch_size = 128
epochs = 200
# Out:
# (108, 6)

# %% [markdown]
# Plot history of the training and the learning rate schedule

# %%
def plot_history(history):
	best_epoch = np.argmax(history['val_accuracy'])
	plt.figure(figsize=(17,4))
	plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
	plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.title('Categorical Crossentropy')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

	plt.figure(figsize=(17,4))
	plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
	plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.title('Accuracy')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

	plt.figure(figsize=(17,4))
	plt.title('Learning Rate Schedule')
	plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

# %% [markdown]
# Plot confusion matrix, F1 scores and displays model accuracy

# %%
def plot_statistics(predictions):	
	# Compute the confusion matrix
	cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

	# Compute the classification metrics
	accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
	precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	print('Accuracy:',accuracy.round(4))
	print('Precision:',precision.round(4))
	print('Recall:',recall.round(4))
	print('F1:',f1.round(4))
    
	# Plot the confusion matrix
	plt.figure(figsize=(7, 6))
	plt.title('Confusion matrix')
	sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()), annot=True, fmt="d")
	plt.ylabel('Predicted labels')
	plt.show()

	# horizontal bar plot of the f1 scores for each class
	plt.figure(figsize=(6,4))
	plt.barh(y=list(label_mapping.keys()), width=f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average=None))
	plt.title('F1 scores')
	plt.show()

# %% [markdown]
# #### Bidirectional Long Short Term Memory (BiLSTM) Neural Network

# %%
def build_BiLSTM_classifier(input_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    bilstm = tfkl.Bidirectional(tfkl.LSTM(512, return_sequences=True))(input_layer)
    bilstm = tfkl.Bidirectional(tfkl.LSTM(384, return_sequences=True))(bilstm)
    bilstm = tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=True))(bilstm)
    bilstm = tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=False))(bilstm)
    x = tfkl.Dropout(.5, seed=seed)(bilstm)

    # Classifier
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dropout(.3, seed=seed)(x)
    output_layer = tfkl.Dense(classes, activation='softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-4), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_BiLSTM_classifier(input_shape)
model.summary() #note double number of parameters (this is because we have a bidirectional lstm)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 108, 6)]          0
# _________________________________________________________________
# bidirectional_71 (Bidirectio (None, 108, 1024)         2125824
# _________________________________________________________________
# bidirectional_72 (Bidirectio (None, 108, 768)          4328448
# _________________________________________________________________
# bidirectional_73 (Bidirectio (None, 108, 512)          2099200
# _________________________________________________________________
# bidirectional_74 (Bidirectio (None, 512)               1574912
# _________________________________________________________________
# dropout_121 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_260 (Dense)            (None, 128)               65664
# _________________________________________________________________
# dense_261 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_262 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dropout_122 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_263 (Dense)            (None, 12)                1548
# =================================================================
# Total params: 10,228,620
# Trainable params: 10,228,620
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_test, y_test),
    #class_weight = class_weights,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=11, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.75, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 16/16 [==============================] - 16s 397ms/step - loss: 2.3948 - accuracy: 0.2301 - val_loss: 2.2385 - val_accuracy: 0.3580
# Epoch 2/200
# 16/16 [==============================] - 4s 229ms/step - loss: 2.1260 - accuracy: 0.3731 - val_loss: 1.9257 - val_accuracy: 0.4218
# Epoch 3/200
# 16/16 [==============================] - 4s 229ms/step - loss: 1.9022 - accuracy: 0.4164 - val_loss: 1.7152 - val_accuracy: 0.4547
# Epoch 4/200
# 16/16 [==============================] - 4s 230ms/step - loss: 1.7227 - accuracy: 0.4411 - val_loss: 1.5886 - val_accuracy: 0.4671
# Epoch 5/200
# 16/16 [==============================] - 4s 229ms/step - loss: 1.6224 - accuracy: 0.4642 - val_loss: 1.5255 - val_accuracy: 0.4897
# Epoch 6/200
# 16/16 [==============================] - 4s 229ms/step - loss: 1.5038 - accuracy: 0.4946 - val_loss: 1.4126 - val_accuracy: 0.5309
# Epoch 7/200
# 16/16 [==============================] - 4s 229ms/step - loss: 1.3676 - accuracy: 0.5471 - val_loss: 1.3048 - val_accuracy: 0.5638
# Epoch 8/200
# 16/16 [==============================] - 4s 230ms/step - loss: 1.2542 - accuracy: 0.5862 - val_loss: 1.2620 - val_accuracy: 0.5823
# Epoch 9/200
# 16/16 [==============================] - 4s 230ms/step - loss: 1.1527 - accuracy: 0.6361 - val_loss: 1.1964 - val_accuracy: 0.6008
# Epoch 10/200
# 16/16 [==============================] - 4s 230ms/step - loss: 1.0315 - accuracy: 0.6824 - val_loss: 1.2583 - val_accuracy: 0.5988
# Epoch 11/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.9401 - accuracy: 0.7138 - val_loss: 1.1766 - val_accuracy: 0.5967
# Epoch 12/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.8359 - accuracy: 0.7591 - val_loss: 1.2516 - val_accuracy: 0.5741
# Epoch 13/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.8339 - accuracy: 0.7416 - val_loss: 1.2127 - val_accuracy: 0.6317
# Epoch 14/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.7417 - accuracy: 0.7699 - val_loss: 1.1938 - val_accuracy: 0.6337
# Epoch 15/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.6754 - accuracy: 0.7993 - val_loss: 1.2049 - val_accuracy: 0.6296
# Epoch 16/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.6115 - accuracy: 0.8168 - val_loss: 1.2166 - val_accuracy: 0.6358
# Epoch 17/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.5523 - accuracy: 0.8389 - val_loss: 1.3483 - val_accuracy: 0.5967
# Epoch 18/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.5118 - accuracy: 0.8466 - val_loss: 1.2957 - val_accuracy: 0.6626
# Epoch 19/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.4440 - accuracy: 0.8724 - val_loss: 1.4638 - val_accuracy: 0.6091
# Epoch 20/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.4534 - accuracy: 0.8662 - val_loss: 1.4794 - val_accuracy: 0.6420
# Epoch 21/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.3646 - accuracy: 0.8868 - val_loss: 1.3479 - val_accuracy: 0.6543
# Epoch 22/200
# 16/16 [==============================] - 4s 231ms/step - loss: 0.3205 - accuracy: 0.8971 - val_loss: 1.4137 - val_accuracy: 0.6584
# Epoch 23/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.2899 - accuracy: 0.9094 - val_loss: 1.5974 - val_accuracy: 0.6399
# Epoch 24/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.2697 - accuracy: 0.9156 - val_loss: 1.5904 - val_accuracy: 0.6646
# Epoch 25/200
# 16/16 [==============================] - 4s 232ms/step - loss: 0.2429 - accuracy: 0.9207 - val_loss: 1.6493 - val_accuracy: 0.6461
# Epoch 26/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.2082 - accuracy: 0.9352 - val_loss: 1.6492 - val_accuracy: 0.6626
# Epoch 27/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.1971 - accuracy: 0.9398 - val_loss: 1.8709 - val_accuracy: 0.6317
# Epoch 28/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.2004 - accuracy: 0.9424 - val_loss: 1.6770 - val_accuracy: 0.6420
# Epoch 29/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.1701 - accuracy: 0.9475 - val_loss: 1.7148 - val_accuracy: 0.6708
# Epoch 30/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.1263 - accuracy: 0.9609 - val_loss: 1.6956 - val_accuracy: 0.6626
# Epoch 31/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.1248 - accuracy: 0.9588 - val_loss: 1.7563 - val_accuracy: 0.6811
# Epoch 32/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.1463 - accuracy: 0.9557 - val_loss: 2.0699 - val_accuracy: 0.6111
# Epoch 33/200
# 16/16 [==============================] - 4s 231ms/step - loss: 0.1870 - accuracy: 0.9449 - val_loss: 1.7316 - val_accuracy: 0.6420
# Epoch 34/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.1990 - accuracy: 0.9429 - val_loss: 1.9729 - val_accuracy: 0.6358
# Epoch 35/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.1470 - accuracy: 0.9490 - val_loss: 1.6037 - val_accuracy: 0.6481
# Epoch 36/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.1169 - accuracy: 0.9707 - val_loss: 1.9557 - val_accuracy: 0.6523
# Epoch 37/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0891 - accuracy: 0.9732 - val_loss: 1.8958 - val_accuracy: 0.6543
# Epoch 38/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0819 - accuracy: 0.9779 - val_loss: 1.9239 - val_accuracy: 0.6605
# Epoch 39/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0612 - accuracy: 0.9892 - val_loss: 1.9407 - val_accuracy: 0.6523
# Epoch 40/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.0487 - accuracy: 0.9897 - val_loss: 1.9672 - val_accuracy: 0.6605
# Epoch 41/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0427 - accuracy: 0.9918 - val_loss: 2.0698 - val_accuracy: 0.6667
# Epoch 42/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.0393 - accuracy: 0.9907 - val_loss: 2.0952 - val_accuracy: 0.6605

# %% [markdown]
# Bidirectional LSTM model evaluation

# %%
plot_history(history)

# Predict the test set with the LSTM
predictions = model.predict(X_test)

plot_statistics(predictions)
# Out:
# Accuracy: 0.6811
# Precision: 0.6395
# Recall: 0.546
# F1: 0.5758

# %% [markdown]
# Save bidirectional lstm model with accuracy in the name

# %%
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
if (accuracy > 0.7):
    model_name = "model_bilstm_" + str(accuracy.round(5))
    model.save(model_name)

# %% [markdown]
# #### 1D Convolutional Neural Network

# %%
def build_1DCNN_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    cnn = tfkl.Conv1D(512, 17, padding='same', activation='relu')(input_layer)
    cnn = tfkl.MaxPooling1D()(cnn)
    cnn = tfkl.Conv1D(384, 15, padding='same', activation='relu')(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)
    cnn = tfkl.Conv1D(384, 15, padding='same', activation='relu')(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)
    cnn = tfkl.Conv1D(256, 12, padding='same', activation='relu')(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)
    cnn = tfkl.Conv1D(256, 12, padding='same', activation='relu')(cnn)
    
    x = tfkl.GlobalAveragePooling1D()(cnn)
    #x = tfkl.Dropout(.3, seed=seed)(x)
    
    # Classifier
    x = tfkl.Dense(256, activation='relu')(x)
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dropout(.1, seed=seed)(x)
    # kernel_regularizer = tfk.regularizers.L2(1e-4)
    output_layer = tfkl.Dense(classes, activation='softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(3e-4), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_1DCNN_classifier(input_shape, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 108, 6)]          0
# _________________________________________________________________
# conv1d_221 (Conv1D)          (None, 108, 512)          52736
# _________________________________________________________________
# max_pooling1d_206 (MaxPoolin (None, 54, 512)           0
# _________________________________________________________________
# conv1d_222 (Conv1D)          (None, 54, 384)           2949504
# _________________________________________________________________
# max_pooling1d_207 (MaxPoolin (None, 27, 384)           0
# _________________________________________________________________
# conv1d_223 (Conv1D)          (None, 27, 384)           2212224
# _________________________________________________________________
# max_pooling1d_208 (MaxPoolin (None, 13, 384)           0
# _________________________________________________________________
# conv1d_224 (Conv1D)          (None, 13, 256)           1179904
# _________________________________________________________________
# max_pooling1d_209 (MaxPoolin (None, 6, 256)            0
# _________________________________________________________________
# conv1d_225 (Conv1D)          (None, 6, 256)            786688
# _________________________________________________________________
# global_average_pooling1d_57  (None, 256)               0
# _________________________________________________________________
# dense_280 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_281 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_282 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dropout_127 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_283 (Dense)            (None, 12)                1548
# =================================================================
# Total params: 7,297,804
# Trainable params: 7,297,804
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_test, y_test),
    #class_weight = class_weights,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 16/16 [==============================] - 2s 50ms/step - loss: 4.3620 - accuracy: 0.1127 - val_loss: 2.4168 - val_accuracy: 0.1667
# Epoch 2/200
# 16/16 [==============================] - 1s 33ms/step - loss: 2.4618 - accuracy: 0.2229 - val_loss: 2.4003 - val_accuracy: 0.2510
# Epoch 3/200
# 16/16 [==============================] - 1s 35ms/step - loss: 2.4541 - accuracy: 0.2604 - val_loss: 2.4020 - val_accuracy: 0.3251
# Epoch 4/200
# 16/16 [==============================] - 1s 33ms/step - loss: 2.3312 - accuracy: 0.3618 - val_loss: 2.3296 - val_accuracy: 0.3930
# Epoch 5/200
# 16/16 [==============================] - 1s 33ms/step - loss: 2.2959 - accuracy: 0.3829 - val_loss: 2.3969 - val_accuracy: 0.2840
# Epoch 6/200
# 16/16 [==============================] - 1s 36ms/step - loss: 2.3283 - accuracy: 0.3289 - val_loss: 2.3159 - val_accuracy: 0.3477
# Epoch 7/200
# 16/16 [==============================] - 1s 36ms/step - loss: 2.2455 - accuracy: 0.3917 - val_loss: 2.2035 - val_accuracy: 0.3827
# Epoch 8/200
# 16/16 [==============================] - 1s 34ms/step - loss: 2.1642 - accuracy: 0.4040 - val_loss: 2.1929 - val_accuracy: 0.3971
# Epoch 9/200
# 16/16 [==============================] - 1s 33ms/step - loss: 2.0963 - accuracy: 0.4040 - val_loss: 2.0888 - val_accuracy: 0.4259
# Epoch 10/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.9852 - accuracy: 0.4323 - val_loss: 2.0610 - val_accuracy: 0.4444
# Epoch 11/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.9683 - accuracy: 0.4380 - val_loss: 2.0477 - val_accuracy: 0.4259
# Epoch 12/200
# 16/16 [==============================] - 1s 38ms/step - loss: 1.8698 - accuracy: 0.4179 - val_loss: 2.0108 - val_accuracy: 0.4300
# Epoch 13/200
# 16/16 [==============================] - 1s 39ms/step - loss: 1.9045 - accuracy: 0.4297 - val_loss: 2.0097 - val_accuracy: 0.4588
# Epoch 14/200
# 16/16 [==============================] - 1s 37ms/step - loss: 1.7967 - accuracy: 0.4601 - val_loss: 1.7689 - val_accuracy: 0.4897
# Epoch 15/200
# 16/16 [==============================] - 1s 38ms/step - loss: 1.6301 - accuracy: 0.4822 - val_loss: 1.9449 - val_accuracy: 0.4198
# Epoch 16/200
# 16/16 [==============================] - 1s 34ms/step - loss: 1.7786 - accuracy: 0.4591 - val_loss: 1.7160 - val_accuracy: 0.4835
# Epoch 17/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.7172 - accuracy: 0.4771 - val_loss: 1.8873 - val_accuracy: 0.4691
# Epoch 18/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.7130 - accuracy: 0.4617 - val_loss: 1.7764 - val_accuracy: 0.4609
# Epoch 19/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.7123 - accuracy: 0.4637 - val_loss: 1.8182 - val_accuracy: 0.4506
# Epoch 20/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.6345 - accuracy: 0.4673 - val_loss: 1.7179 - val_accuracy: 0.4280
# Epoch 21/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.5477 - accuracy: 0.5023 - val_loss: 1.8585 - val_accuracy: 0.4835
# Epoch 22/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.4574 - accuracy: 0.5183 - val_loss: 1.8585 - val_accuracy: 0.5103
# Epoch 23/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.3699 - accuracy: 0.5574 - val_loss: 1.7362 - val_accuracy: 0.5576
# Epoch 24/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.3306 - accuracy: 0.5625 - val_loss: 1.6724 - val_accuracy: 0.5432
# Epoch 25/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.3200 - accuracy: 0.5831 - val_loss: 1.8407 - val_accuracy: 0.5556
# Epoch 26/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.4459 - accuracy: 0.5589 - val_loss: 1.8292 - val_accuracy: 0.4794
# Epoch 27/200
# 16/16 [==============================] - 1s 34ms/step - loss: 1.3029 - accuracy: 0.5867 - val_loss: 1.7525 - val_accuracy: 0.5638
# Epoch 28/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.1970 - accuracy: 0.6186 - val_loss: 1.9689 - val_accuracy: 0.5782
# Epoch 29/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.3870 - accuracy: 0.5775 - val_loss: 2.6662 - val_accuracy: 0.5556
# Epoch 30/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.2886 - accuracy: 0.6022 - val_loss: 1.9388 - val_accuracy: 0.5658
# Epoch 31/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.1842 - accuracy: 0.6233 - val_loss: 2.2594 - val_accuracy: 0.5926
# Epoch 32/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.2352 - accuracy: 0.6351 - val_loss: 2.0220 - val_accuracy: 0.5926
# Epoch 33/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.1768 - accuracy: 0.6351 - val_loss: 1.9060 - val_accuracy: 0.5844
# Epoch 34/200
# 16/16 [==============================] - 1s 33ms/step - loss: 1.1874 - accuracy: 0.6243 - val_loss: 1.4752 - val_accuracy: 0.5823
# Epoch 35/200
# 16/16 [==============================] - 1s 36ms/step - loss: 1.1444 - accuracy: 0.6320 - val_loss: 1.8665 - val_accuracy: 0.6317
# Epoch 36/200
# 16/16 [==============================] - 1s 36ms/step - loss: 1.0041 - accuracy: 0.6886 - val_loss: 1.6169 - val_accuracy: 0.6523
# Epoch 37/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.9912 - accuracy: 0.6953 - val_loss: 1.6878 - val_accuracy: 0.6296
# Epoch 38/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.9870 - accuracy: 0.6912 - val_loss: 1.4828 - val_accuracy: 0.6502
# Epoch 39/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.9136 - accuracy: 0.7036 - val_loss: 1.7665 - val_accuracy: 0.6420
# Epoch 40/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.8627 - accuracy: 0.7221 - val_loss: 1.3195 - val_accuracy: 0.6235
# Epoch 41/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.8686 - accuracy: 0.7303 - val_loss: 1.9890 - val_accuracy: 0.6420
# Epoch 42/200
# 16/16 [==============================] - 1s 35ms/step - loss: 1.0015 - accuracy: 0.7118 - val_loss: 1.8640 - val_accuracy: 0.6481
# Epoch 43/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.8943 - accuracy: 0.7231 - val_loss: 1.7337 - val_accuracy: 0.6399
# Epoch 44/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.8207 - accuracy: 0.7283 - val_loss: 1.6548 - val_accuracy: 0.6543
# Epoch 45/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.7511 - accuracy: 0.7566 - val_loss: 1.5753 - val_accuracy: 0.6687
# Epoch 46/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.6794 - accuracy: 0.7818 - val_loss: 1.6414 - val_accuracy: 0.6770
# Epoch 47/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.6552 - accuracy: 0.7864 - val_loss: 1.7022 - val_accuracy: 0.6852
# Epoch 48/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.6226 - accuracy: 0.7962 - val_loss: 1.7641 - val_accuracy: 0.6749
# Epoch 49/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5963 - accuracy: 0.7998 - val_loss: 1.6989 - val_accuracy: 0.6872
# Epoch 50/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5697 - accuracy: 0.8204 - val_loss: 1.9426 - val_accuracy: 0.6790
# Epoch 51/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.6053 - accuracy: 0.8101 - val_loss: 1.7181 - val_accuracy: 0.6831
# Epoch 52/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5692 - accuracy: 0.8106 - val_loss: 2.0388 - val_accuracy: 0.6872
# Epoch 53/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.5535 - accuracy: 0.8188 - val_loss: 1.6688 - val_accuracy: 0.6790
# Epoch 54/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5871 - accuracy: 0.8080 - val_loss: 1.6680 - val_accuracy: 0.6893
# Epoch 55/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.5351 - accuracy: 0.8230 - val_loss: 1.7809 - val_accuracy: 0.6955
# Epoch 56/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.5068 - accuracy: 0.8410 - val_loss: 1.8738 - val_accuracy: 0.6790
# Epoch 57/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.4616 - accuracy: 0.8513 - val_loss: 1.7903 - val_accuracy: 0.6934
# Epoch 58/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.4865 - accuracy: 0.8477 - val_loss: 1.8496 - val_accuracy: 0.6934
# Epoch 59/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.4302 - accuracy: 0.8590 - val_loss: 1.9583 - val_accuracy: 0.6934
# Epoch 60/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.4033 - accuracy: 0.8626 - val_loss: 2.5400 - val_accuracy: 0.6975
# Epoch 61/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.4111 - accuracy: 0.8770 - val_loss: 2.1842 - val_accuracy: 0.6687
# Epoch 62/200
# 16/16 [==============================] - 1s 36ms/step - loss: 0.4606 - accuracy: 0.8477 - val_loss: 2.0338 - val_accuracy: 0.6667
# Epoch 63/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5407 - accuracy: 0.8302 - val_loss: 1.4878 - val_accuracy: 0.6687
# Epoch 64/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5152 - accuracy: 0.8405 - val_loss: 2.4081 - val_accuracy: 0.6502
# Epoch 65/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.6218 - accuracy: 0.7946 - val_loss: 2.5157 - val_accuracy: 0.6523
# Epoch 66/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.4658 - accuracy: 0.8492 - val_loss: 1.8448 - val_accuracy: 0.6872
# Epoch 67/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.4186 - accuracy: 0.8703 - val_loss: 1.9937 - val_accuracy: 0.6914
# Epoch 68/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3811 - accuracy: 0.8765 - val_loss: 2.1968 - val_accuracy: 0.6728
# Epoch 69/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.3689 - accuracy: 0.8842 - val_loss: 2.3613 - val_accuracy: 0.6996
# Epoch 70/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.3692 - accuracy: 0.8868 - val_loss: 2.5709 - val_accuracy: 0.7037
# Epoch 71/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.3403 - accuracy: 0.8924 - val_loss: 2.6655 - val_accuracy: 0.7078
# Epoch 72/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3219 - accuracy: 0.8950 - val_loss: 2.6066 - val_accuracy: 0.6996
# Epoch 73/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.3046 - accuracy: 0.9053 - val_loss: 2.7668 - val_accuracy: 0.6996
# Epoch 74/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3026 - accuracy: 0.9079 - val_loss: 2.8197 - val_accuracy: 0.6996
# Epoch 75/200
# 16/16 [==============================] - 1s 39ms/step - loss: 0.2862 - accuracy: 0.9104 - val_loss: 2.6803 - val_accuracy: 0.6893
# Epoch 76/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2736 - accuracy: 0.9166 - val_loss: 2.8532 - val_accuracy: 0.6872
# Epoch 77/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2596 - accuracy: 0.9197 - val_loss: 2.9922 - val_accuracy: 0.6975
# Epoch 78/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2519 - accuracy: 0.9218 - val_loss: 3.0239 - val_accuracy: 0.6893
# Epoch 79/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2592 - accuracy: 0.9166 - val_loss: 2.5869 - val_accuracy: 0.6975
# Epoch 80/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2573 - accuracy: 0.9218 - val_loss: 2.5748 - val_accuracy: 0.7078
# Epoch 81/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2512 - accuracy: 0.9187 - val_loss: 2.7412 - val_accuracy: 0.6934
# Epoch 82/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2424 - accuracy: 0.9207 - val_loss: 2.8563 - val_accuracy: 0.7058
# Epoch 83/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2491 - accuracy: 0.9259 - val_loss: 2.9468 - val_accuracy: 0.6934
# Epoch 84/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2390 - accuracy: 0.9279 - val_loss: 2.9412 - val_accuracy: 0.6852
# Epoch 85/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2346 - accuracy: 0.9310 - val_loss: 2.9950 - val_accuracy: 0.6955
# Epoch 86/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2357 - accuracy: 0.9243 - val_loss: 3.0499 - val_accuracy: 0.7037
# Epoch 87/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2301 - accuracy: 0.9279 - val_loss: 3.0569 - val_accuracy: 0.6975
# Epoch 88/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2475 - accuracy: 0.9305 - val_loss: 3.0504 - val_accuracy: 0.7037
# Epoch 89/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2260 - accuracy: 0.9331 - val_loss: 3.1050 - val_accuracy: 0.6996
# Epoch 90/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2203 - accuracy: 0.9346 - val_loss: 3.1090 - val_accuracy: 0.6955
# Epoch 91/200
# 16/16 [==============================] - 1s 35ms/step - loss: 0.2230 - accuracy: 0.9352 - val_loss: 3.2976 - val_accuracy: 0.6996

# %% [markdown]
# Convolution in 1D model evaluation

# %%
plot_history(history)

# Predict the test set with the LSTM
predictions = model.predict(X_test)

plot_statistics(predictions)
# Out:
# Accuracy: 0.7078
# Precision: 0.6996
# Recall: 0.5419
# F1: 0.5682

# %%
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
if (accuracy > 0.7):
    model_name = "model_1dcnn_" + str(accuracy.round(5))
    model.save(model_name)
