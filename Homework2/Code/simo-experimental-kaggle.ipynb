# %% [markdown]
# ### Import libraries

# %%
#!rm -r /kaggle/working/model_vanilla_*
#!rm -r /kaggle/working/model_bilstm_0.63* /kaggle/working/model_bilstm_0.64* /kaggle/working/model_bilstm_0.65* /kaggle/working/model_bilstm_0.66*
#!rm -r /kaggle/working/model_bilstm_0.61* /kaggle/working/model_1dcnn_0.54321/
#!rm -r /kaggle/working/model_1dcnn_0.41564/ /kaggle/working/model_1dcnn_0.66461/ /kaggle/working/model_1dcnn_0.63786/

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)

print(tf.config.list_physical_devices())
# Out:
# 2.6.4
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Set seed for reproducibility

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
#  # Load the training dataset

# %%
path = "/kaggle/input/competition2/"
# Load the .npy file
X = np.load(path + "x_train.npy")
y = np.load(path + "y_train.npy")

print(X.shape, X.dtype, sep=", ")
print(y.shape, y.dtype, sep=", ")
# Out:
# (2429, 36, 6), float64
# (2429,), int32

# %% [markdown]
# Plotting the classes distributions

# %%
# Map classes STRINGS to integers
label_mapping = {
    'Wish': 0,
    'Another': 1,
    'Comfortably': 2,
    'Money': 3,
    'Breathe': 4,
    'Time': 5,
    'Brain': 6,
    'Echoes': 7,
    'Wearing': 8,
    'Sorrow': 9,
    'Hey': 10,
    'Shine': 11,  
}

#vertical bar plot of the classes distribution in y
plt.title('Classes distribution')
plt.bar(label_mapping.keys(), np.bincount(y), color = matplotlib.colormaps['Set2'].colors)
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Data preprocessing with cubic spline interpolation

# %% [markdown]
# Before the cubic spline interpolation

# %%
# plot the sequence of points in a randomly drawn sample from X
sample = random.randint(0, X.shape[0])

# create a figure with 6 subplots, one plot per each feature
fig, axs = plt.subplots(6, 1, figsize=(9, 13))
fig.suptitle('Sample ' + str(sample))
for i in range(6):
	axs[i].set_title('Feature ' + str(i))
	# add a dot at each point in the sequence
	axs[i].plot(X[sample, :, i], 'o-', color='blue', markersize=4)

plt.show()

# %% [markdown]
# Application of spline interpolation to create a spline with 108 new points

# %%
# add cubic spline interpolation between the data points of the sequence X[sample, :, i] and return the new set of points

from scipy import interpolate

# triple the number of points in the sequence to increase the resolution by a factor of 3
x_lin = np.linspace(0, 35, 36 * 3)

# new augmented dataset
X_spline = np.zeros((X.shape[0], x_lin.size, 6))
print(X_spline.shape)

for i in np.arange(X[:, 0, 0].size): # for each sample
	for j in np.arange(6): # for each feature
		# add a cubic spline interpolation between the data points of X[sample, :, 0]
		interpolation = interpolate.interp1d(np.arange(0, 36), X[i, :, j], kind='cubic', fill_value="extrapolate")
		X_spline[i, :, j] = interpolation(x_lin)
# Out:
# (2429, 108, 6)

# %% [markdown]
# Plot the new sequence of 108 points

# %%
# create a figure with 6 subplots, one plot per each feature
fig, axs = plt.subplots(6, 1, figsize=(9, 14))
fig.suptitle('Sample ' + str(sample))
for i in range(6):
	axs[i].set_title('Feature ' + str(i))
	# plots the given sequence of points without interpolation
	axs[i].plot(np.arange(0, 36), X[sample, :, i], 'o-', color='blue', markersize=4)

	x_lin = np.linspace(0, 35, 36 * 3)
	# plots the new set of points with cubic spline interpolation
	axs[i].plot(x_lin, X_spline[sample, :, i], "o-", color='red', markersize = 3, alpha = 0.7)

plt.show()

# %% [markdown]
#  Train-test split

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_spline, y, test_size=0.2, stratify=y)
print("training set : ", X_train.shape)
print("test set: ", X_test.shape)
# Out:
# training set :  (1943, 108, 6)
# test set:  (486, 108, 6)

# %% [markdown]
# Class weights computation

# %%
# Compute the class weights in order to balance loss during training
labels = np.unique(np.fromiter([t for t in y_train], np.int32))
class_weights = dict(enumerate(class_weight.compute_class_weight('balanced', classes=labels, y=y_train)))

# plot class weights with respect to the labels
plt.title('Class weights')
plt.bar(label_mapping.keys(), class_weights.values(), color = matplotlib.colormaps['Set2'].colors)
plt.xticks(rotation=90)
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# Application of Min Max Scaler to the dataset

# %%
features_num = X_train.shape[2]
print("features: ", features_num)

scalers = {}
scaling = False
if (scaling):
    for i in range(features_num):
        scalers[i] = MinMaxScaler()
        X_train[:, i, :] = scalers[i].fit_transform(X_train[:, i, :]) 

    for i in range(features_num):
        X_test[:, i, :] = scalers[i].transform(X_test[:, i, :])
# Out:
# features:  6

# %% [markdown]
# Categorical labels for the training and test data

# %%
# Convert the sparse labels to categorical values
y_train = tfk.utils.to_categorical(y_train)
y_test = tfk.utils.to_categorical(y_test)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1943, 12)
# (486, 12)

# %% [markdown]
# ## Build the models

# %% [markdown]
# Hyperparameters

# %%
input_shape = X_train.shape[1:]
print(input_shape)
classes = y_train.shape[-1]
batch_size = 128
epochs = 200
# Out:
# (108, 6)

# %% [markdown]
# Plot history of the training and the learning rate schedule

# %%
def plot_history(history):
	best_epoch = np.argmax(history['val_accuracy'])
	plt.figure(figsize=(17,4))
	plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
	plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.title('Categorical Crossentropy')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

	plt.figure(figsize=(17,4))
	plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
	plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.title('Accuracy')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

	plt.figure(figsize=(17,4))
	plt.title('Learning Rate Schedule')
	plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

# %% [markdown]
# Plot confusion matrix, F1 scores and displays model accuracy

# %%
def plot_statistics(predictions):	
	# Compute the confusion matrix
	cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

	# Compute the classification metrics
	accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
	precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	print('Accuracy:',accuracy.round(4))
	print('Precision:',precision.round(4))
	print('Recall:',recall.round(4))
	print('F1:',f1.round(4))
    
	# Plot the confusion matrix
	plt.figure(figsize=(7, 6))
	plt.title('Confusion matrix')
	sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()), annot=True, fmt="d")
	plt.ylabel('Predicted labels')
	plt.show()

	# horizontal bar plot of the f1 scores for each class
	plt.figure(figsize=(6,4))
	plt.barh(y=list(label_mapping.keys()), width=f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average=None))
	plt.title('F1 scores')
	plt.show()

# %% [markdown]
# #### Bidirectional Long Short Term Memory (BiLSTM) Neural Network

# %%
def build_BiLSTM_classifier(input_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    bilstm = tfkl.Bidirectional(tfkl.LSTM(512, return_sequences=True))(input_layer)
    bilstm = tfkl.Bidirectional(tfkl.LSTM(384, return_sequences=True))(bilstm)
    bilstm = tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=True))(bilstm)
    bilstm = tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=False))(bilstm)
    x = tfkl.Dropout(.5, seed=seed)(bilstm)

    # Classifier
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dropout(.3, seed=seed)(x)
    output_layer = tfkl.Dense(classes, activation='softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(1e-4), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_BiLSTM_classifier(input_shape)
model.summary() #note double number of parameters (this is because we have a bidirectional lstm)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 108, 6)]          0
# _________________________________________________________________
# bidirectional_71 (Bidirectio (None, 108, 1024)         2125824
# _________________________________________________________________
# bidirectional_72 (Bidirectio (None, 108, 768)          4328448
# _________________________________________________________________
# bidirectional_73 (Bidirectio (None, 108, 512)          2099200
# _________________________________________________________________
# bidirectional_74 (Bidirectio (None, 512)               1574912
# _________________________________________________________________
# dropout_121 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_260 (Dense)            (None, 128)               65664
# _________________________________________________________________
# dense_261 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_262 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dropout_122 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_263 (Dense)            (None, 12)                1548
# =================================================================
# Total params: 10,228,620
# Trainable params: 10,228,620
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_test, y_test),
    #class_weight = class_weights,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=11, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.75, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 16/16 [==============================] - 16s 397ms/step - loss: 2.3948 - accuracy: 0.2301 - val_loss: 2.2385 - val_accuracy: 0.3580
# Epoch 2/200
# 16/16 [==============================] - 4s 229ms/step - loss: 2.1260 - accuracy: 0.3731 - val_loss: 1.9257 - val_accuracy: 0.4218
# Epoch 3/200
# 16/16 [==============================] - 4s 229ms/step - loss: 1.9022 - accuracy: 0.4164 - val_loss: 1.7152 - val_accuracy: 0.4547
# Epoch 4/200
# 16/16 [==============================] - 4s 230ms/step - loss: 1.7227 - accuracy: 0.4411 - val_loss: 1.5886 - val_accuracy: 0.4671
# Epoch 5/200
# 16/16 [==============================] - 4s 229ms/step - loss: 1
200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.1470 - accuracy: 0.9490 - val_loss: 1.6037 - val_accuracy: 0.6481
# Epoch 36/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.1169 - accuracy: 0.9707 - val_loss: 1.9557 - val_accuracy: 0.6523
# Epoch 37/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0891 - accuracy: 0.9732 - val_loss: 1.8958 - val_accuracy: 0.6543
# Epoch 38/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0819 - accuracy: 0.9779 - val_loss: 1.9239 - val_accuracy: 0.6605
# Epoch 39/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0612 - accuracy: 0.9892 - val_loss: 1.9407 - val_accuracy: 0.6523
# Epoch 40/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.0487 - accuracy: 0.9897 - val_loss: 1.9672 - val_accuracy: 0.6605
# Epoch 41/200
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0427 - accuracy: 0.9918 - val_loss: 2.0698 - val_accuracy: 0.6667
# Epoch 42/200
# 16/16 [==============================] - 4s 230ms/step - loss: 0.0393 - accuracy: 0.9907 - val_loss: 2.0952 - val_accuracy: 0.6605

# %% [markdown]
# Bidirectional LSTM model evaluation

# %%
plot_history(history)

# Predict the test set with the LSTM
predictions = model.predict(X_test)

plot_statistics(predictions)
# Out:
# Accuracy: 0.6811
# Precision: 0.6395
# Recall: 0.546
# F1: 0.5758

# %% [markdown]
# Save bidirectional lstm model with accuracy in the name

# %%
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
if (accuracy > 0.7):
    model_name = "model_bilstm_" + str(accuracy.round(5))
    model.save(model_name)

# %% [markdown]
# #### 1D Convolutional Neural Network

# %%
def build_1DCNN_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    cnn = tfkl.Conv1D(512, 12, padding='same', activation='relu')(input_layer)
    cnn = tfkl.MaxPooling1D()(cnn)
    cnn = tfkl.Conv1D(384, 12, padding='same', activation='relu')(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)
    cnn = tfkl.Conv1D(384, 10, padding='same', activation='relu')(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)
    cnn = tfkl.Conv1D(256, 10, padding='same', activation='relu')(cnn)
    cnn = tfkl.MaxPooling1D()(cnn)
    cnn = tfkl.Conv1D(256, 7, padding='same', activation='relu')(cnn)
    
    x = tfkl.GlobalAveragePooling1D()(cnn)
    #x = tfkl.Dropout(.3, seed=seed)(x)
    
    # Classifier
    x = tfkl.Dense(256, activation='relu')(x)
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dense(128, activation='relu')(x)
    x = tfkl.Dropout(.1, seed=seed)(x)
    # kernel_regularizer = tfk.regularizers.L2(1e-4)
    output_layer = tfkl.Dense(classes, activation='softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(3e-4), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_1DCNN_classifier(input_shape, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 108, 6)]          0
# _________________________________________________________________
# conv1d_236 (Conv1D)          (None, 108, 512)          37376
# _________________________________________________________________
# max_pooling1d_218 (MaxPoolin (None, 54, 512)           0
# _________________________________________________________________
# conv1d_237 (Conv1D)          (None, 54, 384)           2359680
# _________________________________________________________________
# max_pooling1d_219 (MaxPoolin (None, 27, 384)           0
# _________________________________________________________________
# conv1d_238 (Conv1D)          (None, 27, 384)           1474944
# _________________________________________________________________
# max_pooling1d_220 (MaxPoolin (None, 13, 384)           0
# _________________________________________________________________
# conv1d_239 (Conv1D)          (None, 13, 256)           983296
# _________________________________________________________________
# max_pooling1d_221 (MaxPoolin (None, 6, 256)            0
# _________________________________________________________________
# conv1d_240 (Conv1D)          (None, 6, 256)            459008
# _________________________________________________________________
# global_average_pooling1d_60  (None, 256)               0
# _________________________________________________________________
# dense_292 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_293 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dense_294 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_295 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dropout_130 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_296 (Dense)            (None, 12)                1548
# =================================================================
# Total params: 5,447,564
# Trainable params: 5,447,564
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_test, y_test),
    #class_weight = class_weights,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 16/16 [==============================] - 2s 46ms/step - loss: 3.8634 - accuracy: 0.1343 - val_loss: 2.4731 - val_accuracy: 0.2243
# Epoch 2/200
# 16/16 [==============================] - 1s 33ms/step - loss: 2.4647 - accuracy: 0.2841 - val_loss: 2.3442 - val_accuracy: 0.3395
# Epoch 3/200
# 16/16 [==============================] - 0s 30ms/step - loss: 2.4017 - accuracy: 0.3356 - val_loss: 2.3403 - val_accuracy: 0.3560
# Epoch 4/200
# 16/16 [==============================] - 1s 33ms/step - loss: 2
200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.4987 - accuracy: 0.8302 - val_loss: 2.0094 - val_accuracy: 0.6811
# Epoch 62/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.4459 - accuracy: 0.8451 - val_loss: 2.2733 - val_accuracy: 0.6893
# Epoch 63/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.4104 - accuracy: 0.8667 - val_loss: 2.1612 - val_accuracy: 0.6852
# Epoch 64/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.4372 - accuracy: 0.8626 - val_loss: 2.0359 - val_accuracy: 0.6605
# Epoch 65/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3981 - accuracy: 0.8724 - val_loss: 2.0474 - val_accuracy: 0.6975
# Epoch 66/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3752 - accuracy: 0.8770 - val_loss: 2.2195 - val_accuracy: 0.7037
# Epoch 67/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3557 - accuracy: 0.8806 - val_loss: 2.2352 - val_accuracy: 0.6975
# Epoch 68/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3551 - accuracy: 0.8837 - val_loss: 2.3808 - val_accuracy: 0.6975
# Epoch 69/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3431 - accuracy: 0.8868 - val_loss: 2.3935 - val_accuracy: 0.7058
# Epoch 70/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.3280 - accuracy: 0.8924 - val_loss: 2.4174 - val_accuracy: 0.6996
# Epoch 71/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.3218 - accuracy: 0.8945 - val_loss: 2.4713 - val_accuracy: 0.7037
# Epoch 72/200
# 16/16 [==============================] - 1s 37ms/step - loss: 0.3108 - accuracy: 0.8976 - val_loss: 2.4584 - val_accuracy: 0.6955
# Epoch 73/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2978 - accuracy: 0.9022 - val_loss: 2.6872 - val_accuracy: 0.6852
# Epoch 74/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2990 - accuracy: 0.9012 - val_loss: 2.7042 - val_accuracy: 0.6914
# Epoch 75/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2945 - accuracy: 0.9038 - val_loss: 2.5152 - val_accuracy: 0.7078
# Epoch 76/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2797 - accuracy: 0.9104 - val_loss: 2.5895 - val_accuracy: 0.7058
# Epoch 77/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2741 - accuracy: 0.9120 - val_loss: 2.7465 - val_accuracy: 0.7016
# Epoch 78/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2656 - accuracy: 0.9192 - val_loss: 2.6589 - val_accuracy: 0.7037
# Epoch 79/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2608 - accuracy: 0.9161 - val_loss: 2.7374 - val_accuracy: 0.6975
# Epoch 80/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2669 - accuracy: 0.9161 - val_loss: 2.8542 - val_accuracy: 0.6996
# Epoch 81/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2887 - accuracy: 0.9063 - val_loss: 2.6329 - val_accuracy: 0.6914
# Epoch 82/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2906 - accuracy: 0.9089 - val_loss: 2.7147 - val_accuracy: 0.7016
# Epoch 83/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2662 - accuracy: 0.9192 - val_loss: 2.7837 - val_accuracy: 0.7016
# Epoch 84/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2638 - accuracy: 0.9197 - val_loss: 2.7013 - val_accuracy: 0.7099
# Epoch 85/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2521 - accuracy: 0.9202 - val_loss: 2.8334 - val_accuracy: 0.7016
# Epoch 86/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2503 - accuracy: 0.9213 - val_loss: 2.8030 - val_accuracy: 0.7037
# Epoch 87/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2428 - accuracy: 0.9238 - val_loss: 2.8390 - val_accuracy: 0.7016
# Epoch 88/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2446 - accuracy: 0.9202 - val_loss: 2.8969 - val_accuracy: 0.7016
# Epoch 89/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2479 - accuracy: 0.9202 - val_loss: 2.9472 - val_accuracy: 0.7016
# Epoch 90/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2443 - accuracy: 0.9218 - val_loss: 2.7857 - val_accuracy: 0.7058
# Epoch 91/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2337 - accuracy: 0.9295 - val_loss: 2.8603 - val_accuracy: 0.7016
# Epoch 92/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2320 - accuracy: 0.9300 - val_loss: 2.7636 - val_accuracy: 0.6975
# Epoch 93/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2377 - accuracy: 0.9233 - val_loss: 2.8911 - val_accuracy: 0.7016
# Epoch 94/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2315 - accuracy: 0.9233 - val_loss: 2.8599 - val_accuracy: 0.7078
# Epoch 95/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2233 - accuracy: 0.9290 - val_loss: 2.8482 - val_accuracy: 0.6975
# Epoch 96/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2331 - accuracy: 0.9269 - val_loss: 2.8539 - val_accuracy: 0.6996
# Epoch 97/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2361 - accuracy: 0.9274 - val_loss: 2.9447 - val_accuracy: 0.6955
# Epoch 98/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2297 - accuracy: 0.9295 - val_loss: 2.8553 - val_accuracy: 0.7016
# Epoch 99/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2324 - accuracy: 0.9259 - val_loss: 2.8900 - val_accuracy: 0.7058
# Epoch 100/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2234 - accuracy: 0.9315 - val_loss: 2.9310 - val_accuracy: 0.7078
# Epoch 101/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2242 - accuracy: 0.9315 - val_loss: 2.8954 - val_accuracy: 0.7160
# Epoch 102/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2214 - accuracy: 0.9269 - val_loss: 2.9762 - val_accuracy: 0.7099
# Epoch 103/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2131 - accuracy: 0.9305 - val_loss: 2.9608 - val_accuracy: 0.7078
# Epoch 104/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2137 - accuracy: 0.9362 - val_loss: 2.9422 - val_accuracy: 0.7078
# Epoch 105/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2153 - accuracy: 0.9352 - val_loss: 3.0414 - val_accuracy: 0.7099
# Epoch 106/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2069 - accuracy: 0.9331 - val_loss: 3.0089 - val_accuracy: 0.7016
# Epoch 107/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2083 - accuracy: 0.9367 - val_loss: 3.0301 - val_accuracy: 0.7058
# Epoch 108/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2084 - accuracy: 0.9331 - val_loss: 3.0777 - val_accuracy: 0.7016
# Epoch 109/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2055 - accuracy: 0.9352 - val_loss: 3.0026 - val_accuracy: 0.7058
# Epoch 110/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2066 - accuracy: 0.9341 - val_loss: 3.0027 - val_accuracy: 0.7037
# Epoch 111/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1984 - accuracy: 0.9382 - val_loss: 3.0477 - val_accuracy: 0.7078
# Epoch 112/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1948 - accuracy: 0.9326 - val_loss: 3.0689 - val_accuracy: 0.7058
# Epoch 113/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.2011 - accuracy: 0.9393 - val_loss: 3.0132 - val_accuracy: 0.7058
# Epoch 114/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2006 - accuracy: 0.9393 - val_loss: 2.8456 - val_accuracy: 0.7037
# Epoch 115/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1961 - accuracy: 0.9413 - val_loss: 2.8559 - val_accuracy: 0.7058
# Epoch 116/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1924 - accuracy: 0.9408 - val_loss: 2.8035 - val_accuracy: 0.6975
# Epoch 117/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2544 - accuracy: 0.9202 - val_loss: 3.0110 - val_accuracy: 0.7099
# Epoch 118/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2470 - accuracy: 0.9243 - val_loss: 2.8633 - val_accuracy: 0.7037
# Epoch 119/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.2094 - accuracy: 0.9388 - val_loss: 2.8819 - val_accuracy: 0.7037
# Epoch 120/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1945 - accuracy: 0.9429 - val_loss: 3.1090 - val_accuracy: 0.7099
# Epoch 121/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2007 - accuracy: 0.9352 - val_loss: 3.2405 - val_accuracy: 0.7078

# %% [markdown]
# Convolution in 1D model evaluation

# %%
plot_history(history)

# Predict the test set with the LSTM
predictions = model.predict(X_test)

plot_statistics(predictions)
# Out:
# Accuracy: 0.716
# Precision: 0.7252
# Recall: 0.5823
# F1: 0.6165

# %%
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
if (accuracy > 0.7):
    model_name = "model_1dcnn_" + str(accuracy.round(5))
    model.save(model_name)
