# %% [markdown]
# ### Import libraries

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight, shuffle
from tensorflow.keras import mixed_precision
import warnings
import logging

# Enable mixed precision
mixed_precision.set_global_policy('mixed_float16')

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)

print(tf.config.list_physical_devices())

import shutil
from IPython.display import FileLink
# Out:
# 2.6.4
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Set seed for reproducibility

# %%
# Random seed for reproducibility
seed = 102

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# Flags

# %%
use_cross_valid = True 
standard_training = True #Performs standard training, saving the model
use_splines_std_training = True #Applies during the standard training the splines augmentation
scaling = True #applies scaling to the standard training

# %% [markdown]
#  ## Load the training dataset

# %%
path = "/kaggle/input/training/"
# Load the .npy file
X = np.load(path + "x_train.npy")
y = np.load(path + "y_train.npy")

# Convert to float32 for less precision and better performance
X = X.astype(np.float32)
y = y.astype(np.int32)

# shuffle X, y
X, y = shuffle(X, y, random_state=seed)

print(X.shape, X.dtype, sep=", ")   
print(y.shape, y.dtype, sep=", ")
# Out:
# (2429, 36, 6), float32
# (2429,), int32

# %% [markdown]
# Training - Validation Split

# %%
if standard_training:
    # Split the data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15,shuffle=True, random_state=seed, stratify=y)
    print("training set : ", X_train.shape)
    print("test set: ", X_test.shape)
# Out:
# training set :  (2064, 36, 6)
# test set:  (365, 36, 6)

# %% [markdown]
# Plotting the classes distributions

# %%
# Map classes STRINGS to integers
label_mapping = {
    'Wish': 0,
    'Another': 1,
    'Comfortably': 2,
    'Money': 3,
    'Breathe': 4,
    'Time': 5,
    'Brain': 6,
    'Echoes': 7,
    'Wearing': 8,
    'Sorrow': 9,
    'Hey': 10,
    'Shine': 11,  
}

#vertical bar plot of the classes distribution in y
plt.title('Classes distribution')
plt.bar(label_mapping.keys(), np.bincount(y), color = matplotlib.colormaps['Set2'].colors)
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Class weights computation

# %%
# Compute the class weights in order to balance loss during training
labels = np.unique(np.fromiter([t for t in y], np.int32))
class_weights = dict(enumerate(class_weight.compute_class_weight('balanced', classes=labels, y=y)))

# plot class weights with respect to the labels
plt.title('Class weights')
plt.bar(label_mapping.keys(), class_weights.values(), color = matplotlib.colormaps['Set2'].colors)
plt.xticks(rotation=90)
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# ## Data preprocessing with cubic interpolation between data points for increasing resolution

# %%
def spline_augment_print(X_train,y_train,interpolation_multiplier = 3,augment_std = 0.02):
    # plot the sequence of points in a randomly drawn sample from X
    sample = random.randint(0, X_train.shape[0])

    # create a figure with 6 subplots, one plot per each feature
    fig, axs = plt.subplots(6, 1, figsize=(9, 13))
    fig.suptitle('Sample ' + str(sample))
    for i in range(6):
        axs[i].set_title('Feature ' + str(i))
        # add a dot at each point in the sequence
        axs[i].plot(X_train[sample, :, i], 'o-', color='blue', markersize=4)

    plt.show()
    
    from scipy import interpolate

    # triple the number of points in the sequence to increase the resolution by a factor of 3
    x_lin = np.linspace(0, 35, 36 * interpolation_multiplier)

    # new augmented dataset
    X_spline = np.zeros((X_train.shape[0], x_lin.size, 6))
    print(X_spline.shape)

    for i in np.arange(X_train[:, 0, 0].size): # for each sample
        for j in np.arange(6): # for each feature
            # add a cubic spline interpolation between the data points of X[sample, :, 0]
            interpolation = interpolate.interp1d(np.arange(0, 36), X_train[i, :, j], kind='cubic', fill_value="extrapolate")
            X_spline[i, :, j] = interpolation(x_lin)
    # create a figure with 6 subplots, one plot per each feature
    fig, axs = plt.subplots(6, 1, figsize=(9, 14))
    fig.suptitle('Sample ' + str(sample))
    for i in range(6):
        axs[i].set_title('Feature ' + str(i))
        # plots the given sequence of points without interpolation
        axs[i].plot(np.arange(0, 36), X_train[sample, :, i], 'o-', color='blue', markersize=4)

        # plots the new set of points with cubic spline interpolation
        axs[i].plot(x_lin, X_spline[sample, :, i], "o-", color='red', markersize = 3, alpha = 0.7)
    plt.show()
    # create a new augmented dataset with the new samples that is as big as the original training dataset
    X_augmented = np.empty((0, X_train.shape[1], X_train.shape[2]), dtype=np.float32)
    y_augmented = np.empty((0,), dtype=np.int32)

    print("interpolation_multiplier = ", interpolation_multiplier)

    # for each sample in the training dataset
    for i in range(y_train.shape[0]):

        # copy the original sample in the augmented dataset every 3 points from X_spline[i, k, :]
        for j in range(interpolation_multiplier):
            X_augmented = np.append(X_augmented, np.expand_dims(X_spline[i, j::interpolation_multiplier, :], axis=0), axis=0)
            y_augmented = np.append(y_augmented, np.expand_dims(y_train[i], axis=0), axis=0)

            # for each sample, add a random gaussian noise to each feature

            for k in range(X_augmented.shape[2]):
                mins = np.min(X_augmented[-1, :, k], axis=0)
                maxs = np.max(X_augmented[-1, :, k], axis=0)

                values = np.random.normal(0, augment_std * (maxs - mins), X_augmented.shape[1])
                X_augmented[-1, :, k] = np.add(X_augmented[-1, :, k], values)

    print("new augmented dataset size ", X_augmented.shape, y_augmented.shape, sep=", ")

    # shuffle the data
    X_augmented, y_augmented = shuffle(X_augmented, y_augmented, random_state=seed)
    
    return X_augmented, y_augmented

# %%
#redefining the function not to print (to be used in crossvalidation)
def spline_augment_no_print(X_train,y_train,interpolation_multiplier = 3,augment_std = 0.02):

    from scipy import interpolate

    # triple the number of points in the sequence to increase the resolution by a factor of 3
    x_lin = np.linspace(0, 35, 36 * interpolation_multiplier)

    # new augmented dataset
    X_spline = np.zeros((X_train.shape[0], x_lin.size, 6))


    for i in np.arange(X_train[:, 0, 0].size): # for each sample
        for j in np.arange(6): # for each feature
            # add a cubic spline interpolation between the data points of X[sample, :, 0]
            interpolation = interpolate.interp1d(np.arange(0, 36), X_train[i, :, j], kind='cubic', fill_value="extrapolate")
            X_spline[i, :, j] = interpolation(x_lin)
    
    # create a new augmented dataset with the new samples that is as big as the original training dataset
    X_augmented = np.empty((0, X_train.shape[1], X_train.shape[2]), dtype=np.float32)
    y_augmented = np.empty((0,), dtype=np.int32)

    # for each sample in the training dataset
    for i in range(y_train.shape[0]):

        # copy the original sample in the augmented dataset every 3 points from X_spline[i, k, :]
        for j in range(interpolation_multiplier):
            X_augmented = np.append(X_augmented, np.expand_dims(X_spline[i, j::interpolation_multiplier, :], axis=0), axis=0)
            y_augmented = np.append(y_augmented, np.expand_dims(y_train[i], axis=0), axis=0)

            # for each sample, add a random gaussian noise to each feature

            for k in range(X_augmented.shape[2]):
                mins = np.min(X_augmented[-1, :, k], axis=0)
                maxs = np.max(X_augmented[-1, :, k], axis=0)

                values = np.random.normal(0, augment_std * (maxs - mins), X_augmented.shape[1])
                X_augmented[-1, :, k] = np.add(X_augmented[-1, :, k], values)

    # shuffle the data
    X_augmented, y_augmented = shuffle(X_augmented, y_augmented, random_state=seed)
    
    return X_augmented, y_augmented

# %% [markdown]
# ## Preprocessing the dataset

# %%
if standard_training:
    #X_train = np.delete(X_train, 3, axis=2)
    #X_test = np.delete(X_test, 3, axis=2)
    
    features_num = X_train.shape[2]
    print("features: ", features_num)

    #(optional) apply spline augmentation
    if(use_splines_std_training):
        X_train,y_train = spline_augment_print(X_train,y_train,interpolation_multiplier = 2,augment_std = 0.025)
    
    if (scaling):
        scaler_robust = RobustScaler()
        scaler_std = StandardScaler()
        scaler_0 = MinMaxScaler(feature_range=(0,1))
        #scaler_1 = MinMaxScaler(feature_range=(-1,1))

        num_instances, num_time_steps, num_features = X_train.shape
        X_train = np.reshape(X_train, newshape=(-1, num_features))
        #X_train = scaler_robust.fit_transform(X_train)
        X_train = scaler_0.fit_transform(X_train)
        X_train = scaler_std.fit_transform(X_train)

        X_train = np.reshape(X_train, newshape=(num_instances, num_time_steps, num_features))

        num_instances, num_time_steps, num_features = X_test.shape
        X_test = np.reshape(X_test, newshape=(-1, num_features))
        #X_test = scaler_robust.transform(X_test)
        X_test = scaler_0.transform(X_test)
        X_test = scaler_std.transform(X_test)

        X_test = np.reshape(X_test, newshape=(num_instances, num_time_steps, num_features))
        #print("std_scaler: "+str(scaler_std.__dict__))
        #print("min_max_scaler_1: "+str(scaler_1.__dict__))
        #print("min_max_scaler_0: "+str(scaler_0.__dict__))
# Out:
# features:  6
# (2064, 72, 6)
# interpolation_multiplier =  2
# new augmented dataset size , (4128, 36, 6), (4128,)

# %% [markdown]
# Categorical labels for the training and test data

# %%
if standard_training:   
    # Convert the sparse labels to categorical values
    y_train = tfk.utils.to_categorical(y_train)
    y_test = tfk.utils.to_categorical(y_test)
    print(X_train.shape, y_train.shape, sep=", ")
    print(X_test.shape, y_test.shape, sep=", ")
# Out:
# (4128, 36, 6), (4128, 12)
# (365, 36, 6), (365, 12)

# %% [markdown]
# ## Build the models

# %% [markdown]
# Hyperparameters

# %%
if standard_training:  
    input_shape = X_train.shape[1:]
    print("input shape: ", input_shape)
    classes = y_train.shape[-1]
batch_size = 512
epochs = 1000
# Out:
# input shape:  (36, 6)

# %% [markdown]
# Plot history of the training and the learning rate schedule

# %%
def plot_history(history):
	best_epoch = np.argmax(history['val_accuracy'])
	plt.figure(figsize=(17,4))
	plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
	plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.title('Categorical Crossentropy')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

	plt.figure(figsize=(17,4))
	plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
	plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.title('Accuracy')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

	plt.figure(figsize=(17,4))
	plt.title('Learning Rate Schedule')
	plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

# %% [markdown]
# Plot confusion matrix, F1 scores and displays model accuracy

# %%
def plot_statistics(predictions):	
	# Compute the confusion matrix
	cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

	# Compute the classification metrics
	accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
	precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	print('Accuracy:',accuracy.round(4))
	print('Precision:',precision.round(4))
	print('Recall:',recall.round(4))
	print('F1:',f1.round(4))

	# Plot the confusion matrix
	plt.figure(figsize=(7, 6))
	plt.title('Confusion matrix')
	sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()), annot=True, fmt="d")
	plt.xlabel('True labels')
	plt.ylabel('Predicted labels')
	plt.show()

	# horizontal bar plot of the f1 scores for each class
	plt.figure(figsize=(6,4))
	plt.grid(alpha=.3)
	plt.barh(y=list(label_mapping.keys()), width=f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average=None))
	plt.title('F1 scores')
	plt.show()

# %%
from keras import backend as K

class AttentionLayer(tfkl.Layer):
    def _init_(self, **kwargs):
        super(AttentionLayer, self)._init_(**kwargs)

    def build(self, input_shape):
        # create a trainable weight variable for this layer which is used to compute a score for each time step in the input sequence
        self.W = self.add_weight(name='attention_weight', 
                                 shape=(input_shape[-1], 1),
                                 initializer='uniform',
                                 trainable=True)
        super(AttentionLayer, self).build(input_shape)

    def call(self, inputs, mask=None):
        # inputs: (batch_size, time_steps, n_features)
        # mask: (batch_size, time_steps)

        # apply a dot product between the input and the trainable weight to
        # get a score for each time step
        score = K.dot(inputs, self.W)
        score = K.squeeze(score, axis=-1)
        # apply a softmax activation to the score to compute the attention
        # weights for each time step
        attention_weights = K.softmax(score)
        # multiply the attention weights by the input to compute the
        # weighted sum of the input
        weighted_sum = K.sum(K.expand_dims(attention_weights, axis=-1) * inputs, axis=1)
        # return the attention-weighted sum of the input
        return weighted_sum

    def compute_output_shape(self, input_shape):
        # the output shape is the same as the input shape, but with 1 less dimension
        return (input_shape[0], input_shape[-1])

# %% [markdown]
# #### Only convolutional and dense layers

# %%
def build_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    
    #head1
    y = tfkl.Conv1D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv1y')(input_layer)

    #y = tfkl.Dropout(0.1, seed=seed)(y)

    y = tfkl.Conv1D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv2y')(y)
    
    #y = tfkl.Dropout(0.1, seed=seed)(y)
    
    y = tfkl.Conv1D(
        filters = 128,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv3y')(y)

    y = tfkl.Dropout(0.2, seed=seed)(y)
    

    #head4-LSTM
    
    r = tfkl.Bidirectional(tfkl.GRU(60, return_sequences=True, name='lstm1'))(y)
    r = tfkl.Dropout(0.5, seed=seed)(r)
    r = tfkl.Bidirectional(tfkl.GRU(60, return_sequences=True, name='lstm2'))(r)
    r = tfkl.Dropout(0.5, seed=seed)(r)

    x = AttentionLayer()(r)

    output_layer = tfkl.Dense(classes, activation='softmax',kernel_initializer = tfk.initializers.GlorotUniform(seed))(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model1')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(3e-3), metrics='accuracy')

    # Return the model
    return model

# %%
if standard_training:  
    model = build_classifier(input_shape,classes)
    model.summary()
# Out:
# Model: "model1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 36, 6)]           0
# _________________________________________________________________
# conv1y (Conv1D)              (None, 36, 256)           4864
# _________________________________________________________________
# conv2y (Conv1D)              (None, 36, 256)           196864
# _________________________________________________________________
# conv3y (Conv1D)              (None, 36, 128)           98432
# _________________________________________________________________
# dropout_306 (Dropout)        (None, 36, 128)           0
# _________________________________________________________________
# bidirectional_176 (Bidirecti (None, 36, 120)           68400
# _________________________________________________________________
# dropout_307 (Dropout)        (None, 36, 120)           0
# _________________________________________________________________
# bidirectional_177 (Bidirecti (None, 36, 120)           65520
# _________________________________________________________________
# dropout_308 (Dropout)        (None, 36, 120)           0
# _________________________________________________________________
# attention_layer_88 (Attentio (None, 120)               120
# _________________________________________________________________
# dense_88 (Dense)             (None, 12)                1452
# =================================================================
# Total params: 435,652
# Trainable params: 435,652
# Non-trainable params: 0
# _________________________________________________________________

# %%
if standard_training:
    
    # Train the model
    history = model.fit(
        x = X_train,
        y = y_train,
        batch_size = batch_size,
        epochs = epochs,
        validation_data = (X_test, y_test),
        #class_weight = class_weights,
        callbacks = [
            tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=150, restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=20, factor=0.4, min_lr=5e-5)
        ]
    ).history
# Out:
# Epoch 1/1000
# 9/9 [==============================] - 7s 165ms/step - loss: 2.0755 - accuracy: 0.3062 - val_loss: 1.8672 - val_accuracy: 0.3863
# Epoch 2/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 1.7497 - accuracy: 0.4162 - val_loss: 1.7754 - val_accuracy: 0.3836
# Epoch 3/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 1.6004 - accuracy: 0.4501 - val_loss: 1.5967 - val_accuracy: 0.4822
# Epoch 4/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 1.4480 - accuracy: 0.4932 - val_loss: 1.4150 - val_accuracy: 0.5096
# Epoch 5/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 1.3333 - accuracy: 0.5271 - val_loss: 1.3857 - val_accuracy: 0.5370
# Epoch 6/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 1.2764 - accuracy: 0.5494 - val_loss: 1.2520 - val_accuracy: 0.5699
# Epoch 7/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 1.2177 - accuracy: 0.5642 - val_loss: 1.2168 - val_accuracy: 0.5863
# Epoch 8/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 1.1504 - accuracy: 0.5984 - val_loss: 1.1533 - val_accuracy: 0.6055
# Epoch 9/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 1.1062 - accuracy: 0.6163 - val_loss: 1.1670 - val_accuracy: 0.6027
# Epoch 10/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 1.0908 - accuracy: 0.6165 - val_loss: 1.0898 - val_accuracy: 0.6493
# Epoch 11/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 1.0078 - accuracy: 0.6526 - val_loss: 1.1035 - val_accuracy: 0.6329
# Epoch 12/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.9864 - accuracy: 0.6512 - val_loss: 1.0811 - val_accuracy: 0.6493
# Epoch 13/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.9811 - accuracy: 0.6604 - val_loss: 1.0371 - val_accuracy: 0.6740
# Epoch 14/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.9433 - accuracy: 0.6761 - val_loss: 1.0342 - val_accuracy: 0.6411
# Epoch 15/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.9502 - accuracy: 0.6705 - val_loss: 1.0254 - val_accuracy: 0.6603
# Epoch 16/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.9182 - accuracy: 0.6776 - val_loss: 0.9619 - val_accuracy: 0.6849
# Epoch 17/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.8605 - accuracy: 0.7011 - val_loss: 0.9941 - val_accuracy: 0.6849
# Epoch 18/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.8272 - accuracy: 0.7163 - val_loss: 0.9492 - val_accuracy: 0.6795
# Epoch 19/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.7794 - accuracy: 0.7328 - val_loss: 0.9731 - val_accuracy: 0.6767
# Epoch 20/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.7789 - accuracy: 0.7313 - val_loss: 0.9409 - val_accuracy: 0.7123
# Epoch 21/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.7274 - accuracy: 0.7544 - val_loss: 0.8989 - val_accuracy: 0.7178
# Epoch 22/1000
# 9/9 [==============================] - 0s 43ms/step - loss: 0.7211 - accuracy: 0.7476 - val_loss: 0.8799 - val_accuracy: 0.7123
# Epoch 23/1000
# 9/9 [==============================] - 0s 39ms/step - loss: 0.7102 - accuracy: 0.7531 - val_loss: 0.8818 - val_accuracy: 0.7178
# Epoch 24/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.6825 - accuracy: 0.7665 - val_loss: 0.9995 - val_accuracy: 0.6849
# Epoch 25/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.6800 - accuracy: 0.7660 - val_loss: 0.9766 - val_accuracy: 0.6575
# Epoch 26/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.6747 - accuracy: 0.7641 - val_loss: 1.0332 - val_accuracy: 0.7260
# Epoch 27/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.6671 - accuracy: 0.7764 - val_loss: 0.9492 - val_accuracy: 0.7123
# Epoch 28/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.5923 - accuracy: 0.7982 - val_loss: 0.9277 - val_accuracy: 0.7288
# Epoch 29/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5463 - accuracy: 0.8142 - val_loss: 0.9351 - val_accuracy: 0.7123
# Epoch 30/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5487 - accuracy: 0.8123 - val_loss: 1.0381 - val_accuracy: 0.7068
# Epoch 31/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5736 - accuracy: 0.8040 - val_loss: 1.0098 - val_accuracy: 0.6904
# Epoch 32/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5513 - accuracy: 0.8106 - val_loss: 0.9282 - val_accuracy: 0.7205
# Epoch 33/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.4887 - accuracy: 0.8319 - val_loss: 0.9814 - val_accuracy: 0.7260
# Epoch 34/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.4646 - accuracy: 0.8442 - val_loss: 1.0293 - val_accuracy: 0.7397
# Epoch 35/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.4299 - accuracy: 0.8571 - val_loss: 0.9536 - val_accuracy: 0.7315
# Epoch 36/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.4224 - accuracy: 0.8641 - val_loss: 1.1074 - val_accuracy: 0.7096
# Epoch 37/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.4460 - accuracy: 0.8450 - val_loss: 1.0811 - val_accuracy: 0.7370
# Epoch 38/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.4007 - accuracy: 0.8658 - val_loss: 0.9780 - val_accuracy: 0.7425
# Epoch 39/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.3738 - accuracy: 0.8680 - val_loss: 1.0850 - val_accuracy: 0.7123
# Epoch 40/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.4033 - accuracy: 0.8617 - val_loss: 1.0928 - val_accuracy: 0.7096
# Epoch 41/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.3483 - accuracy: 0.8789 - val_loss: 1.0693 - val_accuracy: 0.7233
# Epoch 42/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.3296 - accuracy: 0.8905 - val_loss: 1.0732 - val_accuracy: 0.7315
# Epoch 43/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.2902 - accuracy: 0.9053 - val_loss: 1.0703 - val_accuracy: 0.7260
# Epoch 44/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.2675 - accuracy: 0.9084 - val_loss: 1.1230 - val_accuracy: 0.7096
# Epoch 45/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.2569 - accuracy: 0.9128 - val_loss: 1.1523 - val_accuracy: 0.7425
# Epoch 46/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.2756 - accuracy: 0.9096 - val_loss: 1.2285 - val_accuracy: 0.7342
# Epoch 47/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.3044 - accuracy: 0.8944 - val_loss: 1.2041 - val_accuracy: 0.7370
# Epoch 48/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.2861 - accuracy: 0.8992 - val_loss: 1.2314 - val_accuracy: 0.7370
# Epoch 49/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.2628 - accuracy: 0.9150 - val_loss: 1.1836 - val_accuracy: 0.7616
# Epoch 50/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.2621 - accuracy: 0.9159 - val_loss: 1.3154 - val_accuracy: 0.7233
# Epoch 51/1000
# 9/9 [==============================] - 0s 37ms/step - loss: 0.2432 - accuracy: 0.9210 - val_loss: 1.2666 - val_accuracy: 0.7315
# Epoch 52/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.2699 - accuracy: 0.9167 - val_loss: 1.1631 - val_accuracy: 0.7425
# Epoch 53/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.2187 - accuracy: 0.9322 - val_loss: 1.1396 - val_accuracy: 0.7397
# Epoch 54/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.1690 - accuracy: 0.9499 - val_loss: 1.1797 - val_accuracy: 0.7479
# Epoch 55/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.1659 - accuracy: 0.9508 - val_loss: 1.2080 - val_accuracy: 0.7507
# Epoch 56/1000
# 9/9 [==============================] - 0s 43ms/step - loss: 0.1787 - accuracy: 0.9423 - val_loss: 1.2559 - val_accuracy: 0.7452
# Epoch 57/1000
# 9/9 [==============================] - 0s 37ms/step - loss: 0.1770 - accuracy: 0.9433 - val_loss: 1.2559 - val_accuracy: 0.7370
# Epoch 58/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.1544 - accuracy: 0.9516 - val_loss: 1.3604 - val_accuracy: 0.7260
# Epoch 59/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.1267 - accuracy: 0.9651 - val_loss: 1.3477 - val_accuracy: 0.7315
# Epoch 60/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.1543 - accuracy: 0.9508 - val_loss: 1.4062 - val_accuracy: 0.7342
# Epoch 61/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.1403 - accuracy: 0.9566 - val_loss: 1.3955 - val_accuracy: 0.7151
# Epoch 62/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.1262 - accuracy: 0.9593 - val_loss: 1.4102 - val_accuracy: 0.7507
# Epoch 63/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.1010 - accuracy: 0.9697 - val_loss: 1.5010 - val_accuracy: 0.7151
# Epoch 64/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.2199 - accuracy: 0.9302 - val_loss: 1.5781 - val_accuracy: 0.7123
# Epoch 65/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.1839 - accuracy: 0.9377 - val_loss: 1.4043 - val_accuracy: 0.7260
# Epoch 66/1000
# 9/9 [==============================] - 0s 42ms/step - loss: 0.1635 - accuracy: 0.9484 - val_loss: 1.5205 - val_accuracy: 0.7205
# Epoch 67/1000
# 9/9 [==============================] - 0s 39ms/step - loss: 0.1418 - accuracy: 0.9540 - val_loss: 1.3740 - val_accuracy: 0.7370
# Epoch 68/1000
# 9/9 [==============================] - 0s 39ms/step - loss: 0.1150 - accuracy: 0.9632 - val_loss: 1.4541 - val_accuracy: 0.7205
# Epoch 69/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0914 - accuracy: 0.9726 - val_loss: 1.4287 - val_accuracy: 0.7178
# Epoch 70/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0941 - accuracy: 0.9704 - val_loss: 1.4209 - val_accuracy: 0.7452
# Epoch 71/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0713 - accuracy: 0.9806 - val_loss: 1.4678 - val_accuracy: 0.7342
# Epoch 72/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0582 - accuracy: 0.9826 - val_loss: 1.4863 - val_accuracy: 0.7397
# Epoch 73/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0526 - accuracy: 0.9845 - val_loss: 1.4727 - val_accuracy: 0.7397
# Epoch 74/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0514 - accuracy: 0.9867 - val_loss: 1.4541 - val_accuracy: 0.7397
# Epoch 75/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0497 - accuracy: 0.9867 - val_loss: 1.4961 - val_accuracy: 0.7397
# Epoch 76/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0650 - accuracy: 0.9794 - val_loss: 1.4717 - val_accuracy: 0.7425
# Epoch 77/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0500 - accuracy: 0.9855 - val_loss: 1.4258 - val_accuracy: 0.7370
# Epoch 78/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0548 - accuracy: 0.9843 - val_loss: 1.5488 - val_accuracy: 0.7452
# Epoch 79/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0495 - accuracy: 0.9857 - val_loss: 1.5986 - val_accuracy: 0.7288
# Epoch 80/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0457 - accuracy: 0.9876 - val_loss: 1.5537 - val_accuracy: 0.7260
# Epoch 81/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0373 - accuracy: 0.9913 - val_loss: 1.5898 - val_accuracy: 0.7315
# Epoch 82/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0360 - accuracy: 0.9915 - val_loss: 1.5947 - val_accuracy: 0.7315
# Epoch 83/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0477 - accuracy: 0.9867 - val_loss: 1.5635 - val_accuracy: 0.7370
# Epoch 84/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0375 - accuracy: 0.9920 - val_loss: 1.5938 - val_accuracy: 0.7479
# Epoch 85/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0356 - accuracy: 0.9927 - val_loss: 1.5928 - val_accuracy: 0.7370
# Epoch 86/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0358 - accuracy: 0.9915 - val_loss: 1.6377 - val_accuracy: 0.7342
# Epoch 87/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0321 - accuracy: 0.9930 - val_loss: 1.6064 - val_accuracy: 0.7288
# Epoch 88/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0326 - accuracy: 0.9920 - val_loss: 1.6670 - val_accuracy: 0.7397
# Epoch 89/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0291 - accuracy: 0.9937 - val_loss: 1.6182 - val_accuracy: 0.7370
# Epoch 90/1000
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0238 - accuracy: 0.9939 - val_loss: 1.6445 - val_accuracy: 0.7233
# Epoch 91/1000
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0272 - accuracy: 0.9942 - val_loss: 1.6367 - val_accuracy: 0.7315
# Epoch 92/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0212 - accuracy: 0.9971 - val_loss: 1.6367 - val_accuracy: 0.7342
# Epoch 93/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0221 - accuracy: 0.9959 - val_loss: 1.6445 - val_accuracy: 0.7397
# Epoch 94/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0191 - accuracy: 0.9959 - val_loss: 1.6357 - val_accuracy: 0.7425
# Epoch 95/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0233 - accuracy: 0.9939 - val_loss: 1.6504 - val_accuracy: 0.7397
# Epoch 96/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0202 - accuracy: 0.9961 - val_loss: 1.6445 - val_accuracy: 0.7370
# Epoch 97/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0187 - accuracy: 0.9966 - val_loss: 1.6514 - val_accuracy: 0.7452
# Epoch 98/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0180 - accuracy: 0.9966 - val_loss: 1.6592 - val_accuracy: 0.7452
# Epoch 99/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0199 - accuracy: 0.9954 - val_loss: 1.6650 - val_accuracy: 0.7397
# Epoch 100/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0183 - accuracy: 0.9956 - val_loss: 1.6562 - val_accuracy: 0.7425
# Epoch 101/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0164 - accuracy: 0.9966 - val_loss: 1.6621 - val_accuracy: 0.7370
# Epoch 102/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0184 - accuracy: 0.9964 - val_loss: 1.6748 - val_accuracy: 0.7370
# Epoch 103/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0187 - accuracy: 0.9973 - val_loss: 1.6865 - val_accuracy: 0.7397
# Epoch 104/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0153 - accuracy: 0.9978 - val_loss: 1.6855 - val_accuracy: 0.7452
# Epoch 105/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0166 - accuracy: 0.9971 - val_loss: 1.6943 - val_accuracy: 0.7370
# Epoch 106/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0158 - accuracy: 0.9971 - val_loss: 1.7119 - val_accuracy: 0.7315
# Epoch 107/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0175 - accuracy: 0.9969 - val_loss: 1.7070 - val_accuracy: 0.7315
# Epoch 108/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0160 - accuracy: 0.9969 - val_loss: 1.7119 - val_accuracy: 0.7370
# Epoch 109/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0167 - accuracy: 0.9966 - val_loss: 1.7090 - val_accuracy: 0.7425
# Epoch 110/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0169 - accuracy: 0.9966 - val_loss: 1.7061 - val_accuracy: 0.7425
# Epoch 111/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0175 - accuracy: 0.9971 - val_loss: 1.7119 - val_accuracy: 0.7370
# Epoch 112/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0156 - accuracy: 0.9961 - val_loss: 1.7070 - val_accuracy: 0.7315
# Epoch 113/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0159 - accuracy: 0.9978 - val_loss: 1.7012 - val_accuracy: 0.7315
# Epoch 114/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0166 - accuracy: 0.9964 - val_loss: 1.7041 - val_accuracy: 0.7342
# Epoch 115/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0158 - accuracy: 0.9959 - val_loss: 1.6992 - val_accuracy: 0.7425
# Epoch 116/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0142 - accuracy: 0.9971 - val_loss: 1.7021 - val_accuracy: 0.7397
# Epoch 117/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0155 - accuracy: 0.9971 - val_loss: 1.7168 - val_accuracy: 0.7397
# Epoch 118/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0164 - accuracy: 0.9964 - val_loss: 1.7207 - val_accuracy: 0.7342
# Epoch 119/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0153 - accuracy: 0.9964 - val_loss: 1.7090 - val_accuracy: 0.7452
# Epoch 120/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0175 - accuracy: 0.9959 - val_loss: 1.6973 - val_accuracy: 0.7452
# Epoch 121/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0159 - accuracy: 0.9959 - val_loss: 1.6963 - val_accuracy: 0.7342
# Epoch 122/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0158 - accuracy: 0.9966 - val_loss: 1.7061 - val_accuracy: 0.7342
# Epoch 123/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0148 - accuracy: 0.9976 - val_loss: 1.6963 - val_accuracy: 0.7370
# Epoch 124/1000
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0148 - accuracy: 0.9973 - val_loss: 1.6895 - val_accuracy: 0.7342
# Epoch 125/1000
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0123 - accuracy: 0.9978 - val_loss: 1.6904 - val_accuracy: 0.7370
# Epoch 126/1000
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0144 - accuracy: 0.9971 - val_loss: 1.7002 - val_accuracy: 0.7370
# Epoch 127/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0153 - accuracy: 0.9964 - val_loss: 1.6992 - val_accuracy: 0.7342
# Epoch 128/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0136 - accuracy: 0.9973 - val_loss: 1.6963 - val_accuracy: 0.7315
# Epoch 129/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0134 - accuracy: 0.9976 - val_loss: 1.7031 - val_accuracy: 0.7397
# Epoch 130/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0134 - accuracy: 0.9983 - val_loss: 1.7041 - val_accuracy: 0.7342
# Epoch 131/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0128 - accuracy: 0.9976 - val_loss: 1.7051 - val_accuracy: 0.7397
# Epoch 132/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0118 - accuracy: 0.9983 - val_loss: 1.7051 - val_accuracy: 0.7370
# Epoch 133/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0133 - accuracy: 0.9971 - val_loss: 1.7100 - val_accuracy: 0.7425
# Epoch 134/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0130 - accuracy: 0.9973 - val_loss: 1.7139 - val_accuracy: 0.7397
# Epoch 135/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0148 - accuracy: 0.9971 - val_loss: 1.7148 - val_accuracy: 0.7370
# Epoch 136/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0112 - accuracy: 0.9983 - val_loss: 1.7236 - val_accuracy: 0.7342
# Epoch 137/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0125 - accuracy: 0.9990 - val_loss: 1.7275 - val_accuracy: 0.7342
# Epoch 138/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0124 - accuracy: 0.9973 - val_loss: 1.7295 - val_accuracy: 0.7342
# Epoch 139/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0124 - accuracy: 0.9976 - val_loss: 1.7285 - val_accuracy: 0.7342
# Epoch 140/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0126 - accuracy: 0.9976 - val_loss: 1.7256 - val_accuracy: 0.7342
# Epoch 141/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0127 - accuracy: 0.9981 - val_loss: 1.7275 - val_accuracy: 0.7397
# Epoch 142/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0129 - accuracy: 0.9981 - val_loss: 1.7236 - val_accuracy: 0.7397
# Epoch 143/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0124 - accuracy: 0.9973 - val_loss: 1.7197 - val_accuracy: 0.7397
# Epoch 144/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0118 - accuracy: 0.9981 - val_loss: 1.7158 - val_accuracy: 0.7397
# Epoch 145/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0117 - accuracy: 0.9981 - val_loss: 1.7158 - val_accuracy: 0.7397
# Epoch 146/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0128 - accuracy: 0.9973 - val_loss: 1.7148 - val_accuracy: 0.7425
# Epoch 147/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0138 - accuracy: 0.9971 - val_loss: 1.7148 - val_accuracy: 0.7425
# Epoch 148/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 1.7148 - val_accuracy: 0.7425
# Epoch 149/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0127 - accuracy: 0.9976 - val_loss: 1.7129 - val_accuracy: 0.7425
# Epoch 150/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0123 - accuracy: 0.9973 - val_loss: 1.7129 - val_accuracy: 0.7452
# Epoch 151/1000
# 9/9 [==============================] - 0s 34ms/step - loss: 0.0140 - accuracy: 0.9961 - val_loss: 1.7109 - val_accuracy: 0.7452
# Epoch 152/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0116 - accuracy: 0.9985 - val_loss: 1.7100 - val_accuracy: 0.7479
# Epoch 153/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0115 - accuracy: 0.9983 - val_loss: 1.7119 - val_accuracy: 0.7452
# Epoch 154/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0118 - accuracy: 0.9988 - val_loss: 1.7139 - val_accuracy: 0.7425
# Epoch 155/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0102 - accuracy: 0.9985 - val_loss: 1.7148 - val_accuracy: 0.7425
# Epoch 156/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0110 - accuracy: 0.9988 - val_loss: 1.7158 - val_accuracy: 0.7425
# Epoch 157/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0111 - accuracy: 0.9988 - val_loss: 1.7168 - val_accuracy: 0.7425
# Epoch 158/1000
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0110 - accuracy: 0.9981 - val_loss: 1.7168 - val_accuracy: 0.7452
# Epoch 159/1000
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0114 - accuracy: 0.9983 - val_loss: 1.7178 - val_accuracy: 0.7452
# Epoch 160/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0126 - accuracy: 0.9971 - val_loss: 1.7188 - val_accuracy: 0.7425
# Epoch 161/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0122 - accuracy: 0.9978 - val_loss: 1.7119 - val_accuracy: 0.7425
# Epoch 162/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0121 - accuracy: 0.9981 - val_loss: 1.7090 - val_accuracy: 0.7425
# Epoch 163/1000
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0133 - accuracy: 0.9978 - val_loss: 1.7129 - val_accuracy: 0.7425
# Epoch 164/1000
# 9/9 [==============================] - 0s 40ms/step - loss: 0.0108 - accuracy: 0.9990 - val_loss: 1.7158 - val_accuracy: 0.7452
# Epoch 165/1000
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0110 - accuracy: 0.9983 - val_loss: 1.7178 - val_accuracy: 0.7397
# Epoch 166/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0124 - accuracy: 0.9978 - val_loss: 1.7207 - val_accuracy: 0.7397
# Epoch 167/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0124 - accuracy: 0.9976 - val_loss: 1.7168 - val_accuracy: 0.7397
# Epoch 168/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0122 - accuracy: 0.9978 - val_loss: 1.7178 - val_accuracy: 0.7397
# Epoch 169/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0105 - accuracy: 0.9990 - val_loss: 1.7188 - val_accuracy: 0.7397
# Epoch 170/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0119 - accuracy: 0.9981 - val_loss: 1.7188 - val_accuracy: 0.7397
# Epoch 171/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0116 - accuracy: 0.9983 - val_loss: 1.7217 - val_accuracy: 0.7425
# Epoch 172/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0116 - accuracy: 0.9981 - val_loss: 1.7217 - val_accuracy: 0.7425
# Epoch 173/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0115 - accuracy: 0.9978 - val_loss: 1.7207 - val_accuracy: 0.7397
# Epoch 174/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0118 - accuracy: 0.9969 - val_loss: 1.7236 - val_accuracy: 0.7397
# Epoch 175/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0122 - accuracy: 0.9978 - val_loss: 1.7246 - val_accuracy: 0.7425
# Epoch 176/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0118 - accuracy: 0.9985 - val_loss: 1.7246 - val_accuracy: 0.7397
# Epoch 177/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0129 - accuracy: 0.9976 - val_loss: 1.7246 - val_accuracy: 0.7397
# Epoch 178/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0115 - accuracy: 0.9983 - val_loss: 1.7256 - val_accuracy: 0.7370
# Epoch 179/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0110 - accuracy: 0.9981 - val_loss: 1.7256 - val_accuracy: 0.7370
# Epoch 180/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0134 - accuracy: 0.9966 - val_loss: 1.7256 - val_accuracy: 0.7370
# Epoch 181/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0123 - accuracy: 0.9973 - val_loss: 1.7285 - val_accuracy: 0.7370
# Epoch 182/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0121 - accuracy: 0.9978 - val_loss: 1.7324 - val_accuracy: 0.7370
# Epoch 183/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0113 - accuracy: 0.9983 - val_loss: 1.7324 - val_accuracy: 0.7397
# Epoch 184/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0115 - accuracy: 0.9985 - val_loss: 1.7324 - val_accuracy: 0.7397
# Epoch 185/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0093 - accuracy: 0.9988 - val_loss: 1.7324 - val_accuracy: 0.7397
# Epoch 186/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0115 - accuracy: 0.9978 - val_loss: 1.7324 - val_accuracy: 0.7397
# Epoch 187/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0101 - accuracy: 0.9988 - val_loss: 1.7324 - val_accuracy: 0.7397
# Epoch 188/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0102 - accuracy: 0.9985 - val_loss: 1.7305 - val_accuracy: 0.7397
# Epoch 189/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0114 - accuracy: 0.9978 - val_loss: 1.7275 - val_accuracy: 0.7425
# Epoch 190/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0113 - accuracy: 0.9988 - val_loss: 1.7275 - val_accuracy: 0.7425
# Epoch 191/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0100 - accuracy: 0.9988 - val_loss: 1.7314 - val_accuracy: 0.7397
# Epoch 192/1000
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0103 - accuracy: 0.9983 - val_loss: 1.7334 - val_accuracy: 0.7397
# Epoch 193/1000
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0100 - accuracy: 0.9988 - val_loss: 1.7344 - val_accuracy: 0.7397
# Epoch 194/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0130 - accuracy: 0.9973 - val_loss: 1.7334 - val_accuracy: 0.7425
# Epoch 195/1000
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0106 - accuracy: 0.9981 - val_loss: 1.7295 - val_accuracy: 0.7452
# Epoch 196/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0111 - accuracy: 0.9985 - val_loss: 1.7295 - val_accuracy: 0.7425
# Epoch 197/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0120 - accuracy: 0.9976 - val_loss: 1.7295 - val_accuracy: 0.7425
# Epoch 198/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0123 - accuracy: 0.9973 - val_loss: 1.7285 - val_accuracy: 0.7397
# Epoch 199/1000
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0123 - accuracy: 0.9978 - val_loss: 1.7285 - val_accuracy: 0.7397

# %% [markdown]
# Convolutional model evaluation

# %%
if standard_training:
    plot_history(history)

    # Predict the test set with the LSTM
    predictions = model.predict(X_test)

    plot_statistics(predictions)
# Out:
# Accuracy: 0.7589
# Precision: 0.7255
# Recall: 0.6058
# F1: 0.6476

# %% [markdown]
# Save model with the validation accuracy in the name

# %%
if standard_training:
    accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
    if (accuracy > 0.765):
        model_name = "TUNED_GRU_" + str(accuracy.round(6))
        model.save(model_name)

        
        FileLink(r"" + model_name + ".zip")
        import joblib
        scaler_std_filename =model_name+ "/scaler_std.save"
        joblib.dump(scaler_std, scaler_std_filename) 
        scaler_0_filename =model_name+ "/scaler_0.save"
        joblib.dump(scaler_0, scaler_0_filename) 
        #scaler_robust_filename =model_name+ "/scaler_robust.save"
        #joblib.dump(scaler_robust, scaler_robust_filename) 

        shutil.make_archive(model_name, 'zip', model_name)

# %% [markdown]
# # Cross Validation

# %%
def scale_feature_wise(X_train, X_test):  #apply rescaling to each feature
    scaler_robust = RobustScaler()
    scaler_std = StandardScaler()
    scaler_0 = MinMaxScaler(feature_range=(0,1))
    scaler_1 = MinMaxScaler(feature_range=(-1,1))

    num_instances, num_time_steps, num_features = X_train.shape
    X_train = np.reshape(X_train, newshape=(-1, num_features))
    #X_train = scaler_robust.fit_transform(X_train)
    X_train = scaler_0.fit_transform(X_train)
    X_train = scaler_std.fit_transform(X_train)

    X_train = np.reshape(X_train, newshape=(num_instances, num_time_steps, num_features))

        
    
    if X_test is not None:
        num_instances, num_time_steps, num_features = X_test.shape
        X_test = np.reshape(X_test, newshape=(-1, num_features))
        #X_test = scaler_robust.transform(X_test)
        X_test = scaler_0.transform(X_test)
        X_test = scaler_std.transform(X_test)

        X_test = np.reshape(X_test, newshape=(num_instances, num_time_steps, num_features))
        return X_train, X_test
    
    return X_train

# %%
def scale_feature_wise_pca(X_train, X_test, n_components = 6):  #apply rescaling to each feature and use pca to reduce the number of features
    from sklearn.decomposition import PCA
    
    scaler_robust = RobustScaler()
    scaler_std = StandardScaler()
    scaler_0 = MinMaxScaler(feature_range=(0,1))
    scaler_1 = MinMaxScaler(feature_range=(-1,1))

    num_instances, num_time_steps, num_features = X_train.shape
    X_train = np.reshape(X_train, newshape=(-1, num_features))
    #X_train = scaler_robust.fit_transform(X_train)
    X_train = scaler_0.fit_transform(X_train)
    X_train = scaler_std.fit_transform(X_train)
    
    pca = PCA(n_components=n_components)
    pca.fit(X_train)
    X_train = pca.transform(X_train)
    num_features = pca.n_components_
    print("("+str(num_features)+" PCA components)")
    
    X_train = np.reshape(X_train, newshape=(num_instances, num_time_steps, num_features))

        
    
    if X_test is not None:
        num_instances, num_time_steps, num_features = X_test.shape
        X_test = np.reshape(X_test, newshape=(-1, num_features))
        #X_test = scaler_robust.transform(X_test)
        X_test = scaler_0.transform(X_test)
        X_test = scaler_std.transform(X_test)
        
        X_test = pca.transform(X_test)
        num_features = pca.n_components_
        
        X_test = np.reshape(X_test, newshape=(num_instances, num_time_steps, num_features))
        return X_train, X_test
    
    return X_train

# %%
def scale_ts_feature_wise(X_train, X_test):  #apply rescaling to each (timestamp,feature) pair
    scaler_robust = RobustScaler()
    scaler_std = StandardScaler()
    scaler_0 = MinMaxScaler(feature_range=(0,1))
    scaler_1 = MinMaxScaler(feature_range=(-1,1))

    num_instances, num_time_steps, num_features = X_train.shape
    X_train = np.reshape(X_train, newshape=(-1, num_features * num_time_steps))
    #X_train = scaler_robust.fit_transform(X_train)
    X_train = scaler_0.fit_transform(X_train)
    X_train = scaler_std.fit_transform(X_train)

    X_train = np.reshape(X_train, newshape=(num_instances, num_time_steps, num_features))

        
    
    if X_test is not None:
        num_instances, num_time_steps, num_features = X_test.shape
        X_test = np.reshape(X_test, newshape=(-1, num_features * num_time_steps))
        #X_test = scaler_robust.transform(X_test)
        X_test = scaler_0.transform(X_test)
        X_test = scaler_std.transform(X_test)

        X_test = np.reshape(X_test, newshape=(num_instances, num_time_steps, num_features))
        return X_train, X_test
    
    return X_train

# %%
from sklearn.model_selection import train_test_split, KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import class_weight
# Define the K-fold Cross Validator
num_folds = 10
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True) #Shuffle as we consider each time-series independent from others

# %%
# testing timeseries augmentation with crossvalidation

if use_cross_valid:
    best_acc = 0
    best_model = None
    best_history =  []
    
    # grid search FORs go here
    #print(f'°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°° MODEL {i} °°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°')
    
    print(f'°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°° START °°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°')

    acc_per_fold = []
    loss_per_fold = []
    fold_no = 1
    for train, test in kfold.split(X, y):
        print(f'Training for fold {fold_no} ...', end=' ')
        
        X_train = np.copy(X[train])
        y_train = np.copy(y[train])
        X_test = np.copy(X[test])
        y_test = np.copy(y[test])
        
        #drop some feature
        #X_train = np.delete(X_train, 5, axis=2)
        #X_test = np.delete(X_test, 5, axis=2)
        
        #test splines augmentation: creating new synthetic samples
        #by increasing the resolution of original series and adding gaussian noise
        #note that training will be much slower since augmentation is computed by CPU
        #and interpolation_multiplier linearly increases training set size
        
        #X_train,y_train = spline_augment_no_print(X_train,y_train,interpolation_multiplier = 3,augment_std = 0.05)
        
        y_train = tfk.utils.to_categorical(y_train)
        y_test = tfk.utils.to_categorical(y_test)
        classes = y_train.shape[-1]
        
        
        # Apply scaling (use only one of the following two)
        #X_train,X_test = scale_ts_feature_wise(X_train, X_test)
        X_train,X_test = scale_feature_wise(X_train, X_test)
        #X_train,X_test = scale_feature_wise_pca(X_train, X_test, n_components = 6)
        
        input_shape = X_train.shape[1:]
         # Intantiate a new model
            
        model = build_classifier(input_shape, classes)
        
        history = model.fit(X_train, y_train,
                  batch_size = batch_size,
                  epochs = epochs,
                  validation_data = (X_test, y_test),
                  #class_weight = class_weights,
                  verbose=0,
                  callbacks = [
                      tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=100, restore_best_weights=True),
                      tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=20, factor=0.4, min_lr=5e-5)
                  ]
        ).history
        
        # Generate generalization metrics
        acc = np.max(history['val_accuracy']) * 100
        print(f'score: accuracy of {acc}%')
        acc_per_fold.append(acc)

        # Increase fold number
        fold_no = fold_no + 1
        if fold_no <= num_folds + 1:
            print('------------------------------------------------------------------------')

    print('\nAverage scores for all folds:')
    acc = np.mean(acc_per_fold)
    print(f'> Accuracy: {acc} (+- {np.std(acc_per_fold)})')
    if acc > best_acc:
        best_acc = acc
        best_model = model
        best_history = history
    
    
    print('°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°')
              
    # Plot results
    best_model.summary()
    plot_history(best_history)
# Out:
# °°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°° START °°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°
# Training for fold 1 ... score: accuracy of 73.25102686882019%
# ------------------------------------------------------------------------
# Training for fold 2 ... score: accuracy of 75.72016716003418%
# ------------------------------------------------------------------------
# Training for fold 3 ... score: accuracy of 72.83950448036194%
# ------------------------------------------------------------------------
# Training for fold 4 ... score: accuracy of 76.13168954849243%
# ------------------------------------------------------------------------
# Training for fold 5 ... score: accuracy of 73.66254925727844%
# ------------------------------------------------------------------------
# Training for fold 6 ... score: accuracy of 72.83950448036194%
# ------------------------------------------------------------------------
# Training for fold 7 ... score: accuracy of 74.48559403419495%
# ------------------------------------------------------------------------
# Training for fold 8 ... score: accuracy of 74.8971164226532%
# ------------------------------------------------------------------------
# Training for fold 9 ... score: accuracy of 71.60493731498718%
# ------------------------------------------------------------------------
# Training for fold 10 ... score: accuracy of 72.72727489471436%
# ------------------------------------------------------------------------
#
# Average scores for all folds:
# > Accuracy: 73.81593644618988 (+- 1.3758411546758376)
# °°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°°
# Model: "model1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 36, 6)]           0
# _________________________________________________________________
# conv1y (Conv1D)              (None, 36, 256)           4864
# _________________________________________________________________
# conv2y (Conv1D)              (None, 36, 256)           196864
# _________________________________________________________________
# conv3y (Conv1D)              (None, 36, 128)           98432
# _________________________________________________________________
# dropout_336 (Dropout)        (None, 36, 128)           0
# _________________________________________________________________
# bidirectional_196 (Bidirecti (None, 36, 120)           68400
# _________________________________________________________________
# dropout_337 (Dropout)        (None, 36, 120)           0
# _________________________________________________________________
# bidirectional_197 (Bidirecti (None, 36, 120)           65520
# _________________________________________________________________
# dropout_338 (Dropout)        (None, 36, 120)           0
# _________________________________________________________________
# attention_layer_98 (Attentio (None, 120)               120
# _________________________________________________________________
# dense_98 (Dense)             (None, 12)                1452
# =================================================================
# Total params: 435,652
# Trainable params: 435,652
# Non-trainable params: 0
# _________________________________________________________________
