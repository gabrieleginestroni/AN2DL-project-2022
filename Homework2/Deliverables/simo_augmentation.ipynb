# %% [markdown]
# ### Import libraries

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight, shuffle
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)

print(tf.config.list_physical_devices())

import shutil
from IPython.display import FileLink
# Out:
# 2.10.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Set seed for reproducibility

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# Hyper parameters for augmentation, splines interpolation and scaling

# %%
scaling = True # applies standard scaling to the data
apply_oversampling = False # introduces white noise to the oversampled data

use_splines_resolution = False # uses splines for cubic interpolation the data
use_splines_augmentation = True # uses splines for cubic interpolation to create more artificial samples

# %% [markdown]
#  ## Load the training dataset

# %%
path = os.getcwd()
# Load the .npy file
X = np.load(path+r'\training\x_train.npy')
y = np.load(path+r'\training\y_train.npy')

# Convert to float32 for less precision and better performance
X = X.astype(np.float32)
y = y.astype(np.int32)

# shuffle X, y
X, y = shuffle(X, y, random_state=seed)

print(X.shape, X.dtype, sep=", ")   
print(y.shape, y.dtype, sep=", ")
# Out:
# (2429, 36, 6), float32
# (2429,), int32

# %% [markdown]
# Training - Validation Split

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=seed, shuffle=True)
print("training set : ", X_train.shape)
print("test set: ", X_test.shape)
# Out:
# training set :  (1943, 36, 6)
# test set:  (486, 36, 6)

# %% [markdown]
# Plotting the classes distributions

# %%
# Map classes STRINGS to integers
label_mapping = {
    'Wish': 0,
    'Another': 1,
    'Comfortably': 2,
    'Money': 3,
    'Breathe': 4,
    'Time': 5,
    'Brain': 6,
    'Echoes': 7,
    'Wearing': 8,
    'Sorrow': 9,
    'Hey': 10,
    'Shine': 11,  
}

#vertical bar plot of the classes distribution in y
plt.title('Classes distribution')
plt.bar(label_mapping.keys(), np.bincount(y), color = matplotlib.colormaps['Set2'].colors)
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Class weights computation

# %%
# Compute the class weights in order to balance loss during training
labels = np.unique(np.fromiter([t for t in y], np.int32))
class_weights = dict(enumerate(class_weight.compute_class_weight('balanced', classes=labels, y=y)))

# plot class weights with respect to the labels
plt.title('Class weights')
plt.bar(label_mapping.keys(), class_weights.values(), color = matplotlib.colormaps['Set2'].colors)
plt.xticks(rotation=90)
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# ## Data preprocessing with cubic interpolation between data points for increasing resolution

# %% [markdown]
# Before the cubic spline interpolation

# %%
# plot the sequence of points in a randomly drawn sample from X
sample = random.randint(0, X.shape[0])

# create a figure with 6 subplots, one plot per each feature
fig, axs = plt.subplots(6, 1, figsize=(9, 13))
fig.suptitle('Sample ' + str(sample))
for i in range(6):
	axs[i].set_title('Feature ' + str(i))
	# add a dot at each point in the sequence
	axs[i].plot(X[sample, :, i], 'o-', color='blue', markersize=4)

plt.show()

# %% [markdown]
# Application of spline interpolation to create a spline with new points

# %%
# add cubic spline interpolation between the data points of the sequence X[sample, :, i] and return the new set of points

from scipy import interpolate

interpolation_multiplier = 3 # resolution multiplier

# triple the number of points in the sequence to increase the resolution by a factor of 3
x_lin = np.linspace(0, 35, 36 * interpolation_multiplier)

# new augmented dataset
X_spline = np.zeros((X_train.shape[0], x_lin.size, 6))
print(X_spline.shape)

for i in np.arange(X_train.shape[0]): # for each sample
	for j in np.arange(6): # for each feature
		# add a cubic spline interpolation between the data points of X[sample, :, 0]
		interpolation = interpolate.interp1d(np.arange(0, 36), X_train[i, :, j], kind='cubic', fill_value="extrapolate")
		X_spline[i, :, j] = interpolation(x_lin)
# Out:
# (1943, 108, 6)

# %% [markdown]
# Plot the new sequence of interpolated points

# %%
# create a figure with 6 subplots, one plot per each feature
fig, axs = plt.subplots(6, 1, figsize=(9, 14))
fig.suptitle('Sample ' + str(sample))
for i in range(6):
	axs[i].set_title('Feature ' + str(i))
	# plots the given sequence of points without interpolation
	axs[i].plot(np.arange(0, 36), X_train[sample, :, i], 'o-', color='blue', markersize=4)

	# plots the new set of points with cubic spline interpolation
	axs[i].plot(x_lin, X_spline[sample, :, i], "o-", color='red', markersize = 3, alpha = 0.7)

plt.show()

# %% [markdown]
# Applies splines interpolation to the dataset

# %%
# use the new set of points with cubic spline interpolation so that the models are trained on a higher resolution
if (use_splines_resolution):
    X_train = X_spline
    #X_test = X_spline_test # if model is trained on the interpolated dataset, the test set must be augmented as well

# %% [markdown]
# ## Offline data oversampling

# %% [markdown]
# Oversampling the classes in a manner proportional to the class weights

# %%
# for each class take the samples and copy them in a new array
X_oversampled = np.empty((0, X_train.shape[1], X_train.shape[2]), dtype=np.float32)
y_oversampled = np.empty((0,), dtype=np.int32)

# compute the increment multiplier for each class based on its class weight
increment = np.zeros(len(label_mapping), dtype=np.int32)
for i in range(len(label_mapping)):
	increment[i] = int(np.ceil(np.max(np.bincount(y)) / np.bincount(y)[i]))

print("increment multiplier = ", increment)

# for each sample in the original dataset, copy it in the new array as many times as its class increment multiplier
for i in range(len(y_train)):

	# each sample is copied increment[y[i]] times in the new array
	for j in range(increment[y_train[i]]):
		X_oversampled = np.append(X_oversampled, np.expand_dims(X_train[i], axis=0), axis=0)
		y_oversampled = np.append(y_oversampled, np.expand_dims(y_train[i], axis=0), axis=0)

		# compute min and max for each X[i, :, k]
		for k in range(X.shape[2]):
			mins = np.min(X_train[i, :, k], axis=0)
			maxs = np.max(X_train[i, :, k], axis=0)

			# then add random gaussian noise to each sample
			values = np.random.normal(0, 0.05 * (maxs - mins), X_train.shape[1])
			X_oversampled[i, :, k] = np.add(X_oversampled[i, :, k], values)


print("new oversampled dataset size ", X_oversampled.shape, y_oversampled.shape, sep=", ")

# shuffle the data
X_oversampled, y_oversampled = shuffle(X_oversampled, y_oversampled, random_state=seed)
# Out:
# increment multiplier =  [23  7  3  3 13  6  3 12  7  1 11 16]
# new oversampled dataset size , (8282, 36, 6), (8282,)

# %% [markdown]
# Distribution of the classes after the oversampling

# %%
# plot the new distribution of the classes
plt.title('Classes distribution')
plt.bar(label_mapping.keys(), np.bincount(y_oversampled), color = matplotlib.colormaps['Set2'].colors)
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# New class weights after the oversampling

# %%
# compute and plot the new class weights
labels = np.unique(np.fromiter([t for t in y_oversampled], np.int32))
class_weights = dict(enumerate(class_weight.compute_class_weight('balanced', classes=labels, y=y_oversampled)))

plt.title('Class weights')
plt.bar(label_mapping.keys(), class_weights.values(), color = matplotlib.colormaps['Set2'].colors)
plt.xticks(rotation=90)
plt.ylabel('Weight')
plt.show()

# %% [markdown]
# Save the oversampled dataset

# %%
if (apply_oversampling):
	# save augmented dataset in the same dataset
	X_train = X_oversampled
	y_train = y_oversampled

# %% [markdown]
# ## Offline augmentation with cubic interpolation using splines to create new artificial samples of the original length

# %%
# create a new augmented dataset with the new samples that is as big as the original training dataset
X_augmented = np.empty((0, X_train.shape[1], X_train.shape[2]), dtype=np.float32)
y_augmented = np.empty((0,), dtype=np.int32)

print("interpolation_multiplier = ", interpolation_multiplier)

# for each sample in the training dataset
for i in range(y_train.shape[0]):
	# copy the original sample in the augmented dataset
	X_augmented = np.append(X_augmented, np.expand_dims(X_train[i], axis=0), axis=0)
	y_augmented = np.append(y_augmented, np.expand_dims(y_train[i], axis=0), axis=0)

	# copy the original sample in the augmented dataset every 3 points from X_spline[i, k, :]
	for j in range(interpolation_multiplier):
		X_augmented = np.append(X_augmented, np.expand_dims(X_spline[i, j::interpolation_multiplier, :], axis=0), axis=0)
		y_augmented = np.append(y_augmented, np.expand_dims(y_train[i], axis=0), axis=0)

		# for each sample, add a random gaussian noise to each feature
	
		for k in range(X_augmented.shape[2]):
			mins = np.min(X_augmented[-1, :, k], axis=0)
			maxs = np.max(X_augmented[-1, :, k], axis=0)

			values = np.random.normal(0, 0.05 * (maxs - mins), X_augmented.shape[1])
			X_augmented[-1, :, k] = np.add(X_augmented[-1, :, k], values)

print("new augmented dataset size ", X_augmented.shape, y_augmented.shape, sep=", ")
# Out:
# interpolation_multiplier =  3
# new augmented dataset size , (7772, 36, 6), (7772,)

# %% [markdown]
# Save the augmented dataset, given that the models are trained on sequences of normal length

# %%
# shuffle the data
X_augmented, y_augmented = shuffle(X_augmented, y_augmented, random_state=seed)
if (use_splines_augmentation):
	X_train = X_augmented
	y_train = y_augmented

# %% [markdown]
# ## Application of Standard Scaler to the dataset

# %%
features_num = X_train.shape[2]
print("features: ", features_num)

from sklearn.preprocessing import StandardScaler

scaler_std = StandardScaler()
# if the standard scaling is requested, computes it on the training set and prints its values
if (scaling):
    num_instances, num_time_steps, num_features = X_train.shape
    X_train = np.reshape(X_train, newshape=(-1, num_features))
    X_train = scaler_std.fit_transform(X_train)

    X_train = np.reshape(X_train, newshape=(num_instances, num_time_steps, num_features))

    num_instances, num_time_steps, num_features = X_test.shape
    X_test = np.reshape(X_test, newshape=(-1, num_features))
    X_test = scaler_std.transform(X_test)

    X_test = np.reshape(X_test, newshape=(num_instances, num_time_steps, num_features))

    # print the scaling parameters of scaler_std
    print("scaler_std.mean_ = ", scaler_std.mean_)
    print("scaler_std.var_ = ", scaler_std.var_)
    print("scaler_std.scale_ = ", scaler_std.scale_)
    print("scaler_std.n_samples_seen_ = ", scaler_std.n_samples_seen_)
    print("scaler_std.n_features_in_ = ", scaler_std.n_features_in_)
# Out:
# features:  6
# scaler_std.mean_ =  [11.36687187 23.08495967 28.09395477 35.84765074 34.82773619 30.21714722]
# scaler_std.var_ =  [ 75235.47499797 667340.89104019 516116.92646591 483084.57580208
#  454494.17986151 487019.74175376]
# scaler_std.scale_ =  [274.29085839 816.90935301 718.41278278 695.04285897 674.16183507
#  697.86799737]
# scaler_std.n_samples_seen_ =  279792
# scaler_std.n_features_in_ =  6

# %% [markdown]
# Categorical labels for the training and test data

# %%
# Convert the sparse labels to categorical values
y_train = tfk.utils.to_categorical(y_train)
y_test = tfk.utils.to_categorical(y_test)
print(X_train.shape, y_train.shape, sep=", ")
print(X_test.shape, y_test.shape, sep=", ")
# Out:
# (7772, 36, 6), (7772, 12)
# (486, 36, 6), (486, 12)

# %% [markdown]
# ## Build the models

# %% [markdown]
# Hyperparameters

# %%
input_shape = X_train.shape[1:]
print("input shape: ", input_shape)
classes = y_train.shape[-1]
batch_size = 128
epochs = 800
# Out:
# input shape:  (36, 6)

# %% [markdown]
# Plot history of the training and the learning rate schedule

# %%
def plot_history(history):
	best_epoch = np.argmax(history['val_accuracy'])
	plt.figure(figsize=(17,4))
	plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
	plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.title('Categorical Crossentropy')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

	plt.figure(figsize=(17,4))
	plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
	plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.title('Accuracy')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

	plt.figure(figsize=(17,4))
	plt.title('Learning Rate Schedule')
	plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
	plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
	plt.legend()
	plt.grid(alpha=.3)
	plt.show()

# %% [markdown]
# Plot confusion matrix, F1 scores and displays model accuracy

# %%
def plot_statistics(predictions):	
	# Compute the confusion matrix
	cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

	# Compute the classification metrics
	accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
	precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
	print('Accuracy:',accuracy.round(4))
	print('Precision:',precision.round(4))
	print('Recall:',recall.round(4))
	print('F1:',f1.round(4))

	# Plot the confusion matrix
	plt.figure(figsize=(7, 6))
	plt.title('Confusion matrix')
	sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()), annot=True, fmt="d")
	plt.xlabel('True labels')
	plt.ylabel('Predicted labels')
	plt.show()

	# horizontal bar plot of the f1 scores for each class
	plt.figure(figsize=(6,4))
	plt.grid(alpha=.3)
	plt.barh(y=list(label_mapping.keys()), width=f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average=None))
	plt.title('F1 scores')
	plt.show()

# %% [markdown]
# #### Only convolutional and dense layers

# %%
# this model was able to perform 0.751 on validation using splines augmentation and standard scaling, without class weights
def build_conv_dense(input_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    x = tfkl.Conv1D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed)
        )(input_layer)
    
    #x = tfkl.MaxPooling1D()(x)

    x = tfkl.Conv1D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed)
        )(x)
    
    #x = tfkl.MaxPooling1D(name='mp2')(x)

    x = tfkl.Conv1D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed)
        )(x)
    
    x = tfkl.GlobalAveragePooling1D()(x)
    
    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed)
        )(x)

    x = tfkl.Dense(
        units = 128,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed)
        )(x)
    
    x = tfkl.Dense(
        units = 128,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed)
        )(x)
    
    x = tfkl.Dropout(0.5, seed=seed)(x)

    output_layer = tfkl.Dense(classes, activation='softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model1')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(7e-4), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_conv_dense(input_shape)
model.summary()
# Out:
# Model: "model1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 36, 6)]           0
#
#  conv1d_6 (Conv1D)           (None, 36, 256)           4864
#
#  conv1d_7 (Conv1D)           (None, 36, 256)           196864
#
#  conv1d_8 (Conv1D)           (None, 36, 256)           196864
#
#  global_average_pooling1d_2   (None, 256)              0
#  (GlobalAveragePooling1D)
#
#  dense_8 (Dense)             (None, 256)               65792
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 12)                1548
#
# =================================================================
# Total params: 515,340
# Trainable params: 515,340
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_test, y_test),
    #class_weight = class_weights,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=40, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=15, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/800
# 61/61 [==============================] - 3s 28ms/step - loss: 2.2283 - accuracy: 0.3043 - val_loss: 1.8838 - val_accuracy: 0.3868 - lr: 7.0000e-04
# Epoch 2/800
# 61/61 [==============================] - 1s 23ms/step - loss: 1.8380 - accuracy: 0.4059 - val_loss: 1.6397 - val_accuracy: 0.4527 - lr: 7.0000e-04
# Epoch 3/800
# 61/61 [==============================] - 1s 23ms/step - loss: 1.6058 - accuracy: 0.4664 - val_loss: 1.3953 - val_accuracy: 0.5329 - lr: 7.0000e-04
# Epoch 4/800
# 61/61 [==============================] - 1s 23ms/step - loss: 1.4422 - accuracy: 0.5161 - val_loss: 1.2784 - val_accuracy: 0.5473 - lr: 7.0000e-04
# Epoch 5/800
# 61/61 [==============================] - 1s 23ms/step - loss: 1.3186 - accuracy: 0.5569 - val_loss: 1.2136 - val_accuracy: 0.6070 - lr: 7.0000e-04
# Epoch 6/800
# 61/61 [==============================] - 1s 23ms/step - loss: 1.2232 - accuracy: 0.5987 - val_loss: 1.1359 - val_accuracy: 0.6276 - lr: 7.0000e-04
# Epoch 7/800
# 61/61 [==============================] - 1s 23ms/step - loss: 1.1336 - accuracy: 0.6213 - val_loss: 1.0798 - val_accuracy: 0.6337 - lr: 7.0000e-04
# Epoch 8/800
# 61/61 [==============================] - 1s 23ms/step - loss: 1.1026 - accuracy: 0.6424 - val_loss: 1.0702 - val_accuracy: 0.6399 - lr: 7.0000e-04
# Epoch 9/800
# 61/61 [==============================] - 1s 22ms/step - loss: 1.0924 - accuracy: 0.6409 - val_loss: 1.3097 - val_accuracy: 0.5988 - lr: 7.0000e-04
# Epoch 10/800
# 61/61 [==============================] - 1s 22ms/step - loss: 1.0289 - accuracy: 0.6613 - val_loss: 1.0104 - val_accuracy: 0.6584 - lr: 7.0000e-04
# Epoch 11/800
# 61/61 [==============================] - 1s 22ms/step - loss: 0.9630 - accuracy: 0.6801 - val_loss: 1.0538 - val_accuracy: 0.6543 - lr: 7.0000e-04
# Epoch 12/800
# 61/61 [==============================] - 1s 22ms/step - loss: 0.9492 - accuracy: 0.6897 - val_loss: 0.9905 - val_accuracy: 0.6605 - lr: 7.0000e-04
# Epoch 13/800
# 61/61 [==============================] - 1s 22ms/step - loss: 0.8968 - accuracy: 0.7043 - val_loss: 1.0173 - val_accuracy: 0.6564 - lr: 7.0000e-04
# Epoch 14/800
# 61/61 [==============================] - 1s 22ms/step - loss: 0.8413 - accuracy: 0.7207 - val_loss: 0.9407 - val_accuracy: 0.6728 - lr: 7.0000e-04
# Epoch 15/800
# 61/61 [==============================] - 1s 22ms/step - loss: 0.8188 - accuracy: 0.7271 - val_loss: 1.0113 - val_accuracy: 0.6461 - lr: 7.0000e-04
# Epoch 16/800
# 61/61 [==============================] - 1s 22ms/step - loss: 0.8060 - accuracy: 0.7310 - val_loss: 1.0172 - val_accuracy: 0.6770 - lr: 7.0000e-04
# Epoch 17/800
# 61/61 [==============================] - 1s 22ms/step - loss: 0.7601 - accuracy: 0.7442 - val_loss: 1.3454 - val_accuracy: 0.6584 - lr: 7.0000e-04
# Epoch 18/800
# 61/61 [==============================] - 1s 22ms/step - loss: 0.8810 - accuracy: 0.7057 - val_loss: 1.0433 - val_accuracy: 0.6687 - lr: 7.0000e-04
# Epoch 19/800
# 61/61 [==============================] - 1s 22ms/step - loss: 0.7669 - accuracy: 0.7464 - val_loss: 0.9605 - val_accuracy: 0.6687 - lr: 7.0000e-04
# Epoch 20/800
# 61/61 [==============================] - 1s 23ms/step - loss: 0.6768 - accuracy: 0.7728 - val_loss: 1.1193 - val_accuracy: 0.6708 - lr: 7.0000e-04
# Epoch 21/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.6768 - accuracy: 0.7779 - val_loss: 0.9736 - val_accuracy: 0.6893 - lr: 7.0000e-04
# Epoch 22/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.6474 - accuracy: 0.7822 - val_loss: 0.9981 - val_accuracy: 0.6893 - lr: 7.0000e-04
# Epoch 23/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.5702 - accuracy: 0.8051 - val_loss: 0.9978 - val_accuracy: 0.6996 - lr: 7.0000e-04
# Epoch 24/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.5269 - accuracy: 0.8233 - val_loss: 1.0668 - val_accuracy: 0.7119 - lr: 7.0000e-04
# Epoch 25/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.5130 - accuracy: 0.8300 - val_loss: 1.0790 - val_accuracy: 0.6975 - lr: 7.0000e-04
# Epoch 26/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.4854 - accuracy: 0.8369 - val_loss: 1.1318 - val_accuracy: 0.6914 - lr: 7.0000e-04
# Epoch 27/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.4544 - accuracy: 0.8462 - val_loss: 1.2229 - val_accuracy: 0.7119 - lr: 7.0000e-04
# Epoch 28/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.4170 - accuracy: 0.8605 - val_loss: 1.3184 - val_accuracy: 0.6996 - lr: 7.0000e-04
# Epoch 29/800
# 61/61 [==============================] - 1s 23ms/step - loss: 0.4052 - accuracy: 0.8641 - val_loss: 1.3140 - val_accuracy: 0.6893 - lr: 7.0000e-04
# Epoch 30/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.3600 - accuracy: 0.8810 - val_loss: 1.5028 - val_accuracy: 0.6914 - lr: 7.0000e-04
# Epoch 31/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.3615 - accuracy: 0.8792 - val_loss: 1.4632 - val_accuracy: 0.6934 - lr: 7.0000e-04
# Epoch 32/800
# 61/61 [==============================] - 1s 23ms/step - loss: 0.3328 - accuracy: 0.8905 - val_loss: 1.4875 - val_accuracy: 0.7037 - lr: 7.0000e-04
# Epoch 33/800
# 61/61 [==============================] - 1s 23ms/step - loss: 0.3921 - accuracy: 0.8740 - val_loss: 1.7125 - val_accuracy: 0.6955 - lr: 7.0000e-04
# Epoch 34/800
# 61/61 [==============================] - 1s 23ms/step - loss: 0.5095 - accuracy: 0.8397 - val_loss: 1.3362 - val_accuracy: 0.6914 - lr: 7.0000e-04
# Epoch 35/800
# 61/61 [==============================] - 1s 23ms/step - loss: 0.3410 - accuracy: 0.8847 - val_loss: 1.5505 - val_accuracy: 0.6852 - lr: 7.0000e-04
# Epoch 36/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.3116 - accuracy: 0.8967 - val_loss: 1.6257 - val_accuracy: 0.6914 - lr: 7.0000e-04
# Epoch 37/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.2596 - accuracy: 0.9161 - val_loss: 1.5703 - val_accuracy: 0.6893 - lr: 7.0000e-04
# Epoch 38/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.2456 - accuracy: 0.9193 - val_loss: 1.6129 - val_accuracy: 0.6934 - lr: 7.0000e-04
# Epoch 39/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.2830 - accuracy: 0.9103 - val_loss: 2.2363 - val_accuracy: 0.6770 - lr: 7.0000e-04
# Epoch 40/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.2033 - accuracy: 0.9317 - val_loss: 1.8957 - val_accuracy: 0.6914 - lr: 3.5000e-04
# Epoch 41/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1822 - accuracy: 0.9390 - val_loss: 1.8225 - val_accuracy: 0.6852 - lr: 3.5000e-04
# Epoch 42/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1740 - accuracy: 0.9439 - val_loss: 1.9698 - val_accuracy: 0.6749 - lr: 3.5000e-04
# Epoch 43/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1612 - accuracy: 0.9470 - val_loss: 2.1207 - val_accuracy: 0.6667 - lr: 3.5000e-04
# Epoch 44/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1554 - accuracy: 0.9489 - val_loss: 2.1333 - val_accuracy: 0.6811 - lr: 3.5000e-04
# Epoch 45/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1462 - accuracy: 0.9550 - val_loss: 2.1362 - val_accuracy: 0.7058 - lr: 3.5000e-04
# Epoch 46/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1393 - accuracy: 0.9551 - val_loss: 2.2077 - val_accuracy: 0.6852 - lr: 3.5000e-04
# Epoch 47/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1253 - accuracy: 0.9604 - val_loss: 2.2970 - val_accuracy: 0.6790 - lr: 3.5000e-04
# Epoch 48/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1314 - accuracy: 0.9582 - val_loss: 2.2830 - val_accuracy: 0.6831 - lr: 3.5000e-04
# Epoch 49/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1176 - accuracy: 0.9631 - val_loss: 2.3267 - val_accuracy: 0.7078 - lr: 3.5000e-04
# Epoch 50/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1284 - accuracy: 0.9579 - val_loss: 2.2033 - val_accuracy: 0.6934 - lr: 3.5000e-04
# Epoch 51/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1090 - accuracy: 0.9660 - val_loss: 2.3522 - val_accuracy: 0.6914 - lr: 3.5000e-04
# Epoch 52/800
# 61/61 [==============================] - 1s 25ms/step - loss: 0.1084 - accuracy: 0.9656 - val_loss: 2.2967 - val_accuracy: 0.6872 - lr: 3.5000e-04
# Epoch 53/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1042 - accuracy: 0.9690 - val_loss: 2.4512 - val_accuracy: 0.6790 - lr: 3.5000e-04
# Epoch 54/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.1146 - accuracy: 0.9615 - val_loss: 2.4291 - val_accuracy: 0.6831 - lr: 3.5000e-04
# Epoch 55/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.0817 - accuracy: 0.9752 - val_loss: 2.4748 - val_accuracy: 0.6955 - lr: 1.7500e-04
# Epoch 56/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.0767 - accuracy: 0.9768 - val_loss: 2.5850 - val_accuracy: 0.6893 - lr: 1.7500e-04
# Epoch 57/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.0730 - accuracy: 0.9785 - val_loss: 2.7079 - val_accuracy: 0.7016 - lr: 1.7500e-04
# Epoch 58/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.0705 - accuracy: 0.9784 - val_loss: 2.6278 - val_accuracy: 0.6996 - lr: 1.7500e-04
# Epoch 59/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.0745 - accuracy: 0.9765 - val_loss: 2.6629 - val_accuracy: 0.6955 - lr: 1.7500e-04
# Epoch 60/800
# 61/61 [==============================] - 1s 25ms/step - loss: 0.0718 - accuracy: 0.9786 - val_loss: 2.6252 - val_accuracy: 0.6955 - lr: 1.7500e-04
# Epoch 61/800
# 61/61 [==============================] - 2s 25ms/step - loss: 0.0706 - accuracy: 0.9779 - val_loss: 2.6827 - val_accuracy: 0.6728 - lr: 1.7500e-04
# Epoch 62/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.0705 - accuracy: 0.9797 - val_loss: 2.7839 - val_accuracy: 0.6770 - lr: 1.7500e-04
# Epoch 63/800
# 61/61 [==============================] - 1s 24ms/step - loss: 0.0650 - accuracy: 0.9812 - val_loss: 2.7398 - val_accuracy: 0.6914 - lr: 1.7500e-04
# Epoch 64/800
# 61/61 [==============================] - 2s 25ms/step - loss: 0.0635 - accuracy: 0.9816 - val_loss: 2.8462 - val_accuracy: 0.6790 - lr: 1.7500e-04

# %% [markdown]
# Convolutional model evaluation

# %%
plot_history(history)

# Predict the test set with the LSTM
predictions = model.predict(X_test)

plot_statistics(predictions)
# Out:
# 16/16 [==============================] - 1s 15ms/step
# d:\Programs\Anaconda\envs\anndl\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.7119
# Precision: 0.6607
# Recall: 0.5574
# F1: 0.5883

# %% [markdown]
# Save model with the validation accuracy in the name

# %%
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
if (accuracy > 0.75):
    model_name = "model_convdense_" + str(accuracy.round(5))
    model.save(model_name)
    
    shutil.make_archive(model_name, 'zip', model_name)
    FileLink(r"" + model_name + ".zip")
