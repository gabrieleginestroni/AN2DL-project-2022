# %% [markdown]
# # Code for competition

# %% [markdown]
# Libraries imports and initializations

# %%
import tensorflow as tf
import numpy as np
import os, os.path
import random
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#import visualkeras

tfk = tf.keras
tfkl = tf.keras.layers
print(f"Tensorflow version = ", tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
# Out:
# Tensorflow version =  2.10.0
# Num GPUs Available:  1

# %% [markdown]
# Load the dataset

# %%
samples = []
targets = []

images_ind = [186, 532, 515, 511, 531, 222, 537, 508]

# for each species
for i in range(0, len(images_ind)):
    # for each image in every species folder
    for j in range(0, images_ind[i]):
        temp = Image.open(f'training_data_final/Species{i + 1}/{j:05}.jpg').convert('RGB')
        image = np.squeeze(np.expand_dims(temp, axis=0))
        label = tfk.utils.to_categorical(i, len(images_ind))
        samples.append(image)
        targets.append(label)

# creation of augmented dataset 
X = np.array(samples)
y = np.array(targets, dtype=np.uint8)
print(X.shape, y.shape)
print(X.dtype, y.dtype, sep=", ")
# Out:
# (3542, 96, 96, 3) (3542, 8)
# uint8, uint8

# %% [markdown]
# Models metadata

# %%
input_shape = X.shape[1:]
image_shape = input_shape[:-1]

batch_size = 128 # TODO: try with other batch sizes and check the difference in accuracy and GPU utilization
epochs = 400
labels = ["Species1", "Species2", "Species3", "Species4", "Species5", "Species6", "Species7", "Species8"]

# %% [markdown]
# ### Static augmentation

# %%
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y], np.int32), return_counts=True)

#shows classes imbalance
plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# %% [markdown]
# Split the dataset (85-15) before augmentation

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, test_size=0.15)
class_weight = {0: 10.,
                1: 1.,
                2: 1.,
                3: 1.,
                4: 1.,
                5: 10.,
                6: 1.,
                7: 10.,}
print(f"training set input shape", X_train.shape, y_train.shape)
print(f"validation set input shape", X_val.shape, y_val.shape)
print(y_train[0])
# Out:
# training set input shape (3010, 96, 96, 3) (3010, 8)
# validation set input shape (532, 96, 96, 3) (532, 8)
# [0 0 0 0 1 0 0 0]

# %%
# image transformations generator for the training set ONLY
gen = ImageDataGenerator(rotation_range = 90,
                         height_shift_range = 20,
                         width_shift_range = 20,
                         horizontal_flip = True,
                         vertical_flip = True,
                         zoom_range = 0.3, # added zoom range
                         fill_mode = 'reflect')

# number of images to reach for each category in the training set
desired_amount = 700

ref_list = []
aug_samples = []
aug_targets = []

for i in range(0, len(classes)):
    ref_list.append([])
  
for i in range(0, len(y_train)):
    ref_list[np.argmax(y_train[i])].append(X_train[i])

for i in range(0, len(classes)):
    length = len(ref_list[i])
    to_produce = desired_amount - length
    target = tfk.utils.to_categorical(i, len(classes))
    print(f'Computing {to_produce} augmented images for target {i}')

    # produces images and corresponding targets
    aug_targets_i = np.full((length, len(classes)), target)
    aug_gen_i = gen.flow(np.array(ref_list[i]), 
                         aug_targets_i,
                         batch_size=1,
                         seed=seed,
                         shuffle=True)

    # augmented data samples
    for j in range(0, to_produce):
        aug_samples.append(np.squeeze(next(aug_gen_i)[0]))
        aug_targets.append(target)

# augmented dataset
X_aug_train = np.concatenate((X_train, np.array(aug_samples, dtype=np.uint8)))
y_aug_train = np.concatenate((y_train, np.array(aug_targets, dtype=np.uint8)))
print(X_aug_train.shape, y_aug_train.shape)
print(X_aug_train.dtype, y_aug_train.dtype, sep=", ")
print(y_aug_train[0])
# Out:
# Computing 542 augmented images for target 0
# Computing 248 augmented images for target 1
# Computing 262 augmented images for target 2
# Computing 266 augmented images for target 3
# Computing 249 augmented images for target 4
# Computing 511 augmented images for target 5
# Computing 244 augmented images for target 6
# Computing 268 augmented images for target 7
# (5600, 96, 96, 3) (5600, 8)
# uint8, uint8
# [0 0 0 0 1 0 0 0]

# %% [markdown]
# Showing a few examples of augmented images, one image per class

# %%
num_row = 2
num_col = 4
fig, axes = plt.subplots(num_row, num_col)
for i in range(num_row * num_col):

    # show a random augmented image -> not working 
    img = random.choice(aug_samples)
    ax = axes[i//num_col, i%num_col]
    ax.imshow(Image.fromarray(img.astype(np.uint8)))
    #ax.set_title(labels[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Dataset balanced and shuffled

# %%
# counts of the number of samples per each class after the rebalance
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y_aug_train], np.int32), return_counts=True)

plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# probably not needed, wrote this just in case
X_aug_train, y_aug_train = shuffle(X_aug_train, y_aug_train)

# %%
# Plot y_val histogram
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y_val], np.int32), return_counts=True)

plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# %% [markdown]
# ### Models definition
#
# Convolutional model defined as a stack of some convolution layers, max pooling, gap and dropout layers.
#
# Fully connected dense layers stacked after the convolutional layers, with no regularization applied. 5 layers of 128 neurons each

# %%
def build_conv_dense_model(input_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    x = tfkl.Conv2D(
        filters = 32,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv1')(input_layer)
    
    x = tfkl.MaxPooling2D(pool_size = (2, 2))(x)

    x = tfkl.Conv2D(
        filters = 64,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv2')(x)
    
    x = tfkl.MaxPooling2D(pool_size = (2, 2))(x)

    x = tfkl.Conv2D(
        filters = 128,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'Conv3')(x)
    
    x = tfkl.GlobalAveragePooling2D()(x)

    x = tfkl.Dropout(0.3, seed=seed, name='dropout1')(x)
    
    #x = tfkl.Dropout(0.2, seed=seed, name='gap_dropout')(x)

    # end of convolutional layers
    # start of the fully connected layers
    
    
    
    x = tfkl.Dense(
        units = 96,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense1')(x)

    x = tfkl.Dropout(0.3, seed=seed, name='dropout2')(x)

    output_layer = tfkl.Dense(
        units = len(labels), 
        activation = 'softmax', 
        kernel_initializer = tfk.initializers.GlorotUniform(seed),
        name = 'output_layer')(x)
    
    # Connect input and output through the Model class
    model = tfk.Model(inputs = input_layer, outputs = output_layer, name = 'conv_dense_model_v1')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %% [markdown]
# # First attempt: Hold Out validation

# %% [markdown]
# Train the model

# %%
# first convolutional model
model = build_conv_dense_model(input_shape)

model.summary()

#visualkeras.layered_view(model, legend=True, spacing=20, scale_xy=10)
# Out:
# Model: "conv_dense_model_v1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 96, 96, 3)]       0
#
#  conv1 (Conv2D)              (None, 96, 96, 32)        896
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  conv2 (Conv2D)              (None, 48, 48, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  Conv3 (Conv2D)              (None, 24, 24, 128)       73856
#
#  global_average_pooling2d_1   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  dropout1 (Dropout)          (None, 128)               0
#
#  dense1 (Dense)              (None, 96)                12384
#
#  dropout2 (Dropout)          (None, 96)                0
#
#  output_layer (Dense)        (None, 8)                 776
#
# =================================================================
# Total params: 106,408
# Trainable params: 106,408
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training
history = model.fit(
    x = X_aug_train,
    y = y_aug_train,
    class_weight=class_weight,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val, y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=30, restore_best_weights=True)]
).history
# Out:
# Epoch 1/400
# 44/44 [==============================] - 2s 39ms/step - loss: 246.6994 - accuracy: 0.1346 - val_loss: 2.7646 - val_accuracy: 0.1391
# Epoch 2/400
# 44/44 [==============================] - 2s 35ms/step - loss: 7.8870 - accuracy: 0.1545 - val_loss: 2.4575 - val_accuracy: 0.1485
# Epoch 3/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.9511 - accuracy: 0.1659 - val_loss: 2.4146 - val_accuracy: 0.1278
# Epoch 4/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.7180 - accuracy: 0.1771 - val_loss: 2.3379 - val_accuracy: 0.1335
# Epoch 5/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.6178 - accuracy: 0.1777 - val_loss: 2.3374 - val_accuracy: 0.1485
# Epoch 6/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.5514 - accuracy: 0.1786 - val_loss: 2.4594 - val_accuracy: 0.1504
# Epoch 7/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.5222 - accuracy: 0.1721 - val_loss: 2.4220 - val_accuracy: 0.1541
# Epoch 8/400
# 44/44 [==============================] - 2s 34ms/step - loss: 6.4013 - accuracy: 0.1841 - val_loss: 2.2935 - val_accuracy: 0.1410
# Epoch 9/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.2789 - accuracy: 0.1961 - val_loss: 2.2485 - val_accuracy: 0.1579
# Epoch 10/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.3200 - accuracy: 0.1929 - val_loss: 2.2592 - val_accuracy: 0.1429
# Epoch 11/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.2596 - accuracy: 0.1988 - val_loss: 2.1177 - val_accuracy: 0.1579
# Epoch 12/400
# 44/44 [==============================] - 2s 34ms/step - loss: 6.1528 - accuracy: 0.2084 - val_loss: 2.1612 - val_accuracy: 0.1429
# Epoch 13/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.1013 - accuracy: 0.2055 - val_loss: 2.2193 - val_accuracy: 0.1466
# Epoch 14/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.0460 - accuracy: 0.2139 - val_loss: 2.2175 - val_accuracy: 0.1372
# Epoch 15/400
# 44/44 [==============================] - 2s 35ms/step - loss: 6.0341 - accuracy: 0.2259 - val_loss: 2.0545 - val_accuracy: 0.2124
# Epoch 16/400
# 44/44 [==============================] - 2s 34ms/step - loss: 5.9710 - accuracy: 0.2255 - val_loss: 2.1144 - val_accuracy: 0.1898
# Epoch 17/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.8871 - accuracy: 0.2355 - val_loss: 2.0526 - val_accuracy: 0.2124
# Epoch 18/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.8735 - accuracy: 0.2411 - val_loss: 2.2948 - val_accuracy: 0.1447
# Epoch 19/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.8634 - accuracy: 0.2493 - val_loss: 2.1434 - val_accuracy: 0.1711
# Epoch 20/400
# 44/44 [==============================] - 2s 34ms/step - loss: 5.7693 - accuracy: 0.2377 - val_loss: 2.2501 - val_accuracy: 0.1898
# Epoch 21/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.7200 - accuracy: 0.2584 - val_loss: 1.9337 - val_accuracy: 0.2162
# Epoch 22/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.6690 - accuracy: 0.2584 - val_loss: 1.8863 - val_accuracy: 0.2237
# Epoch 23/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.5708 - accuracy: 0.2670 - val_loss: 2.1200 - val_accuracy: 0.1861
# Epoch 24/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.5239 - accuracy: 0.2727 - val_loss: 1.9172 - val_accuracy: 0.2481
# Epoch 25/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.5361 - accuracy: 0.2721 - val_loss: 1.9328 - val_accuracy: 0.1974
# Epoch 26/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.5069 - accuracy: 0.2621 - val_loss: 1.8754 - val_accuracy: 0.2481
# Epoch 27/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.4806 - accuracy: 0.2670 - val_loss: 1.9888 - val_accuracy: 0.2293
# Epoch 28/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.5309 - accuracy: 0.2670 - val_loss: 1.9933 - val_accuracy: 0.2218
# Epoch 29/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.4044 - accuracy: 0.2754 - val_loss: 1.9168 - val_accuracy: 0.2331
# Epoch 30/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.3327 - accuracy: 0.2868 - val_loss: 1.9999 - val_accuracy: 0.2199
# Epoch 31/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.3887 - accuracy: 0.2893 - val_loss: 2.1081 - val_accuracy: 0.1917
# Epoch 32/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.4099 - accuracy: 0.2939 - val_loss: 2.1214 - val_accuracy: 0.2105
# Epoch 33/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.4021 - accuracy: 0.2752 - val_loss: 1.9343 - val_accuracy: 0.2575
# Epoch 34/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.2989 - accuracy: 0.2980 - val_loss: 1.9354 - val_accuracy: 0.2500
# Epoch 35/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.2789 - accuracy: 0.2998 - val_loss: 1.8202 - val_accuracy: 0.2650
# Epoch 36/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.1313 - accuracy: 0.2912 - val_loss: 1.7365 - val_accuracy: 0.3158
# Epoch 37/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.1524 - accuracy: 0.3034 - val_loss: 1.8745 - val_accuracy: 0.2932
# Epoch 38/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.9961 - accuracy: 0.3136 - val_loss: 1.9068 - val_accuracy: 0.2444
# Epoch 39/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.1161 - accuracy: 0.3014 - val_loss: 1.8503 - val_accuracy: 0.2707
# Epoch 40/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.9763 - accuracy: 0.3229 - val_loss: 1.9647 - val_accuracy: 0.2556
# Epoch 41/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.0252 - accuracy: 0.3113 - val_loss: 1.8088 - val_accuracy: 0.2575
# Epoch 42/400
# 44/44 [==============================] - 2s 35ms/step - loss: 5.0460 - accuracy: 0.3107 - val_loss: 1.7908 - val_accuracy: 0.2914
# Epoch 43/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.8169 - accuracy: 0.3268 - val_loss: 1.7464 - val_accuracy: 0.3120
# Epoch 44/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.8316 - accuracy: 0.3352 - val_loss: 1.9452 - val_accuracy: 0.2594
# Epoch 45/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.7798 - accuracy: 0.3323 - val_loss: 1.7636 - val_accuracy: 0.3252
# Epoch 46/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.6941 - accuracy: 0.3523 - val_loss: 2.0627 - val_accuracy: 0.2425
# Epoch 47/400
# 44/44 [==============================] - 2s 34ms/step - loss: 4.7792 - accuracy: 0.3250 - val_loss: 1.7892 - val_accuracy: 0.3177
# Epoch 48/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.7386 - accuracy: 0.3296 - val_loss: 1.6849 - val_accuracy: 0.2970
# Epoch 49/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.6635 - accuracy: 0.3439 - val_loss: 2.1086 - val_accuracy: 0.2237
# Epoch 50/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.5721 - accuracy: 0.3318 - val_loss: 1.6423 - val_accuracy: 0.3628
# Epoch 51/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.5667 - accuracy: 0.3393 - val_loss: 1.7004 - val_accuracy: 0.3496
# Epoch 52/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.3688 - accuracy: 0.3632 - val_loss: 1.7252 - val_accuracy: 0.3665
# Epoch 53/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.4884 - accuracy: 0.3611 - val_loss: 1.8831 - val_accuracy: 0.2932
# Epoch 54/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.3780 - accuracy: 0.3616 - val_loss: 1.8986 - val_accuracy: 0.2820
# Epoch 55/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.3951 - accuracy: 0.3491 - val_loss: 1.7790 - val_accuracy: 0.2951
# Epoch 56/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.3761 - accuracy: 0.3686 - val_loss: 1.5406 - val_accuracy: 0.4417
# Epoch 57/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.2966 - accuracy: 0.3598 - val_loss: 1.5348 - val_accuracy: 0.3910
# Epoch 58/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.2776 - accuracy: 0.3595 - val_loss: 1.7863 - val_accuracy: 0.3177
# Epoch 59/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.1595 - accuracy: 0.3707 - val_loss: 1.5792 - val_accuracy: 0.3496
# Epoch 60/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.0960 - accuracy: 0.3884 - val_loss: 1.5807 - val_accuracy: 0.3891
# Epoch 61/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.0218 - accuracy: 0.3907 - val_loss: 1.5712 - val_accuracy: 0.3853
# Epoch 62/400
# 44/44 [==============================] - 2s 35ms/step - loss: 4.1580 - accuracy: 0.3809 - val_loss: 1.8597 - val_accuracy: 0.3026
# Epoch 63/400
# 44/44 [==============================] - 2s 35ms/step - loss: 3.9513 - accuracy: 0.3982 - val_loss: 1.7275 - val_accuracy: 0.3590
# Epoch 64/400
# 44/44 [==============================] - 2s 35ms/step - loss: 3
400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1984 - accuracy: 0.6875 - val_loss: 1.2955 - val_accuracy: 0.5602
# Epoch 154/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.2145 - accuracy: 0.6845 - val_loss: 1.3078 - val_accuracy: 0.5564
# Epoch 155/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.2280 - accuracy: 0.6882 - val_loss: 1.3470 - val_accuracy: 0.5583
# Epoch 156/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1382 - accuracy: 0.7041 - val_loss: 1.3629 - val_accuracy: 0.5564
# Epoch 157/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1373 - accuracy: 0.7020 - val_loss: 1.3561 - val_accuracy: 0.5620
# Epoch 158/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.2569 - accuracy: 0.6811 - val_loss: 1.3340 - val_accuracy: 0.5263
# Epoch 159/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1511 - accuracy: 0.7009 - val_loss: 1.3549 - val_accuracy: 0.5451
# Epoch 160/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1259 - accuracy: 0.7098 - val_loss: 1.3847 - val_accuracy: 0.5395
# Epoch 161/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1869 - accuracy: 0.6975 - val_loss: 1.4175 - val_accuracy: 0.5226
# Epoch 162/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1518 - accuracy: 0.7014 - val_loss: 1.2829 - val_accuracy: 0.5451
# Epoch 163/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0892 - accuracy: 0.7084 - val_loss: 1.3340 - val_accuracy: 0.5526
# Epoch 164/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0882 - accuracy: 0.7216 - val_loss: 1.3399 - val_accuracy: 0.5489
# Epoch 165/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0807 - accuracy: 0.7214 - val_loss: 1.4464 - val_accuracy: 0.5113
# Epoch 166/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0941 - accuracy: 0.7071 - val_loss: 1.3939 - val_accuracy: 0.5320
# Epoch 167/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1324 - accuracy: 0.7091 - val_loss: 1.4669 - val_accuracy: 0.4981
# Epoch 168/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1044 - accuracy: 0.7100 - val_loss: 1.4243 - val_accuracy: 0.5376
# Epoch 169/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9927 - accuracy: 0.7270 - val_loss: 1.4112 - val_accuracy: 0.5508
# Epoch 170/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1099 - accuracy: 0.7102 - val_loss: 1.4115 - val_accuracy: 0.5301
# Epoch 171/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0920 - accuracy: 0.7120 - val_loss: 1.2922 - val_accuracy: 0.5583
# Epoch 172/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0113 - accuracy: 0.7286 - val_loss: 1.3554 - val_accuracy: 0.5489
# Epoch 173/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0165 - accuracy: 0.7218 - val_loss: 1.3790 - val_accuracy: 0.5602
# Epoch 174/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8849 - accuracy: 0.7443 - val_loss: 1.3171 - val_accuracy: 0.5789
# Epoch 175/400
# 44/44 [==============================] - 2s 34ms/step - loss: 1.0061 - accuracy: 0.7246 - val_loss: 1.4687 - val_accuracy: 0.5038
# Epoch 176/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0236 - accuracy: 0.7189 - val_loss: 1.3760 - val_accuracy: 0.5639
# Epoch 177/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9591 - accuracy: 0.7364 - val_loss: 1.4068 - val_accuracy: 0.5395
# Epoch 178/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0652 - accuracy: 0.7248 - val_loss: 1.4740 - val_accuracy: 0.5094
# Epoch 179/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1198 - accuracy: 0.7177 - val_loss: 1.3940 - val_accuracy: 0.5695
# Epoch 180/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0261 - accuracy: 0.7391 - val_loss: 1.4379 - val_accuracy: 0.5451
# Epoch 181/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9970 - accuracy: 0.7330 - val_loss: 1.3398 - val_accuracy: 0.5451
# Epoch 182/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9961 - accuracy: 0.7218 - val_loss: 1.4710 - val_accuracy: 0.5489
# Epoch 183/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0229 - accuracy: 0.7309 - val_loss: 1.4309 - val_accuracy: 0.5263
# Epoch 184/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8886 - accuracy: 0.7452 - val_loss: 1.6367 - val_accuracy: 0.5414
# Epoch 185/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0270 - accuracy: 0.7332 - val_loss: 1.3484 - val_accuracy: 0.5489
# Epoch 186/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9544 - accuracy: 0.7357 - val_loss: 1.4583 - val_accuracy: 0.5432
# Epoch 187/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9466 - accuracy: 0.7480 - val_loss: 1.4538 - val_accuracy: 0.5451
# Epoch 188/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.0436 - accuracy: 0.7327 - val_loss: 1.4797 - val_accuracy: 0.5695
# Epoch 189/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9010 - accuracy: 0.7432 - val_loss: 1.4485 - val_accuracy: 0.5395
# Epoch 190/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8467 - accuracy: 0.7538 - val_loss: 1.4618 - val_accuracy: 0.5489
# Epoch 191/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7837 - accuracy: 0.7688 - val_loss: 1.5006 - val_accuracy: 0.5414
# Epoch 192/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7973 - accuracy: 0.7721 - val_loss: 1.3882 - val_accuracy: 0.5695
# Epoch 193/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7887 - accuracy: 0.7768 - val_loss: 1.4230 - val_accuracy: 0.5695
# Epoch 194/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9895 - accuracy: 0.7441 - val_loss: 1.5649 - val_accuracy: 0.4850
# Epoch 195/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9909 - accuracy: 0.7445 - val_loss: 1.5247 - val_accuracy: 0.5489
# Epoch 196/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9807 - accuracy: 0.7396 - val_loss: 1.4431 - val_accuracy: 0.5639
# Epoch 197/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9366 - accuracy: 0.7502 - val_loss: 1.4089 - val_accuracy: 0.5959
# Epoch 198/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7799 - accuracy: 0.7791 - val_loss: 1.4289 - val_accuracy: 0.5808
# Epoch 199/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7648 - accuracy: 0.7829 - val_loss: 1.4409 - val_accuracy: 0.5583
# Epoch 200/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8482 - accuracy: 0.7613 - val_loss: 1.4613 - val_accuracy: 0.5432
# Epoch 201/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8340 - accuracy: 0.7748 - val_loss: 1.4552 - val_accuracy: 0.5752
# Epoch 202/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8509 - accuracy: 0.7550 - val_loss: 1.4220 - val_accuracy: 0.5564
# Epoch 203/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7586 - accuracy: 0.7764 - val_loss: 1.5545 - val_accuracy: 0.5508
# Epoch 204/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7425 - accuracy: 0.7798 - val_loss: 1.5327 - val_accuracy: 0.5583
# Epoch 205/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7856 - accuracy: 0.7871 - val_loss: 1.4488 - val_accuracy: 0.5733
# Epoch 206/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8101 - accuracy: 0.7757 - val_loss: 1.5212 - val_accuracy: 0.5508
# Epoch 207/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9111 - accuracy: 0.7564 - val_loss: 1.6178 - val_accuracy: 0.5207
# Epoch 208/400
# 44/44 [==============================] - 2s 35ms/step - loss: 1.1149 - accuracy: 0.7284 - val_loss: 1.5209 - val_accuracy: 0.5301
# Epoch 209/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8327 - accuracy: 0.7696 - val_loss: 1.5390 - val_accuracy: 0.5639
# Epoch 210/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8436 - accuracy: 0.7695 - val_loss: 1.4039 - val_accuracy: 0.5489
# Epoch 211/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7353 - accuracy: 0.7889 - val_loss: 1.4073 - val_accuracy: 0.5771
# Epoch 212/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.6286 - accuracy: 0.8111 - val_loss: 1.4596 - val_accuracy: 0.5789
# Epoch 213/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.6512 - accuracy: 0.8021 - val_loss: 1.4089 - val_accuracy: 0.5808
# Epoch 214/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.6309 - accuracy: 0.8080 - val_loss: 1.5374 - val_accuracy: 0.5733
# Epoch 215/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.6925 - accuracy: 0.8004 - val_loss: 1.5294 - val_accuracy: 0.5639
# Epoch 216/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8133 - accuracy: 0.7809 - val_loss: 1.5554 - val_accuracy: 0.5526
# Epoch 217/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8855 - accuracy: 0.7723 - val_loss: 1.4342 - val_accuracy: 0.5564
# Epoch 218/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.9933 - accuracy: 0.7600 - val_loss: 1.5227 - val_accuracy: 0.5620
# Epoch 219/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.8769 - accuracy: 0.7629 - val_loss: 1.4575 - val_accuracy: 0.5620
# Epoch 220/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.6956 - accuracy: 0.7929 - val_loss: 1.5677 - val_accuracy: 0.5301
# Epoch 221/400
# 44/44 [==============================] - 2s 34ms/step - loss: 0.7114 - accuracy: 0.7984 - val_loss: 1.5377 - val_accuracy: 0.5733
# Epoch 222/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7111 - accuracy: 0.8046 - val_loss: 1.3973 - val_accuracy: 0.5789
# Epoch 223/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7420 - accuracy: 0.7955 - val_loss: 1.4627 - val_accuracy: 0.5376
# Epoch 224/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.6689 - accuracy: 0.8086 - val_loss: 1.5348 - val_accuracy: 0.5846
# Epoch 225/400
# 44/44 [==============================] - 2s 34ms/step - loss: 0.7722 - accuracy: 0.7905 - val_loss: 1.5330 - val_accuracy: 0.5639
# Epoch 226/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.7108 - accuracy: 0.8014 - val_loss: 1.5251 - val_accuracy: 0.5752
# Epoch 227/400
# 44/44 [==============================] - 2s 35ms/step - loss: 0.6744 - accuracy: 0.8114 - val_loss: 1.5824 - val_accuracy: 0.5677

# %% [markdown]
# ### Plot training results

# %%
plt.figure(figsize=(15,5))
plt.plot(history['loss'], label='Std training', alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Std validation', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], label='Std training', alpha=.8, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Std validation', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper right')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %% [markdown]
# Plot the confusion matrix (evaluated on the validation set)

# %%
predictions = model.predict(X_val)
cm = confusion_matrix(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))

accuracy = accuracy_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print(f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average=None))
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

plt.figure(figsize=(6,5.5))
sns.heatmap(cm.T, xticklabels=labels, yticklabels=labels)
plt.ylabel('True labels')
plt.xlabel('Predicted labels')
plt.show()
# Out:
# 17/17 [==============================] - 0s 3ms/step
# [0.38297872 0.63414634 0.60402685 0.5        0.60645161 0.62686567
#  0.75496689 0.5380117 ]
# Accuracy: 0.5959
# Precision: 0.5928
# Recall: 0.576
# F1: 0.5809

# %% [markdown]
# Plot one example of an image for each class from the validation set of images.
# For each image show the prediction on a bar plot

# %%
#TODO: fix this code
example_prediction = random.choice(X_val[0])
'''
fig, axes = plt.subplots(8,2)
fig.set_size_inches(10,20)
for i in range(8):

	# TODO: find random choice from validation set, one per class

	axes[i, 0].imshow(X_val[choice])
	axes[i, 0].set_title('True label: ' + labels[np.argmax(y_val[choice])])
	axes[i, 1].barh(list(labels.values()), predictions[prediction_index], color=plt.get_cmap('Paired').colors)
	axes[i, 1].set_title('Predicted label: '+labels[np.argmax(predictions[prediction_index])])
	axes[i, 1].grid(alpha=.3)


plt.show()
'''
# Out:
# "\nfig, axes = plt.subplots(8,2)\nfig.set_size_inches(10,20)\nfor i in range(8):\n\n\t# TODO: find random choice from validation set, one per class\n\n\taxes[i, 0].imshow(X_val[choice])\n\taxes[i, 0].set_title('True label: ' + labels[np.argmax(y_val[choice])])\n\taxes[i, 1].barh(list(labels.values()), predictions[prediction_index], color=plt.get_cmap('Paired').colors)\n\taxes[i, 1].set_title('Predicted label: '+labels[np.argmax(predictions[prediction_index])])\n\taxes[i, 1].grid(alpha=.3)\n\n\nplt.show()\n"

# %% [markdown]
# ### Save the model
#
# Here it is not working

# %%
restored_model = tfk.models.load_model('simo_model')

#TODO: not right because validation set can change
restored_loss, restored_acc = restored_model.evaluate(X_val, y_val, verbose=2)
loss, acc = model.evaluate(X_val, y_val, verbose=2)
if acc > restored_acc:  # know that this is conceptually wrong
    print("Model improved!")
    model.save('simo_model')
else:
    print("No improvement!")
# Out:
# 17/17 - 0s - loss: 0.2023 - accuracy: 0.9229 - 393ms/epoch - 23ms/step
# 17/17 - 0s - loss: 1.4089 - accuracy: 0.5959 - 71ms/epoch - 4ms/step
# No improvement!
