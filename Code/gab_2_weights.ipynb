# %% [markdown]
# # Code for competition

# %% [markdown]
# Libraries imports and initializations

# %%
import tensorflow as tf
import numpy as np
import os, os.path
import random
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
#import visualkeras

tfk = tf.keras
tfkl = tf.keras.layers
print(f"Tensorflow version = ", tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
# Out:
# Tensorflow version =  2.10.0
# Num GPUs Available:  1

# %% [markdown]
# Load the dataset

# %%
samples = []
targets = []

images_ind = [186, 532, 515, 511, 531, 222, 537, 508]

# for each species
for i in range(0, len(images_ind)):
    # for each image in every species folder
    for j in range(0, images_ind[i]):
        temp = Image.open(f'training_data_final/Species{i + 1}/{j:05}.jpg').convert('RGB')
        image = np.squeeze(np.expand_dims(temp, axis=0))
        label = tfk.utils.to_categorical(i, len(images_ind))
        samples.append(image)
        targets.append(label)

# creation of augmented dataset 
X = np.array(samples)
y = np.array(targets, dtype=np.uint8)
print(X.shape, y.shape)
print(X.dtype, y.dtype, sep=", ")
# Out:
# (3542, 96, 96, 3) (3542, 8)
# uint8, uint8

# %% [markdown]
# Models metadata

# %%
input_shape = X.shape[1:]
image_shape = input_shape[:-1]

batch_size = 128 # TODO: try with other batch sizes and check the difference in accuracy and GPU utilization
epochs = 400
labels = ["Species1", "Species2", "Species3", "Species4", "Species5", "Species6", "Species7", "Species8"]

# %% [markdown]
# ### Static augmentation

# %%
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y], np.int32), return_counts=True)

#shows classes imbalance
plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# %% [markdown]
# Split the dataset (85-15) before augmentation

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, test_size=0.15)
y_numeric = []
for v in y:
    y_numeric.append(np.argmax(v))
'''class_weights_vect = class_weight.compute_class_weight('balanced', classes=classes, y=y_numeric)'''
'''class_weights = dict(enumerate(class_weights_vect))'''
class_weights_vect = [3.,1.,1.,1.,1.,3.,1.,3.]
class_weights = dict(enumerate(class_weights_vect))
print(class_weights)
print(f"training set input shape", X_train.shape, y_train.shape)
print(f"validation set input shape", X_val.shape, y_val.shape)
print(y_train[0])
# Out:
# {0: 3.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: 3.0, 6: 1.0, 7: 3.0}
# training set input shape (3010, 96, 96, 3) (3010, 8)
# validation set input shape (532, 96, 96, 3) (532, 8)
# [0 0 0 0 1 0 0 0]

# %%
# image transformations generator for the training set ONLY
gen = ImageDataGenerator(rotation_range = 90,
                         height_shift_range = 30,
                         width_shift_range = 30,
                         horizontal_flip = True,
                         zoom_range=[0.7,1.5], # added zoom range
                         fill_mode = 'reflect'
                         )

#compute number of images to reach for each category in the training set
required_expansion = 800

ref_list = []
aug_samples = []
aug_targets = []

for i in range(0, len(classes)):
    ref_list.append([])
  
for i in range(0, len(y_train)):
    ref_list[np.argmax(y_train[i])].append(X_train[i])

for i in range(0, len(classes)):
    length = len(ref_list[i])
    to_produce = int(class_weights_vect[i] * required_expansion) 
    target = tfk.utils.to_categorical(i, len(classes))
    print(f'Computing {to_produce} augmented images for target {i}')

    # produces images and corresponding targets
    aug_targets_i = np.full((length, len(classes)), target)
    aug_gen_i = gen.flow(np.array(ref_list[i]), 
                         aug_targets_i,
                         batch_size=1,
                         seed=seed,
                         shuffle=True)

    # augmented data samples
    for j in range(0, to_produce):
        aug_samples.append(np.squeeze(next(aug_gen_i)[0]))
        aug_targets.append(target)

# augmented dataset
X_aug_train = np.concatenate((X_train, np.array(aug_samples)))
y_aug_train = np.concatenate((y_train, np.array(aug_targets)))

print(X_aug_train.shape, y_aug_train.shape)
print(X_aug_train.dtype, y_aug_train.dtype, sep=", ")
print(y_aug_train[0])
#adjusting both saturation and constrast of both training and validation
temp = []
for img in X_aug_train: 
    temp.append(np.array(tf.image.adjust_contrast(tf.image.adjust_saturation(img, 1.55), 1.01)))
X_aug_train = np.array(temp)
temp = []
for img in X_val: 
    temp.append(np.array(tf.image.adjust_contrast(tf.image.adjust_saturation(img, 1.55), 1.01)))
X_val = np.array(temp)
# Out:
# Computing 2400 augmented images for target 0
# Computing 800 augmented images for target 1
# Computing 800 augmented images for target 2
# Computing 800 augmented images for target 3
# Computing 800 augmented images for target 4
# Computing 2400 augmented images for target 5
# Computing 800 augmented images for target 6
# Computing 2400 augmented images for target 7
# (14210, 96, 96, 3) (14210, 8)
# float32, float32
# [0. 0. 0. 0. 1. 0. 0. 0.]
# 'temp = []\nfor img in X_aug_train: \n    temp.append(np.array(tf.image.adjust_contrast(tf.image.adjust_saturation(img, 1.55), 1.01)))\nX_aug_train = np.array(temp)\ntemp = []\nfor img in X_val: \n    temp.append(np.array(tf.image.adjust_contrast(tf.image.adjust_saturation(img, 1.55), 1.01)))\nX_val = np.array(temp)\n'

# %% [markdown]
# Showing a few examples of augmented images, one image per class

# %%
num_row = 2
num_col = 4
fig, axes = plt.subplots(num_row, num_col)
for i in range(num_row * num_col):

    # show a random augmented image -> not working 
    img = random.choice(X_aug_train)
    ax = axes[i//num_col, i%num_col]
    ax.imshow(Image.fromarray(img.astype(np.uint8)))
    #ax.set_title(labels[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Dataset balanced and shuffled

# %%
# counts of the number of samples per each class after the rebalance
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y_aug_train], np.int32), return_counts=True)

plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# probably not needed, wrote this just in case
X_aug_train, y_aug_train = shuffle(X_aug_train, y_aug_train)

# %%
# Plot y_val histogram
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y_val], np.int32), return_counts=True)

plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# %% [markdown]
# ### Models definition
#
# Convolutional model defined as a stack of some convolution layers, max pooling, gap and dropout layers.
#
# Fully connected dense layers stacked after the convolutional layers, with no regularization applied. 5 layers of 128 neurons each

# %%
def build_model(input_shape):
    tf.random.set_seed(seed)

    #Load the supernet
    supernet = tfk.applications.InceptionV3(include_top=False,
                                            weights="imagenet",
                                            input_shape=input_shape)
    
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')
    
    x = supernet(input_layer)

    x = tfkl.GlobalAveragePooling2D(name='gap')(x)

    x = tfkl.Flatten()(x)
    
    x = tfkl.Dense(
        units = 512,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense1')(x)

    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense2')(x)

    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense3')(x)

    x = tfkl.Dense(
        units = 128,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense4')(x)

    x = tfkl.Dense(
        units = 128,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense5')(x)
    
    x = tfkl.Dropout(0.2, seed=seed, name='dropout')(x)

    output_layer = tfkl.Dense(
        units = len(labels), 
        activation = 'softmax', 
        kernel_initializer = tfk.initializers.GlorotUniform(seed),
        name = 'output_layer')(x)
    
    # Connect input and output through the Model class
    model = tfk.Model(inputs = input_layer, outputs = output_layer, name = 'tl_model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %% [markdown]
# # First attempt: Hold Out validation

# %% [markdown]
# Train the model

# %%
# first convolutional model
model = build_model(input_shape)

# Use the supernet only as feature extractor (eventually apply fine tuning)
model.get_layer('inception_v3').trainable = True
for i, layer in enumerate(model.get_layer('inception_v3').layers[:-25]):
  layer.trainable=False
  
model.summary()
#visualkeras.layered_view(model, legend=True, spacing=20, scale_xy=10)
# Out:
# Model: "tl_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 96, 96, 3)]       0
#
#  inception_v3 (Functional)   (None, 1, 1, 2048)        21802784
#
#  gap (GlobalAveragePooling2D  (None, 2048)             0
#  )
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense1 (Dense)              (None, 512)               1049088
#
#  dense2 (Dense)              (None, 256)               131328
#
#  dense3 (Dense)              (None, 256)               65792
#
#  dense4 (Dense)              (None, 128)               32896
#
#  dense5 (Dense)              (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  output_layer (Dense)        (None, 8)                 1032
#
# =================================================================
# Total params: 23,099,432
# Trainable params: 7,617,992
# Non-trainable params: 15,481,440
# _________________________________________________________________

# %%
from tensorflow.keras.applications.inception_v3 import preprocess_input
X_train_tl = np.array(preprocess_input(X_aug_train))
X_val_tl = np.array(preprocess_input(X_val))

# training
history = model.fit(
    x = X_train_tl,
    y = y_aug_train,
    class_weight= class_weights,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val_tl, y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=50, restore_best_weights=True)]
).history
# Out:
# Epoch 1/400
# 112/112 [==============================] - 25s 171ms/step - loss: 1.9166 - accuracy: 0.2338 - val_loss: 2.3875 - val_accuracy: 0.1541
# Epoch 2/400
# 112/112 [==============================] - 18s 160ms/step - loss: 1.5106 - accuracy: 0.4067 - val_loss: 13.8486 - val_accuracy: 0.3252
# Epoch 3/400
# 112/112 [==============================] - 18s 160ms/step - loss: 1.2397 - accuracy: 0.5070 - val_loss: 4.6853 - val_accuracy: 0.3440
# Epoch 4/400
# 112/112 [==============================] - 18s 159ms/step - loss: 1.0849 - accuracy: 0.5806 - val_loss: 9.9355 - val_accuracy: 0.3214
# Epoch 5/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.9130 - accuracy: 0.6618 - val_loss: 2.5233 - val_accuracy: 0.4568
# Epoch 6/400
# 112/112 [==============================] - 18s 164ms/step - loss: 0.7981 - accuracy: 0.7208 - val_loss: 2.0230 - val_accuracy: 0.4643
# Epoch 7/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.7587 - accuracy: 0.7419 - val_loss: 1.7640 - val_accuracy: 0.4605
# Epoch 8/400
# 112/112 [==============================] - 18s 164ms/step - loss: 0.6440 - accuracy: 0.7799 - val_loss: 1.3924 - val_accuracy: 0.6391
# Epoch 9/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.4832 - accuracy: 0.8409 - val_loss: 1.3446 - val_accuracy: 0.5940
# Epoch 10/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.7044 - accuracy: 0.7714 - val_loss: 30.7599 - val_accuracy: 0.2820
# Epoch 11/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.5461 - accuracy: 0.8189 - val_loss: 1.2263 - val_accuracy: 0.6654
# Epoch 12/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.4197 - accuracy: 0.8669 - val_loss: 1.3289 - val_accuracy: 0.6898
# Epoch 13/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.3535 - accuracy: 0.8896 - val_loss: 1.8659 - val_accuracy: 0.5695
# Epoch 14/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.2790 - accuracy: 0.9151 - val_loss: 1.1756 - val_accuracy: 0.6560
# Epoch 15/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.2658 - accuracy: 0.9191 - val_loss: 2.9860 - val_accuracy: 0.4286
# Epoch 16/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.4341 - accuracy: 0.8681 - val_loss: 2.3061 - val_accuracy: 0.6053
# Epoch 17/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.2456 - accuracy: 0.9247 - val_loss: 1.2438 - val_accuracy: 0.7105
# Epoch 18/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.2483 - accuracy: 0.9232 - val_loss: 1.1978 - val_accuracy: 0.7105
# Epoch 19/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.1652 - accuracy: 0.9501 - val_loss: 3.1946 - val_accuracy: 0.4925
# Epoch 20/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.1431 - accuracy: 0.9575 - val_loss: 1.9139 - val_accuracy: 0.6053
# Epoch 21/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.5568 - accuracy: 0.8243 - val_loss: 145.1141 - val_accuracy: 0.0677
# Epoch 22/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.6517 - accuracy: 0.7901 - val_loss: 4.3680 - val_accuracy: 0.3402
# Epoch 23/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.3239 - accuracy: 0.8961 - val_loss: 1.5575 - val_accuracy: 0.6316
# Epoch 24/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.2571 - accuracy: 0.9253 - val_loss: 203.1120 - val_accuracy: 0.2312
# Epoch 25/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.3969 - accuracy: 0.8723 - val_loss: 1.9699 - val_accuracy: 0.5996
# Epoch 26/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.2007 - accuracy: 0.9420 - val_loss: 2.9018 - val_accuracy: 0.4267
# Epoch 27/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.1795 - accuracy: 0.9476 - val_loss: 1.5907 - val_accuracy: 0.6673
# Epoch 28/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.3895 - accuracy: 0.8864 - val_loss: 1.7687 - val_accuracy: 0.5902
# Epoch 29/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.3329 - accuracy: 0.9013 - val_loss: 2.3211 - val_accuracy: 0.5789
# Epoch 30/400
# 112/112 [==============================] - 18s 163ms/step - loss: 0.2038 - accuracy: 0.9378 - val_loss: 1.4504 - val_accuracy: 0.7444
# Epoch 31/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.1419 - accuracy: 0.9569 - val_loss: 1.1672 - val_accuracy: 0.7801
# Epoch 32/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0993 - accuracy: 0.9709 - val_loss: 1.3977 - val_accuracy: 0.7068
# Epoch 33/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0798 - accuracy: 0.9743 - val_loss: 1.8976 - val_accuracy: 0.6974
# Epoch 34/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0693 - accuracy: 0.9802 - val_loss: 1.5996 - val_accuracy: 0.7218
# Epoch 35/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0632 - accuracy: 0.9825 - val_loss: 1.3874 - val_accuracy: 0.7556
# Epoch 36/400
# 112/112 [==============================] - 18s 163ms/step - loss: 0.0492 - accuracy: 0.9854 - val_loss: 0.9650 - val_accuracy: 0.7895
# Epoch 37/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0476 - accuracy: 0.9866 - val_loss: 1.2321 - val_accuracy: 0.7726
# Epoch 38/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0980 - accuracy: 0.9735 - val_loss: 1.3632 - val_accuracy: 0.7444
# Epoch 39/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.1149 - accuracy: 0.9692 - val_loss: 1.4307 - val_accuracy: 0.7256
# Epoch 40/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0670 - accuracy: 0.9831 - val_loss: 2.0835 - val_accuracy: 0.6617
# Epoch 41/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.1296 - accuracy: 0.9653 - val_loss: 3.0130 - val_accuracy: 0.6447
# Epoch 42/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.1689 - accuracy: 0.9517 - val_loss: 1.4385 - val_accuracy: 0.7218
# Epoch 43/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.1012 - accuracy: 0.9686 - val_loss: 1.2627 - val_accuracy: 0.6974
# Epoch 44/400
# 112/112 [==============================] - 18s 163ms/step - loss: 0.0886 - accuracy: 0.9714 - val_loss: 1.7422 - val_accuracy: 0.7068
# Epoch 45/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0828 - accuracy: 0.9760 - val_loss: 1.0641 - val_accuracy: 0.7726
# Epoch 46/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0544 - accuracy: 0.9828 - val_loss: 0.9879 - val_accuracy: 0.7876
# Epoch 47/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.1056 - accuracy: 0.9681 - val_loss: 1.8130 - val_accuracy: 0.6748
# Epoch 48/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0924 - accuracy: 0.9726 - val_loss: 1.0635 - val_accuracy: 0.7556
# Epoch 49/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0533 - accuracy: 0.9818 - val_loss: 2.2587 - val_accuracy: 0.5226
# Epoch 50/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0530 - accuracy: 0.9847 - val_loss: 1.8110 - val_accuracy: 0.6936
# Epoch 51/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0256 - accuracy: 0.9920 - val_loss: 1.0293 - val_accuracy: 0.8102
# Epoch 52/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0263 - accuracy: 0.9930 - val_loss: 0.9964 - val_accuracy: 0.8045
# Epoch 53/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0893 - accuracy: 0.9785 - val_loss: 5.1660 - val_accuracy: 0.4511
# Epoch 54/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0943 - accuracy: 0.9734 - val_loss: 1.5123 - val_accuracy: 0.7049
# Epoch 55/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0422 - accuracy: 0.9877 - val_loss: 1.5370 - val_accuracy: 0.7256
# Epoch 56/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0817 - accuracy: 0.9774 - val_loss: 1.9449 - val_accuracy: 0.6391
# Epoch 57/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0743 - accuracy: 0.9786 - val_loss: 2.1149 - val_accuracy: 0.6692
# Epoch 58/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0353 - accuracy: 0.9904 - val_loss: 1.2623 - val_accuracy: 0.7744
# Epoch 59/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0563 - accuracy: 0.9853 - val_loss: 2.1288 - val_accuracy: 0.6391
# Epoch 60/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0554 - accuracy: 0.9852 - val_loss: 1.5207 - val_accuracy: 0.7387
# Epoch 61/400
# 112/112 [==============================] - 18s 163ms/step - loss: 0.0387 - accuracy: 0.9901 - val_loss: 1.3457 - val_accuracy: 0.7556
# Epoch 62/400
# 112/112 [==============================] - 18s 163ms/step - loss: 0.0636 - accuracy: 0.9829 - val_loss: 1.7546 - val_accuracy: 0.6786
# Epoch 63/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0301 - accuracy: 0.9913 - val_loss: 2.3902 - val_accuracy: 0.6673
# Epoch 64/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0937 - accuracy: 0.9751 - val_loss: 1.3474 - val_accuracy: 0.7538
# Epoch 65/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0327 - accuracy: 0.9909 - val_loss: 1.7940 - val_accuracy: 0.7030
# Epoch 66/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0345 - accuracy: 0.9902 - val_loss: 2.0095 - val_accuracy: 0.6729
# Epoch 67/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.2276 - accuracy: 0.9328 - val_loss: 1.5628 - val_accuracy: 0.6635
# Epoch 68/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0619 - accuracy: 0.9823 - val_loss: 1.5016 - val_accuracy: 0.7237
# Epoch 69/400
# 112/112 [==============================] - 18s 163ms/step - loss: 0.0405 - accuracy: 0.9879 - val_loss: 1.3790 - val_accuracy: 0.7462
# Epoch 70/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0538 - accuracy: 0.9863 - val_loss: 2.1440 - val_accuracy: 0.6748
# Epoch 71/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0816 - accuracy: 0.9790 - val_loss: 1.7080 - val_accuracy: 0.7237
# Epoch 72/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.0209 - accuracy: 0.9939 - val_loss: 1.0928 - val_accuracy: 0.8026
# Epoch 73/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.0308 - accuracy: 0.9913 - val_loss: 1.5865 - val_accuracy: 0.7538
# Epoch 74/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.5089 - accuracy: 0.8471 - val_loss: 1.7626 - val_accuracy: 0.5583
# Epoch 75/400
# 112/112 [==============================] - 18s 157ms/step - loss: 0.2463 - accuracy: 0.9230 - val_loss: 1.4150 - val_accuracy: 0.6128
# Epoch 76/400
# 112/112 [==============================] - 18s 157ms/step - loss: 0.1125 - accuracy: 0.9665 - val_loss: 1.1010 - val_accuracy: 0.7744
# Epoch 77/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0504 - accuracy: 0.9859 - val_loss: 1.1333 - val_accuracy: 0.7481
# Epoch 78/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0977 - accuracy: 0.9719 - val_loss: 3.8602 - val_accuracy: 0.4568
# Epoch 79/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0409 - accuracy: 0.9888 - val_loss: 2.0670 - val_accuracy: 0.6748
# Epoch 80/400
# 112/112 [==============================] - 18s 163ms/step - loss: 0.0645 - accuracy: 0.9820 - val_loss: 0.8316 - val_accuracy: 0.8214
# Epoch 81/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0330 - accuracy: 0.9898 - val_loss: 3.7953 - val_accuracy: 0.4624
# Epoch 82/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0565 - accuracy: 0.9823 - val_loss: 1.1547 - val_accuracy: 0.7801
# Epoch 83/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.1196 - accuracy: 0.9668 - val_loss: 0.9748 - val_accuracy: 0.8233
# Epoch 84/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.0472 - accuracy: 0.9859 - val_loss: 0.9969 - val_accuracy: 0.8177
# Epoch 85/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 1.2495 - val_accuracy: 0.8008
# Epoch 86/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.0285 - accuracy: 0.9951 - val_loss: 1.2992 - val_accuracy: 0.7876
# Epoch 87/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.2345 - accuracy: 0.9328 - val_loss: 2.3925 - val_accuracy: 0.4868
# Epoch 88/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.1953 - accuracy: 0.9426 - val_loss: 2.0825 - val_accuracy: 0.6410
# Epoch 89/400
# 112/112 [==============================] - 18s 157ms/step - loss: 0.0904 - accuracy: 0.9716 - val_loss: 1.1099 - val_accuracy: 0.7914
# Epoch 90/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.0483 - accuracy: 0.9853 - val_loss: 1.7182 - val_accuracy: 0.7425
# Epoch 91/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.0223 - accuracy: 0.9938 - val_loss: 1.0010 - val_accuracy: 0.8177
# Epoch 92/400
# 112/112 [==============================] - 18s 159ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 1.0151 - val_accuracy: 0.8271
# Epoch 93/400
# 112/112 [==============================] - 18s 159ms/step - loss: 0.0378 - accuracy: 0.9901 - val_loss: 1.7395 - val_accuracy: 0.7105
# Epoch 94/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0284 - accuracy: 0.9931 - val_loss: 1.2451 - val_accuracy: 0.7763
# Epoch 95/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 1.0955 - val_accuracy: 0.8214
# Epoch 96/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0181 - accuracy: 0.9953 - val_loss: 1.6569 - val_accuracy: 0.7256
# Epoch 97/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 1.0886 - val_accuracy: 0.8139
# Epoch 98/400
# 112/112 [==============================] - 18s 159ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 1.4849 - val_accuracy: 0.7575
# Epoch 99/400
# 112/112 [==============================] - 18s 159ms/step - loss: 0.0161 - accuracy: 0.9952 - val_loss: 1.6696 - val_accuracy: 0.7632
# Epoch 100/400
# 112/112 [==============================] - 18s 159ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 1.6158 - val_accuracy: 0.7970
# Epoch 101/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0164 - accuracy: 0.9949 - val_loss: 1.2117 - val_accuracy: 0.7782
# Epoch 102/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0210 - accuracy: 0.9937 - val_loss: 1.3823 - val_accuracy: 0.7613
# Epoch 103/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0142 - accuracy: 0.9961 - val_loss: 1.8173 - val_accuracy: 0.7312
# Epoch 104/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0173 - accuracy: 0.9949 - val_loss: 1.6438 - val_accuracy: 0.7444
# Epoch 105/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0187 - accuracy: 0.9942 - val_loss: 2.2126 - val_accuracy: 0.6673
# Epoch 106/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0183 - accuracy: 0.9944 - val_loss: 1.4616 - val_accuracy: 0.7650
# Epoch 107/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0146 - accuracy: 0.9958 - val_loss: 2.0259 - val_accuracy: 0.6842
# Epoch 108/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0449 - accuracy: 0.9870 - val_loss: 1.4773 - val_accuracy: 0.7556
# Epoch 109/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0226 - accuracy: 0.9939 - val_loss: 1.1731 - val_accuracy: 0.7895
# Epoch 110/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0220 - accuracy: 0.9932 - val_loss: 1.7679 - val_accuracy: 0.6805
# Epoch 111/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0184 - accuracy: 0.9948 - val_loss: 1.2513 - val_accuracy: 0.7707
# Epoch 112/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0195 - accuracy: 0.9950 - val_loss: 2.1779 - val_accuracy: 0.6316
# Epoch 113/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0184 - accuracy: 0.9948 - val_loss: 1.8541 - val_accuracy: 0.7688
# Epoch 114/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0255 - accuracy: 0.9928 - val_loss: 1.2918 - val_accuracy: 0.7519
# Epoch 115/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0290 - accuracy: 0.9925 - val_loss: 2.7552 - val_accuracy: 0.6711
# Epoch 116/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.1716 - accuracy: 0.9493 - val_loss: 3.1333 - val_accuracy: 0.3891
# Epoch 117/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.1442 - accuracy: 0.9571 - val_loss: 1.7693 - val_accuracy: 0.6541
# Epoch 118/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0856 - accuracy: 0.9781 - val_loss: 1.5993 - val_accuracy: 0.6654
# Epoch 119/400
# 112/112 [==============================] - 18s 163ms/step - loss: 0.0434 - accuracy: 0.9873 - val_loss: 1.0312 - val_accuracy: 0.7989
# Epoch 120/400
# 112/112 [==============================] - 18s 163ms/step - loss: 0.0335 - accuracy: 0.9916 - val_loss: 1.5556 - val_accuracy: 0.7331
# Epoch 121/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0254 - accuracy: 0.9923 - val_loss: 1.2207 - val_accuracy: 0.7914
# Epoch 122/400
# 112/112 [==============================] - 18s 159ms/step - loss: 0.0238 - accuracy: 0.9946 - val_loss: 1.2811 - val_accuracy: 0.7782
# Epoch 123/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0121 - accuracy: 0.9969 - val_loss: 1.1493 - val_accuracy: 0.7951
# Epoch 124/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0166 - accuracy: 0.9961 - val_loss: 1.2478 - val_accuracy: 0.7838
# Epoch 125/400
# 112/112 [==============================] - 18s 160ms/step - loss: 0.0151 - accuracy: 0.9961 - val_loss: 1.5310 - val_accuracy: 0.7462
# Epoch 126/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0124 - accuracy: 0.9964 - val_loss: 1.2465 - val_accuracy: 0.7895
# Epoch 127/400
# 112/112 [==============================] - 18s 163ms/step - loss: 0.0220 - accuracy: 0.9938 - val_loss: 1.4354 - val_accuracy: 0.7613
# Epoch 128/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0291 - accuracy: 0.9928 - val_loss: 1.7609 - val_accuracy: 0.7143
# Epoch 129/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0208 - accuracy: 0.9941 - val_loss: 1.2486 - val_accuracy: 0.7989
# Epoch 130/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0243 - accuracy: 0.9944 - val_loss: 1.2156 - val_accuracy: 0.7970
# Epoch 131/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0230 - accuracy: 0.9939 - val_loss: 1.3277 - val_accuracy: 0.7519
# Epoch 132/400
# 112/112 [==============================] - 18s 162ms/step - loss: 0.0227 - accuracy: 0.9939 - val_loss: 1.5543 - val_accuracy: 0.7594
# Epoch 133/400
# 112/112 [==============================] - 18s 159ms/step - loss: 0.0478 - accuracy: 0.9878 - val_loss: 1.0230 - val_accuracy: 0.7820
# Epoch 134/400
# 112/112 [==============================] - 18s 159ms/step - loss: 0.0207 - accuracy: 0.9943 - val_loss: 0.9880 - val_accuracy: 0.8195
# Epoch 135/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 1.2090 - val_accuracy: 0.8158
# Epoch 136/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.0275 - accuracy: 0.9926 - val_loss: 1.3644 - val_accuracy: 0.7857
# Epoch 137/400
# 112/112 [==============================] - 18s 159ms/step - loss: 0.0110 - accuracy: 0.9976 - val_loss: 2.1450 - val_accuracy: 0.6842
# Epoch 138/400
# 112/112 [==============================] - 17s 156ms/step - loss: 0.0342 - accuracy: 0.9897 - val_loss: 2.3626 - val_accuracy: 0.7162
# Epoch 139/400
# 112/112 [==============================] - 18s 157ms/step - loss: 0.0386 - accuracy: 0.9907 - val_loss: 1.6736 - val_accuracy: 0.6617
# Epoch 140/400
# 112/112 [==============================] - 18s 157ms/step - loss: 0.8011 - accuracy: 0.7443 - val_loss: 2.2466 - val_accuracy: 0.4211
# Epoch 141/400
# 112/112 [==============================] - 18s 158ms/step - loss: 0.3933 - accuracy: 0.8754 - val_loss: 1.1991 - val_accuracy: 0.7350
# Epoch 142/400
# 112/112 [==============================] - 18s 161ms/step - loss: 0.1505 - accuracy: 0.9541 - val_loss: 1.2059 - val_accuracy: 0.7312

# %% [markdown]
# ### Plot training results

# %%
plt.figure(figsize=(15,5))
plt.plot(history['loss'], label='Std training', alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Std validation', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], label='Std training', alpha=.8, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Std validation', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper right')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %% [markdown]
# Plot the confusion matrix (evaluated on the validation set)

# %%
predictions = model.predict(X_val_tl)
cm = confusion_matrix(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))

accuracy = accuracy_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print(f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average=None))
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

plt.figure(figsize=(6,5.5))
sns.heatmap(cm.T, xticklabels=labels, yticklabels=labels)
plt.ylabel('True labels')
plt.xlabel('Predicted labels')
plt.show()
# Out:
# 17/17 [==============================] - 1s 20ms/step
# [0.49275362 0.85897436 0.87012987 0.81081081 0.8625     0.81690141
#  0.93506494 0.77631579]
# Accuracy: 0.8271
# Precision: 0.8
# Recall: 0.8126
# F1: 0.8029

# %% [markdown]
# Plot one example of an image for each class from the validation set of images.
# For each image show the prediction on a bar plot

# %%
#TODO: fix this code
example_prediction = random.choice(X_val[0])
'''
fig, axes = plt.subplots(8,2)
fig.set_size_inches(10,20)
for i in range(8):

	# TODO: find random choice from validation set, one per class

	axes[i, 0].imshow(X_val[choice])
	axes[i, 0].set_title('True label: ' + labels[np.argmax(y_val[choice])])
	axes[i, 1].barh(list(labels.values()), predictions[prediction_index], color=plt.get_cmap('Paired').colors)
	axes[i, 1].set_title('Predicted label: '+labels[np.argmax(predictions[prediction_index])])
	axes[i, 1].grid(alpha=.3)


plt.show()
'''
# Out:
# "\nfig, axes = plt.subplots(8,2)\nfig.set_size_inches(10,20)\nfor i in range(8):\n\n\t# TODO: find random choice from validation set, one per class\n\n\taxes[i, 0].imshow(X_val[choice])\n\taxes[i, 0].set_title('True label: ' + labels[np.argmax(y_val[choice])])\n\taxes[i, 1].barh(list(labels.values()), predictions[prediction_index], color=plt.get_cmap('Paired').colors)\n\taxes[i, 1].set_title('Predicted label: '+labels[np.argmax(predictions[prediction_index])])\n\taxes[i, 1].grid(alpha=.3)\n\n\nplt.show()\n"

# %% [markdown]
# ### Save the model
#
# Here it is not working

# %%
restored_model = tfk.models.load_model('gab_model')

#TODO: not right because validation set can change
restored_loss, restored_acc = restored_model.evaluate(X_val, y_val, verbose=2)
loss, acc = model.evaluate(X_val_tl, y_val, verbose=2)
if acc > restored_acc:  # know that this is conceptually wrong
    print("Model improved!")
    model.save('gab_model_tl_new')
else:
    print("No improvement!")
# Out:
# 17/17 - 0s - loss: 3.1280 - accuracy: 0.4436 - 417ms/epoch - 25ms/step
# 17/17 - 0s - loss: 1.0151 - accuracy: 0.8271 - 386ms/epoch - 23ms/step
# Model improved!
