# %% [markdown]
# # Code for competition

# %% [markdown]
# Libraries imports and initializations

# %%
import tensorflow as tf
import numpy as np
import os, os.path
import random
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
#import visualkeras

tfk = tf.keras
tfkl = tf.keras.layers
print(f"Tensorflow version = ", tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
# Out:
# Tensorflow version =  2.10.0
# Num GPUs Available:  1

# %% [markdown]
# Load the dataset

# %%
samples = []
targets = []

images_ind = [186, 532, 515, 511, 531, 222, 537, 508]

# for each species
for i in range(0, len(images_ind)):
    # for each image in every species folder
    for j in range(0, images_ind[i]):
        temp = Image.open(f'training_data_final/Species{i + 1}/{j:05}.jpg').convert('RGB')
        image = np.squeeze(np.expand_dims(temp, axis=0))
        label = tfk.utils.to_categorical(i, len(images_ind))
        samples.append(image)
        targets.append(label)

# creation of augmented dataset 
X = np.array(samples)
y = np.array(targets, dtype=np.uint8)
print(X.shape, y.shape)
print(X.dtype, y.dtype, sep=", ")
# Out:
# (3542, 96, 96, 3) (3542, 8)
# uint8, uint8

# %% [markdown]
# Models metadata

# %%
input_shape = X.shape[1:]
image_shape = input_shape[:-1]

batch_size = 128 # TODO: try with other batch sizes and check the difference in accuracy and GPU utilization
epochs = 400
labels = ["Species1", "Species2", "Species3", "Species4", "Species5", "Species6", "Species7", "Species8"]

# %% [markdown]
# ### Static augmentation

# %%
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y], np.int32), return_counts=True)

#shows classes imbalance
plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# %% [markdown]
# Split the dataset (85-15) before augmentation

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, test_size=0.15)
y_numeric = []
for v in y:
    y_numeric.append(np.argmax(v))
'''class_weights_vect = class_weight.compute_class_weight('balanced', classes=classes, y=y_numeric)'''
'''class_weights = dict(enumerate(class_weights_vect))'''
class_weights_vect = [3.,1.,1.,1.,1.,3.,1.,3.]
class_weights = dict(enumerate(class_weights_vect))
print(class_weights)
print(f"training set input shape", X_train.shape, y_train.shape)
print(f"validation set input shape", X_val.shape, y_val.shape)
print(y_train[0])
# Out:
# {0: 3.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: 3.0, 6: 1.0, 7: 3.0}
# training set input shape (3010, 96, 96, 3) (3010, 8)
# validation set input shape (532, 96, 96, 3) (532, 8)
# [0 0 0 0 1 0 0 0]

# %%
# image transformations generator for the training set ONLY
gen = ImageDataGenerator(rotation_range = 90,
                         height_shift_range = 30,
                         width_shift_range = 30,
                         horizontal_flip = True,
                         zoom_range=[0.7,2], # added zoom range
                         fill_mode = 'reflect')

#compute number of images to reach for each category in the training set
required_expansion = 800

ref_list = []
aug_samples = []
aug_targets = []

for i in range(0, len(classes)):
    ref_list.append([])
  
for i in range(0, len(y_train)):
    ref_list[np.argmax(y_train[i])].append(X_train[i])

for i in range(0, len(classes)):
    length = len(ref_list[i])
    to_produce = int(class_weights_vect[i] * required_expansion) 
    target = tfk.utils.to_categorical(i, len(classes))
    print(f'Computing {to_produce} augmented images for target {i}')

    # produces images and corresponding targets
    aug_targets_i = np.full((length, len(classes)), target)
    aug_gen_i = gen.flow(np.array(ref_list[i]), 
                         aug_targets_i,
                         batch_size=1,
                         seed=seed,
                         shuffle=True)

    # augmented data samples
    for j in range(0, to_produce):
        aug_samples.append(np.squeeze(next(aug_gen_i)[0]))
        aug_targets.append(target)

# augmented dataset
X_aug_train = np.concatenate((X_train, np.array(aug_samples, dtype=np.uint8)))
y_aug_train = np.concatenate((y_train, np.array(aug_targets, dtype=np.uint8)))
print(X_aug_train.shape, y_aug_train.shape)
print(X_aug_train.dtype, y_aug_train.dtype, sep=", ")
print(y_aug_train[0])
#adjusting both saturation and constrast of both training and validation
temp = []
for img in X_aug_train: 
    temp.append(np.array(tf.image.adjust_contrast(tf.image.adjust_saturation(img, 1.55), 1.01)))
X_aug_train = np.array(temp)
temp = []
for img in X_val: 
    temp.append(np.array(tf.image.adjust_contrast(tf.image.adjust_saturation(img, 1.55), 1.01)))
X_val = np.array(temp)
# Out:
# Computing 2400 augmented images for target 0
# Computing 800 augmented images for target 1
# Computing 800 augmented images for target 2
# Computing 800 augmented images for target 3
# Computing 800 augmented images for target 4
# Computing 2400 augmented images for target 5
# Computing 800 augmented images for target 6
# Computing 2400 augmented images for target 7
# (14210, 96, 96, 3) (14210, 8)
# uint8, uint8
# [0 0 0 0 1 0 0 0]

# %% [markdown]
# Showing a few examples of augmented images, one image per class

# %%
num_row = 2
num_col = 4
fig, axes = plt.subplots(num_row, num_col)
for i in range(num_row * num_col):

    # show a random augmented image -> not working 
    img = random.choice(X_aug_train)
    ax = axes[i//num_col, i%num_col]
    ax.imshow(Image.fromarray(img.astype(np.uint8)))
    #ax.set_title(labels[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Dataset balanced and shuffled

# %%
# counts of the number of samples per each class after the rebalance
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y_aug_train], np.int32), return_counts=True)

plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# probably not needed, wrote this just in case
X_aug_train, y_aug_train = shuffle(X_aug_train, y_aug_train)

# %%
# Plot y_val histogram
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y_val], np.int32), return_counts=True)

plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# %% [markdown]
# ### Models definition
#
# Convolutional model defined as a stack of some convolution layers, max pooling, gap and dropout layers.
#
# Fully connected dense layers stacked after the convolutional layers, with no regularization applied. 5 layers of 128 neurons each

# %%
def build_conv_dense_model(input_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    x = tfkl.Conv2D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv1')(input_layer)
    
    x = tfkl.MaxPooling2D(name='mp1')(x)

    x = tfkl.Conv2D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv2')(x)
    
    x = tfkl.MaxPooling2D(name='mp2')(x)

    x = tfkl.Conv2D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'Conv3')(x)
    
    x = tfkl.GlobalAveragePooling2D(name='gap')(x)
    
    #x = tfkl.Dropout(0.2, seed=seed, name='gap_dropout')(x)

    # end of convolutional layers
    # start of the fully connected layers
    
    x = tfkl.Flatten()(x)
    
    x = tfkl.Dense(
        units = 512,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense1')(x)

    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense2')(x)

    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense3')(x)

    x = tfkl.Dense(
        units = 128,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense4')(x)

    

    x = tfkl.Dense(
        units = 128,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense5')(x)
    
    x = tfkl.Dropout(0.2, seed=seed)(x)

    output_layer = tfkl.Dense(
        units = len(labels), 
        activation = 'softmax', 
        kernel_initializer = tfk.initializers.GlorotUniform(seed),
        name = 'output_layer')(x)
    
    # Connect input and output through the Model class
    model = tfk.Model(inputs = input_layer, outputs = output_layer, name = 'conv_dense_model_v1')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %% [markdown]
# # First attempt: Hold Out validation

# %% [markdown]
# Train the model

# %%
# first convolutional model
model = build_conv_dense_model(input_shape)

model.summary()

#visualkeras.layered_view(model, legend=True, spacing=20, scale_xy=10)
# Out:
# Model: "conv_dense_model_v1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 96, 96, 3)]       0
#
#  conv1 (Conv2D)              (None, 96, 96, 256)       7168
#
#  mp1 (MaxPooling2D)          (None, 48, 48, 256)       0
#
#  conv2 (Conv2D)              (None, 48, 48, 256)       590080
#
#  mp2 (MaxPooling2D)          (None, 24, 24, 256)       0
#
#  Conv3 (Conv2D)              (None, 24, 24, 256)       590080
#
#  gap (GlobalAveragePooling2D  (None, 256)              0
#  )
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense1 (Dense)              (None, 512)               131584
#
#  dense2 (Dense)              (None, 256)               131328
#
#  dense3 (Dense)              (None, 256)               65792
#
#  dense4 (Dense)              (None, 128)               32896
#
#  dense5 (Dense)              (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  output_layer (Dense)        (None, 8)                 1032
#
# =================================================================
# Total params: 1,566,472
# Trainable params: 1,566,472
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input
X_train_tl = np.array(preprocess_input(X_aug_train), dtype=np.uint8)
X_val_tl = np.array(preprocess_input(X_val), dtype=np.uint8)

# training
history = model.fit(
    x = X_aug_train,
    y = y_aug_train,
    
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val, y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=30, restore_best_weights=True)]
).history
# Out:
# Epoch 1/400
# 112/112 [==============================] - 32s 219ms/step - loss: 48.1834 - accuracy: 0.1929 - val_loss: 1.9628 - val_accuracy: 0.2011
# Epoch 2/400
# 112/112 [==============================] - 23s 210ms/step - loss: 1.8883 - accuracy: 0.2707 - val_loss: 2.1639 - val_accuracy: 0.2105
# Epoch 3/400
# 112/112 [==============================] - 24s 210ms/step - loss: 1.7375 - accuracy: 0.3151 - val_loss: 1.7285 - val_accuracy: 0.3496
# Epoch 4/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.6604 - accuracy: 0.3579 - val_loss: 1.7086 - val_accuracy: 0.3477
# Epoch 5/400
# 112/112 [==============================] - 23s 210ms/step - loss: 1.5885 - accuracy: 0.3856 - val_loss: 1.6006 - val_accuracy: 0.4342
# Epoch 6/400
# 112/112 [==============================] - 24s 210ms/step - loss: 1.5198 - accuracy: 0.4191 - val_loss: 1.5323 - val_accuracy: 0.4380
# Epoch 7/400
# 112/112 [==============================] - 24s 210ms/step - loss: 1.4974 - accuracy: 0.4291 - val_loss: 1.8431 - val_accuracy: 0.3383
# Epoch 8/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.4907 - accuracy: 0.4393 - val_loss: 1.7636 - val_accuracy: 0.3741
# Epoch 9/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.3599 - accuracy: 0.4921 - val_loss: 1.7051 - val_accuracy: 0.3797
# Epoch 10/400
# 112/112 [==============================] - 24s 210ms/step - loss: 1.3636 - accuracy: 0.4822 - val_loss: 1.4817 - val_accuracy: 0.4492
# Epoch 11/400
# 112/112 [==============================] - 24s 210ms/step - loss: 1.2760 - accuracy: 0.5193 - val_loss: 1.6732 - val_accuracy: 0.3665
# Epoch 12/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.3465 - accuracy: 0.4873 - val_loss: 1.6132 - val_accuracy: 0.4455
# Epoch 13/400
# 112/112 [==============================] - 24s 210ms/step - loss: 1.2387 - accuracy: 0.5429 - val_loss: 1.3081 - val_accuracy: 0.5263
# Epoch 14/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.1599 - accuracy: 0.5673 - val_loss: 1.4196 - val_accuracy: 0.4737
# Epoch 15/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.1274 - accuracy: 0.5818 - val_loss: 1.3432 - val_accuracy: 0.5320
# Epoch 16/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.1111 - accuracy: 0.5844 - val_loss: 1.1306 - val_accuracy: 0.6034
# Epoch 17/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.0614 - accuracy: 0.6054 - val_loss: 1.2843 - val_accuracy: 0.5150
# Epoch 18/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.0802 - accuracy: 0.5959 - val_loss: 1.2263 - val_accuracy: 0.5620
# Epoch 19/400
# 112/112 [==============================] - 24s 211ms/step - loss: 0.9910 - accuracy: 0.6303 - val_loss: 2.1551 - val_accuracy: 0.3515
# Epoch 20/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.1318 - accuracy: 0.5854 - val_loss: 1.0846 - val_accuracy: 0.5714
# Epoch 21/400
# 112/112 [==============================] - 24s 211ms/step - loss: 0.9896 - accuracy: 0.6269 - val_loss: 2.2390 - val_accuracy: 0.3120
# Epoch 22/400
# 112/112 [==============================] - 23s 209ms/step - loss: 1.1709 - accuracy: 0.5669 - val_loss: 1.0592 - val_accuracy: 0.6128
# Epoch 23/400
# 112/112 [==============================] - 24s 211ms/step - loss: 0.9661 - accuracy: 0.6385 - val_loss: 1.1868 - val_accuracy: 0.5639
# Epoch 24/400
# 112/112 [==============================] - 24s 211ms/step - loss: 0.9634 - accuracy: 0.6472 - val_loss: 1.2060 - val_accuracy: 0.5846
# Epoch 25/400
# 112/112 [==============================] - 24s 214ms/step - loss: 1.0444 - accuracy: 0.6205 - val_loss: 1.0977 - val_accuracy: 0.5959
# Epoch 26/400
# 112/112 [==============================] - 24s 214ms/step - loss: 0.8924 - accuracy: 0.6724 - val_loss: 1.2225 - val_accuracy: 0.5752
# Epoch 27/400
# 112/112 [==============================] - 24s 213ms/step - loss: 1.0049 - accuracy: 0.6303 - val_loss: 1.5910 - val_accuracy: 0.4906
# Epoch 28/400
# 112/112 [==============================] - 24s 211ms/step - loss: 1.0121 - accuracy: 0.6311 - val_loss: 1.0354 - val_accuracy: 0.6391
# Epoch 29/400
# 112/112 [==============================] - 24s 211ms/step - loss: 0.8752 - accuracy: 0.6802 - val_loss: 2.5310 - val_accuracy: 0.4361
# Epoch 30/400
# 112/112 [==============================] - 23s 208ms/step - loss: 1.2987 - accuracy: 0.5425 - val_loss: 1.0699 - val_accuracy: 0.5865
# Epoch 31/400
# 112/112 [==============================] - 24s 210ms/step - loss: 0.9193 - accuracy: 0.6635 - val_loss: 2.7060 - val_accuracy: 0.3008
# Epoch 32/400
# 112/112 [==============================] - 24s 213ms/step - loss: 1.2578 - accuracy: 0.5254 - val_loss: 1.1628 - val_accuracy: 0.5752
# Epoch 33/400
# 112/112 [==============================] - 23s 208ms/step - loss: 0.9519 - accuracy: 0.6473 - val_loss: 1.1813 - val_accuracy: 0.5827
# Epoch 34/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.9186 - accuracy: 0.6662 - val_loss: 1.3088 - val_accuracy: 0.5526
# Epoch 35/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.9511 - accuracy: 0.6563 - val_loss: 2.3836 - val_accuracy: 0.4079
# Epoch 36/400
# 112/112 [==============================] - 23s 206ms/step - loss: 1.2891 - accuracy: 0.5388 - val_loss: 1.3323 - val_accuracy: 0.4906
# Epoch 37/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.9295 - accuracy: 0.6616 - val_loss: 1.2023 - val_accuracy: 0.5827
# Epoch 38/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.9925 - accuracy: 0.6396 - val_loss: 1.1096 - val_accuracy: 0.5977
# Epoch 39/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.8702 - accuracy: 0.6878 - val_loss: 0.8855 - val_accuracy: 0.6880
# Epoch 40/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.7569 - accuracy: 0.7285 - val_loss: 1.0414 - val_accuracy: 0.6692
# Epoch 41/400
# 112/112 [==============================] - 23s 207ms/step - loss: 0.7486 - accuracy: 0.7289 - val_loss: 1.0074 - val_accuracy: 0.6692
# Epoch 42/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.7190 - accuracy: 0.7354 - val_loss: 0.9718 - val_accuracy: 0.6541
# Epoch 43/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.6869 - accuracy: 0.7489 - val_loss: 1.0491 - val_accuracy: 0.6579
# Epoch 44/400
# 112/112 [==============================] - 23s 208ms/step - loss: 0.6467 - accuracy: 0.7663 - val_loss: 1.0008 - val_accuracy: 0.6786
# Epoch 45/400
# 112/112 [==============================] - 23s 209ms/step - loss: 0.6114 - accuracy: 0.7783 - val_loss: 1.1245 - val_accuracy: 0.6654
# Epoch 46/400
# 112/112 [==============================] - 23s 209ms/step - loss: 0.6001 - accuracy: 0.7823 - val_loss: 1.0574 - val_accuracy: 0.6936
# Epoch 47/400
# 112/112 [==============================] - 23s 207ms/step - loss: 0.6022 - accuracy: 0.7847 - val_loss: 0.9969 - val_accuracy: 0.7068
# Epoch 48/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.5699 - accuracy: 0.7929 - val_loss: 1.1635 - val_accuracy: 0.6560
# Epoch 49/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.6327 - accuracy: 0.7761 - val_loss: 1.1155 - val_accuracy: 0.6372
# Epoch 50/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.5713 - accuracy: 0.7966 - val_loss: 1.1018 - val_accuracy: 0.6692
# Epoch 51/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.5835 - accuracy: 0.7948 - val_loss: 1.0850 - val_accuracy: 0.7011
# Epoch 52/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.5142 - accuracy: 0.8126 - val_loss: 1.1612 - val_accuracy: 0.6353
# Epoch 53/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.5615 - accuracy: 0.7938 - val_loss: 1.0112 - val_accuracy: 0.7030
# Epoch 54/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.4603 - accuracy: 0.8372 - val_loss: 1.0126 - val_accuracy: 0.6974
# Epoch 55/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.4225 - accuracy: 0.8482 - val_loss: 0.9181 - val_accuracy: 0.7274
# Epoch 56/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.3731 - accuracy: 0.8661 - val_loss: 1.2247 - val_accuracy: 0.6748
# Epoch 57/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.4848 - accuracy: 0.8293 - val_loss: 0.9772 - val_accuracy: 0.6880
# Epoch 58/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.3649 - accuracy: 0.8686 - val_loss: 1.0279 - val_accuracy: 0.7350
# Epoch 59/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.3250 - accuracy: 0.8842 - val_loss: 1.2466 - val_accuracy: 0.6692
# Epoch 60/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.5439 - accuracy: 0.8113 - val_loss: 0.9661 - val_accuracy: 0.7180
# Epoch 61/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.3774 - accuracy: 0.8651 - val_loss: 1.0321 - val_accuracy: 0.7030
# Epoch 62/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.3414 - accuracy: 0.8776 - val_loss: 0.9062 - val_accuracy: 0.7481
# Epoch 63/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.3535 - accuracy: 0.8743 - val_loss: 0.8951 - val_accuracy: 0.7857
# Epoch 64/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.3054 - accuracy: 0.8916 - val_loss: 0.8336 - val_accuracy: 0.7801
# Epoch 65/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.2796 - accuracy: 0.9004 - val_loss: 1.1273 - val_accuracy: 0.7293
# Epoch 66/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.2965 - accuracy: 0.8941 - val_loss: 0.9698 - val_accuracy: 0.7613
# Epoch 67/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.2444 - accuracy: 0.9136 - val_loss: 1.0343 - val_accuracy: 0.7763
# Epoch 68/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.2445 - accuracy: 0.9167 - val_loss: 1.0843 - val_accuracy: 0.7763
# Epoch 69/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.2410 - accuracy: 0.9132 - val_loss: 1.0545 - val_accuracy: 0.7556
# Epoch 70/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.2416 - accuracy: 0.9146 - val_loss: 1.2644 - val_accuracy: 0.7481
# Epoch 71/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.2192 - accuracy: 0.9222 - val_loss: 1.1756 - val_accuracy: 0.7519
# Epoch 72/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.2035 - accuracy: 0.9274 - val_loss: 1.1136 - val_accuracy: 0.7613
# Epoch 73/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.2055 - accuracy: 0.9315 - val_loss: 1.1096 - val_accuracy: 0.7838
# Epoch 74/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.1958 - accuracy: 0.9305 - val_loss: 1.1343 - val_accuracy: 0.7594
# Epoch 75/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.2019 - accuracy: 0.9356 - val_loss: 1.7128 - val_accuracy: 0.6936
# Epoch 76/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.4854 - accuracy: 0.8385 - val_loss: 1.0842 - val_accuracy: 0.7632
# Epoch 77/400
# 112/112 [==============================] - 23s 208ms/step - loss: 0.2341 - accuracy: 0.9186 - val_loss: 1.0988 - val_accuracy: 0.7632
# Epoch 78/400
# 112/112 [==============================] - 23s 208ms/step - loss: 0.1970 - accuracy: 0.9342 - val_loss: 1.1742 - val_accuracy: 0.7350
# Epoch 79/400
# 112/112 [==============================] - 23s 207ms/step - loss: 0.2124 - accuracy: 0.9282 - val_loss: 1.2267 - val_accuracy: 0.7500
# Epoch 80/400
# 112/112 [==============================] - 23s 206ms/step - loss: 0.1713 - accuracy: 0.9445 - val_loss: 1.6810 - val_accuracy: 0.7274
# Epoch 81/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.1856 - accuracy: 0.9376 - val_loss: 1.2644 - val_accuracy: 0.7801
# Epoch 82/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.1509 - accuracy: 0.9482 - val_loss: 1.8970 - val_accuracy: 0.6579
# Epoch 83/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.5052 - accuracy: 0.8331 - val_loss: 1.3515 - val_accuracy: 0.6955
# Epoch 84/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.2479 - accuracy: 0.9166 - val_loss: 1.2361 - val_accuracy: 0.7500
# Epoch 85/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.2103 - accuracy: 0.9311 - val_loss: 1.3412 - val_accuracy: 0.7500
# Epoch 86/400
# 112/112 [==============================] - 23s 205ms/step - loss: 0.1788 - accuracy: 0.9371 - val_loss: 1.3166 - val_accuracy: 0.7162
# Epoch 87/400
# 112/112 [==============================] - 23s 204ms/step - loss: 0.3461 - accuracy: 0.8867 - val_loss: 1.2299 - val_accuracy: 0.7481
# Epoch 88/400
# 112/112 [==============================] - 23s 204ms/step - loss: 0.1735 - accuracy: 0.9429 - val_loss: 1.3149 - val_accuracy: 0.7538
# Epoch 89/400
# 112/112 [==============================] - 23s 204ms/step - loss: 0.1694 - accuracy: 0.9426 - val_loss: 1.3898 - val_accuracy: 0.7575
# Epoch 90/400
# 112/112 [==============================] - 23s 204ms/step - loss: 0.1111 - accuracy: 0.9591 - val_loss: 1.6876 - val_accuracy: 0.7274
# Epoch 91/400
# 112/112 [==============================] - 23s 204ms/step - loss: 0.1395 - accuracy: 0.9537 - val_loss: 1.3551 - val_accuracy: 0.7632
# Epoch 92/400
# 112/112 [==============================] - 23s 204ms/step - loss: 0.0940 - accuracy: 0.9687 - val_loss: 2.9900 - val_accuracy: 0.6090
# Epoch 93/400
# 112/112 [==============================] - 23s 204ms/step - loss: 0.3335 - accuracy: 0.8925 - val_loss: 1.3830 - val_accuracy: 0.7688

# %% [markdown]
# ### Plot training results

# %%
plt.figure(figsize=(15,5))
plt.plot(history['loss'], label='Std training', alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Std validation', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], label='Std training', alpha=.8, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Std validation', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper right')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %% [markdown]
# Plot the confusion matrix (evaluated on the validation set)

# %%
predictions = model.predict(X_val)
cm = confusion_matrix(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))

accuracy = accuracy_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print(f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average=None))
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

plt.figure(figsize=(6,5.5))
sns.heatmap(cm.T, xticklabels=labels, yticklabels=labels)
plt.ylabel('True labels')
plt.xlabel('Predicted labels')
plt.show()
# Out:
# 17/17 [==============================] - 1s 14ms/step
# [0.27906977 0.86451613 0.79503106 0.75177305 0.81656805 0.89552239
#  0.92405063 0.65882353]
# Accuracy: 0.7857
# Precision: 0.7606
# Recall: 0.7476
# F1: 0.7482

# %% [markdown]
# Plot one example of an image for each class from the validation set of images.
# For each image show the prediction on a bar plot

# %%
#TODO: fix this code
example_prediction = random.choice(X_val[0])
'''
fig, axes = plt.subplots(8,2)
fig.set_size_inches(10,20)
for i in range(8):

	# TODO: find random choice from validation set, one per class

	axes[i, 0].imshow(X_val[choice])
	axes[i, 0].set_title('True label: ' + labels[np.argmax(y_val[choice])])
	axes[i, 1].barh(list(labels.values()), predictions[prediction_index], color=plt.get_cmap('Paired').colors)
	axes[i, 1].set_title('Predicted label: '+labels[np.argmax(predictions[prediction_index])])
	axes[i, 1].grid(alpha=.3)


plt.show()
'''
# Out:
# "\nfig, axes = plt.subplots(8,2)\nfig.set_size_inches(10,20)\nfor i in range(8):\n\n\t# TODO: find random choice from validation set, one per class\n\n\taxes[i, 0].imshow(X_val[choice])\n\taxes[i, 0].set_title('True label: ' + labels[np.argmax(y_val[choice])])\n\taxes[i, 1].barh(list(labels.values()), predictions[prediction_index], color=plt.get_cmap('Paired').colors)\n\taxes[i, 1].set_title('Predicted label: '+labels[np.argmax(predictions[prediction_index])])\n\taxes[i, 1].grid(alpha=.3)\n\n\nplt.show()\n"

# %% [markdown]
# ### Save the model
#
# Here it is not working

# %%
restored_model = tfk.models.load_model('simo_model')

#TODO: not right because validation set can change
restored_loss, restored_acc = restored_model.evaluate(X_val, y_val, verbose=2)
loss, acc = model.evaluate(X_val, y_val, verbose=2)
if acc > restored_acc:  # know that this is conceptually wrong
    print("Model improved!")
    model.save('gab_model')
else:
    print("No improvement!")
# Out:
# 17/17 - 0s - loss: 1.2133 - accuracy: 0.7801 - 390ms/epoch - 23ms/step
# 17/17 - 0s - loss: 0.8951 - accuracy: 0.7857 - 277ms/epoch - 16ms/step
# Model improved!
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: gab_model\assets
# INFO:tensorflow:Assets written to: gab_model\assets
