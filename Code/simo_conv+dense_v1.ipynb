# %% [markdown]
# # Code for competition

# %% [markdown]
# Libraries imports and initializations

# %%
import tensorflow as tf
import numpy as np
import os, os.path
import random
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

tfk = tf.keras
tfkl = tf.keras.layers
print(f"Tensorflow version = ", tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
# Out:
# Tensorflow version =  2.6.0
# Num GPUs Available:  1

# %% [markdown]
# Load the dataset

# %%
samples = []
targets = []

images_ind = [186, 532, 515, 511, 531, 222, 537, 508]

# for each species
for i in range(0, len(images_ind)):
    # for each image in every species folder
    for j in range(0, images_ind[i]):
        temp = Image.open(f'training_data_final/Species{i + 1}/{j:05}.jpg').convert('RGB')
        image = np.squeeze(np.expand_dims(temp, axis=0))
        label = tfk.utils.to_categorical(i, len(images_ind))
        samples.append(image)
        targets.append(label)

# creation of augmented dataset 
X = np.array(samples)
y = np.array(targets)
print(X.shape, y.shape)
# Out:
# (3542, 96, 96, 3) (3542, 8)

# %% [markdown]
# Models metadata

# %%
input_shape = X.shape[1:]
image_shape = input_shape[:-1]

batch_size = 16 # TODO: try with other batch sizes and check the difference in accuracy and GPU utilization
epochs = 400
labels = ["Species1", "Species2", "Species3", "Species4", "Species5", "Species6", "Species7", "Species8"]

# %% [markdown]
# ### Static augmentation

# %%
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y], np.int32), return_counts=True)

#shows classes imbalance
plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# %%
# image transformations generator
gen = ImageDataGenerator(rotation_range = 30,
                         height_shift_range = 20,
                         width_shift_range = 20,
                         horizontal_flip = True,
                         vertical_flip = True,
                         zoom_range = 0.2, # added zoom range
                         fill_mode = 'nearest')

# number of images to reach for each category
desired_amount = 800

ref_list = []
aug_samples = []
aug_targets = []

for i in range(0, len(classes)):
    ref_list.append([])
  
for i in range(0, len(y)):
    ref_list[np.argmax(y[i])].append(X[i])

for i in range(0, len(classes)):
    length = len(ref_list[i])
    to_produce = desired_amount - length
    target = tfk.utils.to_categorical(i, len(classes))
    print(f'Computing {to_produce} augmented images for target {i}')

    # produces images and corresponding targets
    aug_targets_i = np.full((length, len(classes)), target)
    aug_gen_i = gen.flow(np.array(ref_list[i]), 
                         aug_targets_i,
                         batch_size=1,
                         seed=seed,
                         shuffle=True)

    # augmented data samples
    for j in range(0, to_produce):
        aug_samples.append(np.squeeze(next(aug_gen_i)[0]))
        aug_targets.append(target)

# augmented dataset
X_aug = np.concatenate((X, np.array(aug_samples)))
y_aug = np.concatenate((y, np.array(aug_targets)))
print(X_aug.shape, y_aug.shape)
# Out:
# Computing 614 augmented images for target 0
# Computing 268 augmented images for target 1
# Computing 285 augmented images for target 2
# Computing 289 augmented images for target 3
# Computing 269 augmented images for target 4
# Computing 578 augmented images for target 5
# Computing 263 augmented images for target 6
# Computing 292 augmented images for target 7
# (6400, 96, 96, 3) (6400, 8)

# %% [markdown]
# Showing a few examples of augmented images, one image per class

# %%
num_row = 2
num_col = 4
fig, axes = plt.subplots(num_row, num_col)
for i in range(num_row * num_col):

    # show a random augmented image -> not working 
    img = random.choice(aug_samples)
    ax = axes[i//num_col, i%num_col]
    ax.imshow(img)
    ax.set_title(labels[i])

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Dataset balanced and shuffled

# %%
# counts of the number of samples per each class, before balancement
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y_aug], np.int32), return_counts=True)

plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# probably not needed, wrote this just in case
X_aug, y_aug = shuffle(X_aug, y_aug)

# %% [markdown]
# ### Models definition
#
# Convolutional model defined as a stack of some convolution layers, max pooling, gap and dropout layers.
#
# Fully connected dense layers stacked after the convolutional layers, with no regularization applied. 5 layers of 128 neurons each

# %%
def build_conv_dense_model(input_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    x = tfkl.Conv2D(
        filters = 128,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv1')(input_layer)
    
    x = tfkl.MaxPooling2D(name='mp1')(x)

    x = tfkl.Conv2D(
        filters = 128,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv2')(x)
    
    x = tfkl.MaxPooling2D(name='mp2')(x)

    x = tfkl.Conv2D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'Conv3')(x)
    
    x = tfkl.GlobalAveragePooling2D(name='gap')(x)
    
    x = tfkl.Dropout(0.2, seed=seed, name='gap_dropout')(x)

    # end of convolutional layers
    # start of the fully connected layers
    
    x = tfkl.Flatten()(x)
    
    x = tfkl.Dense(
        units = 512,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense1')(x)

    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense2')(x)

    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense3')(x)

    x = tfkl.Dense(
        units = 128,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense4')(x)

    x = tfkl.Dense(
        units = 128,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense5')(x)
    
    x = tfkl.Dropout(0.2, seed=seed, name='dropout')(x)

    output_layer = tfkl.Dense(
        units = len(labels), 
        activation = 'softmax', 
        kernel_initializer = tfk.initializers.GlorotUniform(seed),
        name = 'output_layer')(x)
    
    # Connect input and output through the Model class
    model = tfk.Model(inputs = input_layer, outputs = output_layer, name = 'conv_dense_model_v1')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %% [markdown]
# # First attempt: Hold Out validation

# %% [markdown]
# Split the dataset (85-15)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_aug, y_aug, stratify=y_aug, test_size=0.15)

print(f"training set input shape", X_train.shape, y_train.shape)
print(f"validation set input shape",X_val.shape, y_val.shape)
# Out:
# training set input shape (5440, 96, 96, 3) (5440, 8)
# validation set input shape (960, 96, 96, 3) (960, 8)

# %% [markdown]
# Train the model

# %%
# first convolutional model
model = build_conv_dense_model(input_shape)

model.summary()
# Out:
# Model: "conv_dense_model_v1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 96, 96, 3)]       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 96, 96, 128)       3584
# _________________________________________________________________
# mp1 (MaxPooling2D)           (None, 48, 48, 128)       0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 48, 48, 128)       147584
# _________________________________________________________________
# mp2 (MaxPooling2D)           (None, 24, 24, 128)       0
# _________________________________________________________________
# Conv3 (Conv2D)               (None, 24, 24, 256)       295168
# _________________________________________________________________
# gap (GlobalAveragePooling2D) (None, 256)               0
# _________________________________________________________________
# gap_dropout (Dropout)        (None, 256)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense1 (Dense)               (None, 512)               131584
# _________________________________________________________________
# dense2 (Dense)               (None, 256)               131328
# _________________________________________________________________
# dense3 (Dense)               (None, 256)               65792
# _________________________________________________________________
# dense4 (Dense)               (None, 128)               32896
# _________________________________________________________________
# dense5 (Dense)               (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 8)                 1032
# =================================================================
# Total params: 825,480
# Trainable params: 825,480
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val, y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True)]
).history
# Out:
# Epoch 1/400
# 340/340 [==============================] - 46s 46ms/step - loss: 9.6108 - accuracy: 0.1761 - val_loss: 1.8813 - val_accuracy: 0.2677
# Epoch 2/400
# 340/340 [==============================] - 15s 45ms/step - loss: 1.8558 - accuracy: 0.2660 - val_loss: 1.7021 - val_accuracy: 0.3615
# Epoch 3/400
# 340/340 [==============================] - 16s 47ms/step - loss: 1.7130 - accuracy: 0.3213 - val_loss: 1.7490 - val_accuracy: 0.3010
# Epoch 4/400
# 340/340 [==============================] - 15s 45ms/step - loss: 1.6440 - accuracy: 0.3504 - val_loss: 1.6265 - val_accuracy: 0.3427
# Epoch 5/400
# 340/340 [==============================] - 15s 45ms/step - loss: 1.6474 - accuracy: 0.3601 - val_loss: 1.5488 - val_accuracy: 0.3688
# Epoch 6/400
# 340/340 [==============================] - 15s 45ms/step - loss: 1.5836 - accuracy: 0.3761 - val_loss: 1.5212 - val_accuracy: 0.3885
# Epoch 7/400
# 340/340 [==============================] - 15s 45ms/step - loss: 1.5413 - accuracy: 0.3947 - val_loss: 1.4809 - val_accuracy: 0.4073
# Epoch 8/400
# 340/340 [==============================] - 15s 45ms/step - loss: 1.4825 - accuracy: 0.4274 - val_loss: 1.4989 - val_accuracy: 0.4042
# Epoch 9/400
# 340/340 [==============================] - 16s 46ms/step - loss: 1.4617 - accuracy: 0.4221 - val_loss: 1.3993 - val_accuracy: 0.4500
# Epoch 10/400
# 340/340 [==============================] - 16s 47ms/step - loss: 1.4344 - accuracy: 0.4375 - val_loss: 1.5019 - val_accuracy: 0.3854
# Epoch 11/400
# 340/340 [==============================] - 16s 47ms/step - loss: 1.4190 - accuracy: 0.4493 - val_loss: 1.3553 - val_accuracy: 0.4719
# Epoch 12/400
# 340/340 [==============================] - 16s 47ms/step - loss: 1.3845 - accuracy: 0.4579 - val_loss: 1.3652 - val_accuracy: 0.5031
# Epoch 13/400
# 340/340 [==============================] - 16s 47ms/step - loss: 1.3484 - accuracy: 0.4801 - val_loss: 1.4013 - val_accuracy: 0.4583
# Epoch 14/400
# 340/340 [==============================] - 16s 48ms/step - loss: 1.3129 - accuracy: 0.4873 - val_loss: 1.2554 - val_accuracy: 0.5437
# Epoch 15/400
# 340/340 [==============================] - 16s 48ms/step - loss: 1.2932 - accuracy: 0.4963 - val_loss: 1.2727 - val_accuracy: 0.4969
# Epoch 16/400
# 340/340 [==============================] - 16s 48ms/step - loss: 1.2592 - accuracy: 0.5116 - val_loss: 1.2975 - val_accuracy: 0.5125
# Epoch 17/400
# 340/340 [==============================] - 16s 48ms/step - loss: 1.2654 - accuracy: 0.5171 - val_loss: 1.2882 - val_accuracy: 0.5115
# Epoch 18/400
# 340/340 [==============================] - 17s 49ms/step - loss: 1.2493 - accuracy: 0.5309 - val_loss: 1.3240 - val_accuracy: 0.4865
# Epoch 19/400
# 340/340 [==============================] - 16s 48ms/step - loss: 1.2080 - accuracy: 0.5375 - val_loss: 1.2709 - val_accuracy: 0.5104
# Epoch 20/400
# 340/340 [==============================] - 17s 49ms/step - loss: 1.1895 - accuracy: 0.5483 - val_loss: 1.1876 - val_accuracy: 0.5750
# Epoch 21/400
# 340/340 [==============================] - 17s 49ms/step - loss: 1.1594 - accuracy: 0.5553 - val_loss: 1.3600 - val_accuracy: 0.4823
# Epoch 22/400
# 340/340 [==============================] - 16s 48ms/step - loss: 1.1550 - accuracy: 0.5590 - val_loss: 1.1924 - val_accuracy: 0.5427
# Epoch 23/400
# 340/340 [==============================] - 16s 47ms/step - loss: 1.1276 - accuracy: 0.5711 - val_loss: 1.2087 - val_accuracy: 0.5479
# Epoch 24/400
# 340/340 [==============================] - 16s 48ms/step - loss: 1.1149 - accuracy: 0.5827 - val_loss: 1.2009 - val_accuracy: 0.5406
# Epoch 25/400
# 340/340 [==============================] - 16s 49ms/step - loss: 1.0989 - accuracy: 0.5851 - val_loss: 1.1399 - val_accuracy: 0.5917
# Epoch 26/400
# 340/340 [==============================] - 16s 48ms/step - loss: 1.0669 - accuracy: 0.6070 - val_loss: 1.2444 - val_accuracy: 0.5562
# Epoch 27/400
# 340/340 [==============================] - 16s 48ms/step - loss: 1.0159 - accuracy: 0.6213 - val_loss: 1.2409 - val_accuracy: 0.5458
# Epoch 28/400
# 340/340 [==============================] - 16s 48ms/step - loss: 1.0075 - accuracy: 0.6187 - val_loss: 1.1084 - val_accuracy: 0.5958
# Epoch 29/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.9839 - accuracy: 0.6441 - val_loss: 1.2227 - val_accuracy: 0.5729
# Epoch 30/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.9831 - accuracy: 0.6390 - val_loss: 1.2212 - val_accuracy: 0.5594
# Epoch 31/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.9507 - accuracy: 0.6533 - val_loss: 1.2811 - val_accuracy: 0.5708
# Epoch 32/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.9331 - accuracy: 0.6636 - val_loss: 1.2197 - val_accuracy: 0.5417
# Epoch 33/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.8777 - accuracy: 0.6695 - val_loss: 1.3049 - val_accuracy: 0.5427
# Epoch 34/400
# 340/340 [==============================] - 17s 49ms/step - loss: 0.8812 - accuracy: 0.6737 - val_loss: 1.4455 - val_accuracy: 0.5146
# Epoch 35/400
# 340/340 [==============================] - 17s 49ms/step - loss: 0.8556 - accuracy: 0.6827 - val_loss: 1.0655 - val_accuracy: 0.6469
# Epoch 36/400
# 340/340 [==============================] - 17s 49ms/step - loss: 0.8134 - accuracy: 0.7007 - val_loss: 1.1793 - val_accuracy: 0.6146
# Epoch 37/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.8053 - accuracy: 0.7077 - val_loss: 1.0923 - val_accuracy: 0.6219
# Epoch 38/400
# 340/340 [==============================] - 16s 47ms/step - loss: 0.7544 - accuracy: 0.7274 - val_loss: 1.2762 - val_accuracy: 0.6042
# Epoch 39/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.7425 - accuracy: 0.7292 - val_loss: 1.1935 - val_accuracy: 0.6198
# Epoch 40/400
# 340/340 [==============================] - 16s 47ms/step - loss: 0.7776 - accuracy: 0.7169 - val_loss: 1.1448 - val_accuracy: 0.6344
# Epoch 41/400
# 340/340 [==============================] - 16s 47ms/step - loss: 0.7306 - accuracy: 0.7443 - val_loss: 1.2741 - val_accuracy: 0.6094
# Epoch 42/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.7026 - accuracy: 0.7423 - val_loss: 1.1298 - val_accuracy: 0.6146
# Epoch 43/400
# 340/340 [==============================] - 16s 47ms/step - loss: 0.6709 - accuracy: 0.7546 - val_loss: 1.1430 - val_accuracy: 0.6125
# Epoch 44/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.6567 - accuracy: 0.7619 - val_loss: 1.2110 - val_accuracy: 0.6167
# Epoch 45/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.6608 - accuracy: 0.7575 - val_loss: 1.0870 - val_accuracy: 0.6531
# Epoch 46/400
# 340/340 [==============================] - 16s 47ms/step - loss: 0.5925 - accuracy: 0.7869 - val_loss: 1.1899 - val_accuracy: 0.6302
# Epoch 47/400
# 340/340 [==============================] - 16s 46ms/step - loss: 0.5946 - accuracy: 0.7869 - val_loss: 1.2801 - val_accuracy: 0.6198
# Epoch 48/400
# 340/340 [==============================] - 16s 46ms/step - loss: 0.5583 - accuracy: 0.7996 - val_loss: 1.2812 - val_accuracy: 0.6427
# Epoch 49/400
# 340/340 [==============================] - 16s 46ms/step - loss: 0.5679 - accuracy: 0.7943 - val_loss: 1.2056 - val_accuracy: 0.6583
# Epoch 50/400
# 340/340 [==============================] - 16s 46ms/step - loss: 0.5672 - accuracy: 0.7972 - val_loss: 1.3725 - val_accuracy: 0.6000
# Epoch 51/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.5104 - accuracy: 0.8211 - val_loss: 1.4281 - val_accuracy: 0.6062
# Epoch 52/400
# 340/340 [==============================] - 17s 49ms/step - loss: 0.5197 - accuracy: 0.8160 - val_loss: 1.2809 - val_accuracy: 0.6531
# Epoch 53/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.4812 - accuracy: 0.8327 - val_loss: 1.5176 - val_accuracy: 0.6104
# Epoch 54/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.4766 - accuracy: 0.8344 - val_loss: 1.3231 - val_accuracy: 0.6562
# Epoch 55/400
# 340/340 [==============================] - 16s 47ms/step - loss: 0.4807 - accuracy: 0.8276 - val_loss: 1.5147 - val_accuracy: 0.6062
# Epoch 56/400
# 340/340 [==============================] - 16s 46ms/step - loss: 0.4701 - accuracy: 0.8384 - val_loss: 1.4915 - val_accuracy: 0.6021
# Epoch 57/400
# 340/340 [==============================] - 16s 47ms/step - loss: 0.4113 - accuracy: 0.8550 - val_loss: 1.5436 - val_accuracy: 0.6250
# Epoch 58/400
# 340/340 [==============================] - 17s 49ms/step - loss: 0.4168 - accuracy: 0.8548 - val_loss: 1.4618 - val_accuracy: 0.6469
# Epoch 59/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.4207 - accuracy: 0.8548 - val_loss: 1.5999 - val_accuracy: 0.6135
# Epoch 60/400
# 340/340 [==============================] - 16s 46ms/step - loss: 0.4314 - accuracy: 0.8517 - val_loss: 1.5036 - val_accuracy: 0.6406
# Epoch 61/400
# 340/340 [==============================] - 16s 46ms/step - loss: 0.4073 - accuracy: 0.8612 - val_loss: 1.4211 - val_accuracy: 0.6542
# Epoch 62/400
# 340/340 [==============================] - 16s 46ms/step - loss: 0.3636 - accuracy: 0.8772 - val_loss: 1.5472 - val_accuracy: 0.6292
# Epoch 63/400
# 340/340 [==============================] - 15s 45ms/step - loss: 0.3520 - accuracy: 0.8787 - val_loss: 1.5813 - val_accuracy: 0.6000
# Epoch 64/400
# 340/340 [==============================] - 17s 49ms/step - loss: 0.3815 - accuracy: 0.8746 - val_loss: 1.5848 - val_accuracy: 0.5927
# Epoch 65/400
# 340/340 [==============================] - 17s 51ms/step - loss: 0.3724 - accuracy: 0.8699 - val_loss: 1.5969 - val_accuracy: 0.6125
# Epoch 66/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.3490 - accuracy: 0.8814 - val_loss: 1.5775 - val_accuracy: 0.6240
# Epoch 67/400
# 340/340 [==============================] - 16s 47ms/step - loss: 0.3447 - accuracy: 0.8844 - val_loss: 1.6010 - val_accuracy: 0.6344
# Epoch 68/400
# 340/340 [==============================] - 16s 48ms/step - loss: 0.2993 - accuracy: 0.8969 - val_loss: 1.6937 - val_accuracy: 0.6438
# Epoch 69/400
# 340/340 [==============================] - 16s 47ms/step - loss: 0.3440 - accuracy: 0.8858 - val_loss: 1.4912 - val_accuracy: 0.6281

# %% [markdown]
# ### Plot training results

# %%
plt.figure(figsize=(15,5))
plt.plot(history['loss'], label='Std training', alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Std validation', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], label='Std training', alpha=.8, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Std validation', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper right')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %% [markdown]
# Plot the confusion matrix (evaluated on the validation set)

# %%
predictions = model.predict(X_val)
cm = confusion_matrix(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))

accuracy = accuracy_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

plt.figure(figsize=(10,8))
sns.heatmap(cm.T, xticklabels=labels, yticklabels=labels)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.6583
# Precision: 0.6571
# Recall: 0.6583
# F1: 0.6573

# %% [markdown]
# ### Save the model
#
# Here it is not working

# %%
restored_model = tfk.models.load_model('best_model')
restored_loss, restored_acc = restored_model.evaluate(X_val, y_val, verbose=2)  #TODO: not right because validation set can change
loss, acc = model.evaluate(X_val, y_val, verbose=2)
if acc > restored_acc:  # know that this is conceptually wrong
    print("Model improved!")
    model.save('best_model')
else:
    print("No improvement!")
# Out:
# ---------------------------------------------------------------------------
# DecodeError                               Traceback (most recent call last)
# File d:\Programs\Anaconda\lib\site-packages\keras\saving\saved_model\load.py:115, in load(path, compile, options)
#     114     file_content = f.read()
# --> 115   metadata.ParseFromString(file_content)
#     116 except message.DecodeError as e:
#
# File d:\Programs\Anaconda\lib\site-packages\google\protobuf\message.py:199, in Message.ParseFromString(self, serialized)
#     198 self.Clear()
# --> 199 return self.MergeFromString(serialized)
#
# File d:\Programs\Anaconda\lib\site-packages\google\protobuf\internal\python_message.py:1139, in _AddMergeFromStringMethod.<locals>.MergeFromString(self, serialized)
#    1138 try:
# -> 1139   if self._InternalParse(serialized, 0, length) != length:
#    1140     # The only reason _InternalParse would return early is if it
#    1141     # encountered an end-group tag.
#    1142     raise message_mod.DecodeError('Unexpected end-group tag.')
#
# File d:\Programs\Anaconda\lib\site-packages\google\protobuf\internal\python_message.py:1189, in _AddMergeFromStringMethod.<locals>.InternalParse(self, buffer, pos, end)
#    1188 if field_number == 0:
# -> 1189   raise message_mod.DecodeError('Field number 0 is illegal.')
#    1190 # TODO(jieluo): remove old_pos.
#
# DecodeError: Field number 0 is illegal.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# d:\Programming\Artificial Neural Networks\Competition 1\AN2DL-project-2022\Code\competition_simo.ipynb Cell 28 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Programming/Artificial%20Neural%20Networks/Competition%201/AN2DL-project-2022/Code/competition_simo.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> restored_model = tfk.models.load_model('best_model')
#       <a href='vscode-notebook-cell:/d%3A/Programming/Artificial%20Neural%20Networks/Competition%201/AN2DL-project-2022/Code/competition_simo.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> restored_loss, restored_acc = restored_model.evaluate(X_val, y_val, verbose=2)  #TODO: not right because validation set can change
#       <a href='vscode-notebook-cell:/d%3A/Programming/Artificial%20Neural%20Networks/Competition%201/AN2DL-project-2022/Code/competition_simo.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> loss, acc = model.evaluate(X_val, y_val, verbose=2)
#
# File d:\Programs\Anaconda\lib\site-packages\keras\saving\save.py:205, in load_model(filepath, custom_objects, compile, options)
#     203       filepath = path_to_string(filepath)
#     204       if isinstance(filepath, str):
# --> 205         return saved_model_load.load(filepath, compile, options)
#     207 raise IOError(
#     208     'Unable to load model. Filepath is not an hdf5 file (or h5py is not '
#     209     'available) or SavedModel.')
#
# File d:\Programs\Anaconda\lib\site-packages\keras\saving\saved_model\load.py:117, in load(path, compile, options)
#     115     metadata.ParseFromString(file_content)
#     116   except message.DecodeError as e:
# --> 117     raise IOError('Cannot parse keras metadata {}: {}.'
#     118                   .format(path_to_metadata_pb, str(e)))
#     119 else:
#     120   logging.warning('SavedModel saved prior to TF 2.5 detected when loading '
#     121                   'Keras model. Please ensure that you are saving the model '
#     122                   'with model.save() or tf.keras.models.save_model(), *NOT* '
#     123                   'tf.saved_model.save(). To confirm, there should be a file '
#     124                   'named "keras_metadata.pb" in the SavedModel directory.')
#
# OSError: Cannot parse keras metadata best_model\keras_metadata.pb: Field number 0 is illegal..
