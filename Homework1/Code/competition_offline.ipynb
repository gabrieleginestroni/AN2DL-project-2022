# %% [markdown]
# # Code for competition

# %%
import tensorflow as tf
from keras.datasets import mnist
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
print(tf.config.list_physical_devices())

# Enable experimental feature of memory occupation growth control 
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
# Out:
# 2.6.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Load the dataset

# %%
samples = []
targets = []

images_ind = [186, 532, 515, 511, 531, 222, 537, 508]
for i in range(0, len(images_ind)):
    for j in range(0, images_ind[i]):
        temp = Image.open(f'training_data_final/Species{i + 1}/{j:05}.jpg').convert('RGB')
        image = np.squeeze(np.expand_dims(temp, axis=0))
        label = tfk.utils.to_categorical(i, len(images_ind))
        samples.append(image)
        targets.append(label)

X = np.array(samples)
y = np.array(targets, dtype=np.uint8)
print(X.shape, X.dtype, sep=", ")
print(y.shape, y.dtype, sep=", ")
# Out:
# (3542, 96, 96, 3), uint8
# (3542, 8), uint8

# %% [markdown]
# ### Models metadata

# %%
input_shape = X.shape[1:]
image_shape = input_shape[:-1]
batch_size = 128
epochs = 200
labels = ["Species1", "Species2", "Species3", "Species4", "Species5", "Species6", "Species7", "Species8"]

# %% [markdown]
# ### Split training-validation

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, test_size=0.2)

print(X_train.shape, X_train.dtype, y_train.shape, y_train.dtype, sep=", ")
print(X_val.shape, X_val.dtype, y_val.shape, y_val.dtype, sep=", ")
# Out:
# (2833, 96, 96, 3), uint8, (2833, 8), uint8
# (709, 96, 96, 3), uint8, (709, 8), uint8

# %% [markdown]
# ### Static (or offline) augmentation

# %%
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y_train], np.int32), return_counts=True)

plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# %%
shift_range = 15
gen = ImageDataGenerator(rotation_range=180,
                         height_shift_range=shift_range,
                         width_shift_range=shift_range,
                         horizontal_flip=True,
                         zoom_range = 0.3,
                         fill_mode='reflect')

desired_amount = int(537 * 0.8)

ref_list = []
aug_samples = []
aug_targets = []

for i in range(0, len(labels)):
    ref_list.append([])
  
for i in range(0, len(y_train)):
    ref_list[np.argmax(y_train[i])].append(X[i])

# Apply augmentation
for i in range(0, len(labels)):
    length = len(ref_list[i])
    to_produce = desired_amount - length
    target = tfk.utils.to_categorical(i, len(labels))
    print(f'Computing {to_produce} augmented images for target {i}')
    aug_targets_i = np.full((length, len(labels)), target)
    aug_gen_i = gen.flow(np.array(ref_list[i]), 
                         aug_targets_i,
                         batch_size=1,
                         seed=seed,
                         shuffle=True)
    for j in range(0, to_produce):
        aug_samples.append(np.squeeze(next(aug_gen_i)[0]))
        aug_targets.append(target)

# augmented dataset
X_aug = np.concatenate((X_train, np.array(aug_samples, dtype=np.uint8)))
y_aug = np.concatenate((y_train, np.array(aug_targets, dtype=np.uint8)))
print(X_aug.shape, X_aug.dtype, sep=", ")
print(y_aug.shape, y_aug.dtype, sep=", ")
# Out:
# Computing 280 augmented images for target 0
# Computing 4 augmented images for target 1
# Computing 17 augmented images for target 2
# Computing 20 augmented images for target 3
# Computing 4 augmented images for target 4
# Computing 251 augmented images for target 5
# Computing 0 augmented images for target 6
# Computing 23 augmented images for target 7
# (3432, 96, 96, 3), uint8
# (3432, 8), uint8

# %% [markdown]
# ### Test pre-processing

# %%
def preprocess(image):
    return np.array(tf.image.adjust_saturation(img, 3))
    #return np.array(tf.image.adjust_brightness(tf.image.adjust_saturation(img, 3), 0.5))

new_aug_samples = []
for img in aug_samples: 
    new_aug_samples.append(preprocess(img))

# %% [markdown]
# ### Show some example of augmented images

# %%
num_row = 2
num_col = 4
fig, axes = plt.subplots(num_row, num_col)
for i in range(num_row * num_col):
    img = random.choice(new_aug_samples)  # change to new_aug_samples to see also preprocessing effects or keep it to aug_samples
    ax = axes[i//num_col, i%num_col]
    ax.imshow(Image.fromarray(img.astype(np.uint8)))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Apply pre-processing
# All that is done here must be included in the pre-processing phase

# %%
temp = []
for img in X_aug: 
    temp.append(preprocess(img))

X_aug = np.array(temp)
print(X_aug.shape, X_aug.dtype, sep=", ")
# Out:
# (3432, 96, 96, 3), uint8

# %%
classes, counts = np.unique(np.fromiter([np.argmax(t) for t in y_aug], np.int32), return_counts=True)

plt.ylabel('Counts')
plt.xlabel('Classes')
sns.barplot(x = classes, y = counts)
plt.show()

# %% [markdown]
# ### Models definition functions

# %%
def build_tl_model(input_shape):
    tf.random.set_seed(seed)

    #Load the supernet
    supernet = tfk.applications.VGG16(include_top=False,
                                      weights="imagenet",
                                      input_shape=input_shape)
    
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')
    
    x = supernet(input_layer)

    x = tfkl.GlobalAveragePooling2D(name='gap')(x)
    '''
    x = tfkl.Dropout(0.2, seed=seed, name='gap_dropout')(x)
    
    x = tfkl.Dense(
        units = 512,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense1')(x)

    x = tfkl.Dropout(0.3, seed=seed, name='dropout1')(x)

    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense2')(x)

    x = tfkl.Dropout(0.3, seed=seed, name='dropout2')(x)

    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense3')(x)

    x = tfkl.Dropout(0.3, seed=seed, name='dropout3')(x)
    
    x = tfkl.Dense(
        units = 512,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense4')(x)
    
    x = tfkl.Dropout(0.3, seed=seed, name='dropout4')(x)
    '''
    x = tfkl.Dense(
        units = 1024,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense5')(x)
    
    x = tfkl.Dropout(0.2, seed=seed, name='dropout5')(x)
    
    output_layer = tfkl.Dense(
        units = len(labels), 
        activation = 'softmax', 
        kernel_initializer = tfk.initializers.GlorotUniform(seed),
        name = 'output_layer')(x)
    
    # Connect input and output through the Model class
    model = tfk.Model(inputs = input_layer, outputs = output_layer, name = 'tl_model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model


def build_conv_dense_model(input_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    x = tfkl.Conv2D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv1')(input_layer)
    
    x = tfkl.MaxPooling2D(name='mp1')(x)

    x = tfkl.Conv2D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'conv2')(x)
    
    x = tfkl.MaxPooling2D(name='mp2')(x)

    x = tfkl.Conv2D(
        filters = 256,
        kernel_size = 3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'Conv3')(x)
    
    x = tfkl.GlobalAveragePooling2D(name='gap')(x)
    
    #x = tfkl.Dropout(0.2, seed=seed, name='gap_dropout')(x)

    # end of convolutional layers
    # start of the fully connected layers
    
    #x = tfkl.Flatten()(x)
    
    x = tfkl.Dense(
        units = 512,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense1')(x)

    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense2')(x)

    x = tfkl.Dense(
        units = 256,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense3')(x)

    x = tfkl.Dense(
        units = 128,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense4')(x)

    x = tfkl.Dense(
        units = 128,  
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed),
        name = 'dense5')(x)
    
    x = tfkl.Dropout(0.2, seed=seed, name='dropout')(x)

    output_layer = tfkl.Dense(
        units = len(labels), 
        activation = 'softmax', 
        kernel_initializer = tfk.initializers.GlorotUniform(seed),
        name = 'output_layer')(x)
    
    # Connect input and output through the Model class
    model = tfk.Model(inputs = input_layer, outputs = output_layer, name = 'conv_dense_model_v1')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %% [markdown]
# ### Define the model

# %%
model = build_conv_dense_model(input_shape)

# Use the supernet only as feature extractor (eventually apply fine tuning)
#model.get_layer('vgg16').trainable = True
#for i, layer in enumerate(model.get_layer('vgg16').layers[:-1]):
#  layer.trainable=False

model.summary()
# Out:
# Model: "conv_dense_model_v1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 96, 96, 3)]       0
#
#  conv1 (Conv2D)              (None, 96, 96, 256)       7168
#
#  mp1 (MaxPooling2D)          (None, 48, 48, 256)       0
#
#  conv2 (Conv2D)              (None, 48, 48, 256)       590080
#
#  mp2 (MaxPooling2D)          (None, 24, 24, 256)       0
#
#  Conv3 (Conv2D)              (None, 24, 24, 256)       590080
#
#  gap (GlobalAveragePooling2D  (None, 256)              0
#  )
#
#  dense1 (Dense)              (None, 512)               131584
#
#  dense2 (Dense)              (None, 256)               131328
#
#  dense3 (Dense)              (None, 256)               65792
#
#  dense4 (Dense)              (None, 128)               32896
#
#  dense5 (Dense)              (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  output_layer (Dense)        (None, 8)                 1032
#
# =================================================================
# Total params: 1,566,472
# Trainable params: 1,566,472
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
# Transfer learning preprocessing (to be included in the preprocessing)
#from tensorflow.keras.applications.vgg16 import preprocess_input
#X_train_tl = np.array(preprocess_input(X_train), dtype=np.uint8)
#X_val_tl = np.array(preprocess_input(X_val), dtype=np.uint8)

history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val, y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=15, restore_best_weights=True)]
).history
# Out:
# Epoch 1/400
# 213/213 [==============================] - 107s 482ms/step - loss: 24.8340 - accuracy: 0.2163 - val_loss: 1.6962 - val_accuracy: 0.3600
# Epoch 2/400
# 213/213 [==============================] - 103s 481ms/step - loss: 1.6924 - accuracy: 0.3590 - val_loss: 1.6064 - val_accuracy: 0.3958
# Epoch 3/400
# 213/213 [==============================] - 105s 491ms/step - loss: 1.5463 - accuracy: 0.4187 - val_loss: 1.4591 - val_accuracy: 0.4558
# Epoch 4/400
# 213/213 [==============================] - 107s 500ms/step - loss: 1.4301 - accuracy: 0.4675 - val_loss: 1.3982 - val_accuracy: 0.4683
# Epoch 5/400
# 213/213 [==============================] - 106s 500ms/step - loss: 1.3656 - accuracy: 0.4860 - val_loss: 1.1914 - val_accuracy: 0.5542
# Epoch 6/400
# 213/213 [==============================] - 108s 506ms/step - loss: 1.2748 - accuracy: 0.5231 - val_loss: 1.2068 - val_accuracy: 0.5417
# Epoch 7/400
# 213/213 [==============================] - 108s 505ms/step - loss: 1.2318 - accuracy: 0.5485 - val_loss: 1.2790 - val_accuracy: 0.5292
# Epoch 8/400
# 213/213 [==============================] - 110s 516ms/step - loss: 1.1997 - accuracy: 0.5509 - val_loss: 1.1025 - val_accuracy: 0.6008
# Epoch 9/400
# 213/213 [==============================] - 108s 505ms/step - loss: 1.1673 - accuracy: 0.5687 - val_loss: 1.0810 - val_accuracy: 0.5767
# Epoch 10/400
# 213/213 [==============================] - 108s 506ms/step - loss: 1.1189 - accuracy: 0.5868 - val_loss: 1.0917 - val_accuracy: 0.5950
# Epoch 11/400
# 213/213 [==============================] - 107s 502ms/step - loss: 1.0681 - accuracy: 0.6124 - val_loss: 1.0324 - val_accuracy: 0.6017
# Epoch 12/400
# 213/213 [==============================] - 106s 500ms/step - loss: 1.0494 - accuracy: 0.6115 - val_loss: 1.1336 - val_accuracy: 0.5867
# Epoch 13/400
# 213/213 [==============================] - 107s 502ms/step - loss: 1.0203 - accuracy: 0.6335 - val_loss: 0.9774 - val_accuracy: 0.6417
# Epoch 14/400
# 213/213 [==============================] - 106s 496ms/step - loss: 0.9756 - accuracy: 0.6397 - val_loss: 0.9414 - val_accuracy: 0.6608
# Epoch 15/400
# 213/213 [==============================] - 106s 499ms/step - loss: 0.9579 - accuracy: 0.6465 - val_loss: 1.2015 - val_accuracy: 0.5792
# Epoch 16/400
# 213/213 [==============================] - 109s 513ms/step - loss: 0.9628 - accuracy: 0.6446 - val_loss: 0.8813 - val_accuracy: 0.6792
# Epoch 17/400
# 213/213 [==============================] - 107s 502ms/step - loss: 0.9132 - accuracy: 0.6646 - val_loss: 0.8808 - val_accuracy: 0.6733
# Epoch 18/400
# 213/213 [==============================] - 107s 502ms/step - loss: 0.9057 - accuracy: 0.6697 - val_loss: 0.8694 - val_accuracy: 0.6825
# Epoch 19/400
# 213/213 [==============================] - 107s 500ms/step - loss: 0.8931 - accuracy: 0.6731 - val_loss: 1.0288 - val_accuracy: 0.6150
# Epoch 20/400
# 213/213 [==============================] - 108s 508ms/step - loss: 0.8626 - accuracy: 0.6862 - val_loss: 0.8383 - val_accuracy: 0.6933
# Epoch 21/400
# 213/213 [==============================] - 109s 510ms/step - loss: 0.8181 - accuracy: 0.7060 - val_loss: 0.8719 - val_accuracy: 0.6925
# Epoch 22/400
# 213/213 [==============================] - 109s 511ms/step - loss: 0.7812 - accuracy: 0.7212 - val_loss: 0.8316 - val_accuracy: 0.7058
# Epoch 23/400
# 213/213 [==============================] - 106s 496ms/step - loss: 0.7733 - accuracy: 0.7175 - val_loss: 0.8654 - val_accuracy: 0.6792
# Epoch 24/400
# 213/213 [==============================] - 105s 495ms/step - loss: 0.7699 - accuracy: 0.7169 - val_loss: 0.9008 - val_accuracy: 0.6617
# Epoch 25/400
# 213/213 [==============================] - 106s 499ms/step - loss: 0.7117 - accuracy: 0.7368 - val_loss: 0.9657 - val_accuracy: 0.6583
# Epoch 26/400
# 213/213 [==============================] - 106s 497ms/step - loss: 0.7095 - accuracy: 0.7446 - val_loss: 0.8064 - val_accuracy: 0.7133
# Epoch 27/400
# 213/213 [==============================] - 107s 501ms/step - loss: 0.6723 - accuracy: 0.7572 - val_loss: 0.8212 - val_accuracy: 0.7175
# Epoch 28/400
# 213/213 [==============================] - 107s 502ms/step - loss: 0.6730 - accuracy: 0.7615 - val_loss: 0.8688 - val_accuracy: 0.6900
# Epoch 29/400
# 213/213 [==============================] - 107s 504ms/step - loss: 0.6384 - accuracy: 0.7697 - val_loss: 0.7876 - val_accuracy: 0.7175
# Epoch 30/400
# 213/213 [==============================] - 106s 498ms/step - loss: 0.5974 - accuracy: 0.7888 - val_loss: 0.8129 - val_accuracy: 0.7225
# Epoch 31/400
# 213/213 [==============================] - 109s 510ms/step - loss: 0.6013 - accuracy: 0.7869 - val_loss: 0.7638 - val_accuracy: 0.7233
# Epoch 32/400
# 213/213 [==============================] - 105s 494ms/step - loss: 0.5583 - accuracy: 0.7996 - val_loss: 0.7877 - val_accuracy: 0.7583
# Epoch 33/400
# 213/213 [==============================] - 106s 499ms/step - loss: 0.5368 - accuracy: 0.8043 - val_loss: 0.8860 - val_accuracy: 0.7117
# Epoch 34/400
# 213/213 [==============================] - 108s 509ms/step - loss: 0.5280 - accuracy: 0.8132 - val_loss: 0.7330 - val_accuracy: 0.7458
# Epoch 35/400
# 213/213 [==============================] - 107s 502ms/step - loss: 0.5041 - accuracy: 0.8193 - val_loss: 0.7645 - val_accuracy: 0.7492
# Epoch 36/400
# 213/213 [==============================] - 107s 504ms/step - loss: 0.5276 - accuracy: 0.8160 - val_loss: 0.7725 - val_accuracy: 0.7550
# Epoch 37/400
# 213/213 [==============================] - 107s 503ms/step - loss: 0.4841 - accuracy: 0.8296 - val_loss: 0.7167 - val_accuracy: 0.7500
# Epoch 38/400
# 213/213 [==============================] - 110s 514ms/step - loss: 0.4125 - accuracy: 0.8556 - val_loss: 0.8094 - val_accuracy: 0.7258
# Epoch 39/400
# 213/213 [==============================] - 105s 493ms/step - loss: 0.4392 - accuracy: 0.8422 - val_loss: 0.7651 - val_accuracy: 0.7525
# Epoch 40/400
# 213/213 [==============================] - 107s 501ms/step - loss: 0.3813 - accuracy: 0.8625 - val_loss: 0.7907 - val_accuracy: 0.7425
# Epoch 41/400
# 213/213 [==============================] - 106s 500ms/step - loss: 0.3829 - accuracy: 0.8637 - val_loss: 0.7520 - val_accuracy: 0.7733
# Epoch 42/400
# 213/213 [==============================] - 107s 502ms/step - loss: 0.3542 - accuracy: 0.8746 - val_loss: 0.9549 - val_accuracy: 0.7458
# Epoch 43/400
# 213/213 [==============================] - 106s 500ms/step - loss: 0.3187 - accuracy: 0.8887 - val_loss: 0.9163 - val_accuracy: 0.7567
# Epoch 44/400
# 213/213 [==============================] - 107s 504ms/step - loss: 0.3341 - accuracy: 0.8841 - val_loss: 0.9814 - val_accuracy: 0.7175
# Epoch 45/400
# 213/213 [==============================] - 107s 500ms/step - loss: 0.3017 - accuracy: 0.8949 - val_loss: 1.0668 - val_accuracy: 0.7317
# Epoch 46/400
# 213/213 [==============================] - 106s 496ms/step - loss: 0.3078 - accuracy: 0.8957 - val_loss: 0.7710 - val_accuracy: 0.7575
# Epoch 47/400
# 213/213 [==============================] - 106s 496ms/step - loss: 0.2854 - accuracy: 0.9051 - val_loss: 0.8046 - val_accuracy: 0.7683
# Epoch 48/400
# 213/213 [==============================] - 106s 499ms/step - loss: 0.2395 - accuracy: 0.9172 - val_loss: 0.8716 - val_accuracy: 0.7650
# Epoch 49/400
# 213/213 [==============================] - 110s 518ms/step - loss: 0.2093 - accuracy: 0.9297 - val_loss: 0.8415 - val_accuracy: 0.7758
# Epoch 50/400
# 213/213 [==============================] - 108s 505ms/step - loss: 0.2973 - accuracy: 0.9004 - val_loss: 0.8513 - val_accuracy: 0.7625
# Epoch 51/400
# 213/213 [==============================] - 111s 521ms/step - loss: 0.2382 - accuracy: 0.9235 - val_loss: 0.8893 - val_accuracy: 0.7575
# Epoch 52/400
# 213/213 [==============================] - 110s 515ms/step - loss: 0.1813 - accuracy: 0.9396 - val_loss: 0.9894 - val_accuracy: 0.7675
# Epoch 53/400
# 213/213 [==============================] - 103s 485ms/step - loss: 0.2065 - accuracy: 0.9331 - val_loss: 0.9018 - val_accuracy: 0.7408
# Epoch 54/400
# 213/213 [==============================] - 108s 508ms/step - loss: 0.2029 - accuracy: 0.9337 - val_loss: 1.0164 - val_accuracy: 0.7700
# Epoch 55/400
# 213/213 [==============================] - 106s 500ms/step - loss: 0.2153 - accuracy: 0.9265 - val_loss: 0.9068 - val_accuracy: 0.7642
# Epoch 56/400
# 213/213 [==============================] - 105s 491ms/step - loss: 0.1771 - accuracy: 0.9416 - val_loss: 0.9922 - val_accuracy: 0.7633
# Epoch 57/400
# 213/213 [==============================] - 106s 496ms/step - loss: 0.1574 - accuracy: 0.9471 - val_loss: 0.9694 - val_accuracy: 0.7617
# Epoch 58/400
# 213/213 [==============================] - 108s 508ms/step - loss: 0.1836 - accuracy: 0.9438 - val_loss: 1.1252 - val_accuracy: 0.7700
# Epoch 59/400
# 213/213 [==============================] - 108s 505ms/step - loss: 0.1445 - accuracy: 0.9526 - val_loss: 0.9470 - val_accuracy: 0.7867
# Epoch 60/400
# 213/213 [==============================] - 106s 498ms/step - loss: 0.1500 - accuracy: 0.9475 - val_loss: 1.1406 - val_accuracy: 0.7517
# Epoch 61/400
# 213/213 [==============================] - 108s 507ms/step - loss: 0.1650 - accuracy: 0.9491 - val_loss: 1.3290 - val_accuracy: 0.7583
# Epoch 62/400
# 213/213 [==============================] - 111s 521ms/step - loss: 0.1451 - accuracy: 0.9534 - val_loss: 1.0865 - val_accuracy: 0.7642
# Epoch 63/400
# 213/213 [==============================] - 112s 524ms/step - loss: 0.1383 - accuracy: 0.9556 - val_loss: 1.1224 - val_accuracy: 0.7608
# Epoch 64/400
# 213/213 [==============================] - 112s 524ms/step - loss: 0.1127 - accuracy: 0.9643 - val_loss: 1.2773 - val_accuracy: 0.7200
# Epoch 65/400
# 213/213 [==============================] - 112s 525ms/step - loss: 0.1207 - accuracy: 0.9616 - val_loss: 1.0899 - val_accuracy: 0.7725
# Epoch 66/400
# 213/213 [==============================] - 111s 522ms/step - loss: 0.1336 - accuracy: 0.9593 - val_loss: 0.9103 - val_accuracy: 0.7508
# Epoch 67/400
# 213/213 [==============================] - 109s 514ms/step - loss: 0.1289 - accuracy: 0.9618 - val_loss: 1.0858 - val_accuracy: 0.7483
# Epoch 68/400
# 213/213 [==============================] - 102s 478ms/step - loss: 0.1167 - accuracy: 0.9637 - val_loss: 1.0637 - val_accuracy: 0.7675
# Epoch 69/400
# 213/213 [==============================] - 105s 491ms/step - loss: 0.0727 - accuracy: 0.9778 - val_loss: 1.3249 - val_accuracy: 0.7750
# Epoch 70/400
# 213/213 [==============================] - 106s 497ms/step - loss: 0.1112 - accuracy: 0.9654 - val_loss: 1.1849 - val_accuracy: 0.7925
# Epoch 71/400
# 213/213 [==============================] - 110s 516ms/step - loss: 0.0927 - accuracy: 0.9715 - val_loss: 1.2324 - val_accuracy: 0.7750
# Epoch 72/400
# 213/213 [==============================] - 106s 495ms/step - loss: 0.1058 - accuracy: 0.9696 - val_loss: 1.1735 - val_accuracy: 0.7792
# Epoch 73/400
# 213/213 [==============================] - 106s 499ms/step - loss: 0.1748 - accuracy: 0.9494 - val_loss: 1.1939 - val_accuracy: 0.7842
# Epoch 74/400
# 213/213 [==============================] - 109s 511ms/step - loss: 0.1423 - accuracy: 0.9621 - val_loss: 1.1444 - val_accuracy: 0.7750
# Epoch 75/400
# 213/213 [==============================] - 106s 498ms/step - loss: 0.0871 - accuracy: 0.9724 - val_loss: 1.2298 - val_accuracy: 0.7708
# Epoch 76/400
# 213/213 [==============================] - 108s 506ms/step - loss: 0.0763 - accuracy: 0.9763 - val_loss: 1.2475 - val_accuracy: 0.7725
# Epoch 77/400
# 213/213 [==============================] - 105s 492ms/step - loss: 0.0461 - accuracy: 0.9885 - val_loss: 1.2703 - val_accuracy: 0.7783
# Epoch 78/400
# 213/213 [==============================] - 105s 492ms/step - loss: 0.0955 - accuracy: 0.9704 - val_loss: 1.2788 - val_accuracy: 0.7700
# Epoch 79/400
# 213/213 [==============================] - 105s 494ms/step - loss: 0.1107 - accuracy: 0.9668 - val_loss: 1.3962 - val_accuracy: 0.7300
# Epoch 80/400
# 213/213 [==============================] - 105s 494ms/step - loss: 0.1153 - accuracy: 0.9656 - val_loss: 1.4920 - val_accuracy: 0.7425
# Epoch 81/400
# 213/213 [==============================] - 106s 499ms/step - loss: 0.0916 - accuracy: 0.9750 - val_loss: 1.0809 - val_accuracy: 0.7375
# Epoch 82/400
# 213/213 [==============================] - 106s 499ms/step - loss: 0.0560 - accuracy: 0.9825 - val_loss: 1.5141 - val_accuracy: 0.7650
# Epoch 83/400
# 213/213 [==============================] - 105s 491ms/step - loss: 0.0628 - accuracy: 0.9829 - val_loss: 1.6319 - val_accuracy: 0.7592
# Epoch 84/400
# 213/213 [==============================] - 105s 493ms/step - loss: 0.0575 - accuracy: 0.9824 - val_loss: 1.5219 - val_accuracy: 0.7875
# Epoch 85/400
# 213/213 [==============================] - 107s 503ms/step - loss: 0.1245 - accuracy: 0.9621 - val_loss: 1.4199 - val_accuracy: 0.7467

# %% [markdown]
# ### Plot training results

# %%
plt.figure(figsize=(15,5))
plt.plot(history['loss'], label='Std training', alpha=.3, color='#ff7f0e', linestyle='--')
plt.plot(history['val_loss'], label='Std validation', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], label='Std training', alpha=.8, color='#ff7f0e', linestyle='--')
plt.plot(history['val_accuracy'], label='Std validation', alpha=.8, color='#ff7f0e')
plt.legend(loc='upper right')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %% [markdown]
# ### Plot the confusion matrix (evaluated on the validation set)

# %%
predictions = model.predict(X_val)
cm = confusion_matrix(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))

accuracy = accuracy_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_val, axis=-1), np.argmax(predictions, axis=-1), average=None)
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

plt.figure(figsize=(10,8))
sns.heatmap(cm.T, xticklabels=labels, yticklabels=labels)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# 38/38 [==============================] - 5s 120ms/step
# Accuracy: 0.7925
# Precision: 0.7972
# Recall: 0.7925
# F1: [0.7692 0.7697 0.8    0.7932 0.7986 0.894  0.8702 0.651 ]

# %% [markdown]
# ### Save the model

# %%
num_test_samples = 120

test_samples = []
test_targets = []
for i in range(0, len(labels)):
    for j in range(0, num_test_samples):
        test_samples.append(preprocess(ref_list[i][j]))
        test_targets.append(tfk.utils.to_categorical(i, len(labels)))
X_test = np.array(test_samples)
y_test = np.array(test_targets)


restored_model = tfk.models.load_model('best_model')
restored_loss, restored_acc = restored_model.evaluate(X_test, y_test, verbose=2)  #TODO: not right because validation set can change
loss, acc = model.evaluate(X_test, y_test, verbose=2)
if acc > restored_acc:  # know that this is conceptually wrong
    print("Model improved!")
    model.save('best_model')
else:
    print("No improvement!")
# Out:
# 30/30 - 4s - loss: 10.7756 - accuracy: 0.1250 - 4s/epoch - 135ms/step
# 30/30 - 4s - loss: 10.7756 - accuracy: 0.1250 - 4s/epoch - 124ms/step
# No improvement!
